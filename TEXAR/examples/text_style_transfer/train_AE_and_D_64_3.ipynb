# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import importlib
import numpy as np
import tensorflow as tf
import texar as tx

import tensorflow as tf

import texar as tx
from texar.modules import WordEmbedder, UnidirectionalRNNEncoder, \
        MLPTransformConnector, AttentionRNNDecoder, \
        GumbelSoftmaxEmbeddingHelper, Conv1DClassifier,Conv1DNetwork,BidirectionalRNNEncoder
from texar.core import get_train_op
from texar.utils import collect_trainable_variables, get_batch_size

from RL_model3 import RLModel3

tf.set_random_seed(1)

# %%
config = importlib.import_module('RLconfig')

# Data
train_data = tx.data.MultiAlignedData(config.train_data)
val_data = tx.data.MultiAlignedData(config.val_data)
test_data = tx.data.MultiAlignedData(config.test_data)
vocab = train_data.vocab(0)

iterator = tx.data.FeedableDataIterator({'train_g': train_data,'val': val_data, 'test': test_data})
batch = iterator.get_next()

# female Data
ftrain_data = tx.data.MultiAlignedData(config.ftrain_data)
fval_data = tx.data.MultiAlignedData(config.fval_data)
ftest_data = tx.data.MultiAlignedData(config.ftest_data)

fiterator = tx.data.FeedableDataIterator({'ftrain_g': ftrain_data,'fval': fval_data, 'ftest': ftest_data})
fbatch = fiterator.get_next()

# male Data
mtrain_data = tx.data.MultiAlignedData(config.mtrain_data)
mval_data = tx.data.MultiAlignedData(config.mval_data)
mtest_data = tx.data.MultiAlignedData(config.mtest_data)

miterator = tx.data.FeedableDataIterator({'mtrain_g': mtrain_data,'mval': mval_data, 'mtest': mtest_data})
mbatch = miterator.get_next()

gamma = 0.05
model = RLModel3(batch, fbatch, mbatch, vocab, 0.05, config.model)

# %%
def _train_epoch_AE(sess, epoch, verbose=True):
    avg_meters_g = tx.utils.AverageRecorder(size=5)

    step = 0
    while True:
        try:
            step += 1
            
            feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
            vals_g = sess.run(model.train_op_g_ae, feed_dict=feed_dict)
            avg_meters_g.add(vals_g)

            if verbose and (step == 1 or step % 5 == 0):
                print('step: {}, {}'.format(step, avg_meters_g.to_str(4)))

            '''
            if verbose and step % 2 == 0:
                iterator.restart_dataset(sess, 'val')
                _eval_epoch(sess, epoch)
            '''

        except tf.errors.OutOfRangeError:
            print('epoch: {}, {}'.format(epoch, avg_meters_g.to_str(4)))
            break
            
def _eval_epoch_AE(sess, epoch, val_or_test='val'):
    avg_meters = tx.utils.AverageRecorder()
    while True:
        try:
            feed_dict = {
                iterator.handle: iterator.get_handle(sess, val_or_test),
                tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
            }

            vals = sess.run(model.samples, feed_dict=feed_dict)
            batch_size = vals.pop('batch_size')

            # Computes BLEU
            samples = tx.utils.dict_pop(vals, list(model.samples.keys()))
            hyps = tx.utils.map_ids_to_strs(samples['transferred'], vocab)
            print("samples: ",hyps)

            refs = tx.utils.map_ids_to_strs(samples['original'], vocab)
            refs = np.expand_dims(refs, axis=1)
            print("reference: ",refs)

            bleu = tx.evals.corpus_bleu_moses(refs, hyps)
            vals['bleu'] = bleu

            avg_meters.add(vals, weight=batch_size)

            ###################################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            # Writes samples
            '''
            tx.utils.write_paired_text(
                refs.squeeze(), hyps,
                os.path.join(config.sample_path, 'val.%d'%epoch),
                append=True, mode='v')
            '''
        except tf.errors.OutOfRangeError:
            print('{}: {}'.format(
                val_or_test, avg_meters.to_str(precision=4)))
            break
    return avg_meters.avg()

def f_train_epoch_reg(sess, epoch):
    avg_meters_g = tx.utils.AverageRecorder(size=5)
    step = 0
    while True:
        try:
            step += 1          
            feed_dict = {fiterator.handle: fiterator.get_handle(sess, 'ftrain_g')}
            vals_g = sess.run(model.ftrain_op_d, feed_dict=feed_dict)
            avg_meters_g.add(vals_g)

            if (step == 1 or step % 5 == 0):
                print('step: {}, {}'.format(step, avg_meters_g.to_str(4)))
            '''
            if step % 2 == 0:
                iterator.restart_dataset(sess, 'val')
                _eval_epoch(sess, epoch)
            '''
        except tf.errors.OutOfRangeError:
            print('epoch: {}, {}'.format(epoch, avg_meters_g.to_str(4)))
            break
            
def m_train_epoch_reg(sess, epoch):
    avg_meters_g = tx.utils.AverageRecorder(size=5)
    step = 0
    while True:
        try:
            step += 1           
            feed_dict = {miterator.handle: miterator.get_handle(sess, 'mtrain_g')}
            vals_g = sess.run(model.mtrain_op_d, feed_dict=feed_dict)
            avg_meters_g.add(vals_g)

            if (step == 1 or step % 5 == 0):
                print('step: {}, {}'.format(step, avg_meters_g.to_str(4)))
            '''
            if verbose and step % 2 == 0:
                iterator.restart_dataset(sess, 'val')
                _eval_epoch(sess, epoch)
            '''
        except tf.errors.OutOfRangeError:
            print('epoch: {}, {}'.format(epoch, avg_meters_g.to_str(4)))
            break

def fevalf_epoch_reg(sess, val_or_test='fval'):
    avg_meters = []
    while True:
        try:
            ffeed_dict = {
                fiterator.handle: fiterator.get_handle(sess, val_or_test),
                tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
            }
            vals = sess.run(model.floss_reg_batch, feed_dict=ffeed_dict)
            #batch_size = config.train_data['batch_size']

            avg_meters.append(vals)

        except tf.errors.OutOfRangeError:
            avg_loss = np.mean(avg_meters)
            print('{}: {}'.format(
                val_or_test, avg_loss))
            break
    return avg_loss

def mevalm_epoch_reg(sess, val_or_test='mval'):
    avg_meters = []
    while True:
        try:
            mfeed_dict = {
                miterator.handle: miterator.get_handle(sess, val_or_test),
                tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
            }
            vals = sess.run(model.mloss_reg_batch, feed_dict=mfeed_dict)
            #batch_size = config.train_data['batch_size']

            avg_meters.append(vals)

        except tf.errors.OutOfRangeError:
            avg_loss = np.mean(avg_meters)
            print('{}: {}'.format(
                val_or_test, avg_loss))
            break
    return avg_loss


def RL_train_epoch(sess,epoch):
    step = 0
    while True:
        try:
            step+=1
            feed_dict = {iterator.handle: iterator.get_handle(sess,'train_g')}
            vals_g = sess.run(model.train_updated_interface,feed_dict=feed_dict)
            
            if step==1 or step%5==0:
                print('step: {}, {}'.format(step,vals_g))
                
        except tf.errors.OutOfRangeError:
            print('epoch: {}, {}'.format(epoch, vals_g))
            break


def get_sents_AE(sess,val_or_test='test'): 
    iterator.initialize_dataset(sess)
    sample_sents=[]
    #ref_sents=[]
    pre_dif=[]
    i=1
    while True:
        print("batch: ",i)
        i=i+1
        try:
            feed_dict = {
                iterator.handle: iterator.get_handle(sess, val_or_test),
                tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
            }

            vals = sess.run({'a':model.samples,'b':model.pre_dif}, feed_dict=feed_dict)

            #batch_size = vals['a'].pop('batch_size')

            # Computes BLEU
            samples = tx.utils.dict_pop(vals['a'], list(model.samples.keys()))
            hyps = tx.utils.map_ids_to_strs(samples['transferred'], vocab)
            #print("samples: ",hyps)

            #refs = tx.utils.map_ids_to_strs(samples['original'], vocab)
            #refs = np.expand_dims(refs, axis=1)
            #print("reference: ",refs)
            
            sample_sents.extend(hyps.tolist())
            pre_dif.extend(vals['b'].tolist())
            #ref_sents.extend(refs.tolist())
            
            #dif = np.abs(predict_sentiment(str(hyps[0]),frnn,fTEXT)-predict_sentiment(str(hyps[0]),mrnn,mTEXT))

        except tf.errors.OutOfRangeError:
            print("all batches finished")
            break
    return sample_sents,pre_dif

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
sess.run(tf.local_variables_initializer())
sess.run(tf.tables_initializer())

saver = tf.train.Saver(max_to_keep=None)

iterator.initialize_dataset(sess)
# fiterator 和 miterator 其实只是在训练discriminator的时候用，其他时候是用iterator
fiterator.initialize_dataset(sess)
miterator.initialize_dataset(sess)

# %% [markdown]
# ## 调试的时候用的代码

# %%
#saver.save(sess,'RLsave/allmodel64.ckpt')
# Out:
# INFO:tensorflow:RLsave/allmodel64.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# 'RLsave/allmodel64.ckpt'

# %%
saver.save(sess,'RLsave/AE_clas100convnet_finalstate_RL.ckpt') # model after RL training (narrowing pre_dif while keeping the original sent unchanged)
# Out:
# INFO:tensorflow:RLsave/AE_clas100convnet_finalstate_RL.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# 'RLsave/AE_clas100convnet_finalstate_RL.ckpt'

# %%
saver.restore(sess,'RLsave/AE_clas100onlyconvnet_finalstate_RL.ckpt') #model only after AE training
# Out:
# INFO:tensorflow:Restoring parameters from RLsave/AE_clas100onlyconvnet_RL.ckpt

# %%
# Train female regression model
for epoch in range(1, 20):
    fiterator.restart_dataset(sess, ['ftrain_g'])
    f_train_epoch_reg(sess,epoch)
    if epoch%3==0:
        print("evaluation on fval:")
        fiterator.restart_dataset(sess)
        fevalf_epoch_reg(sess, val_or_test='fval')
# Out:
# step: 1, 19.7001
# step: 5, 17.9688
# step: 10, 16.1812
# step: 15, 15.0004
# step: 20, 12.3564
# step: 25, 7.5261
# step: 30, 3.4269
# step: 35, 1.6063
# step: 40, 2.8278
# step: 45, 1.7427
# step: 50, 1.5196
# step: 55, 1.6947
# step: 60, 1.4191
# step: 65, 1.1881
# step: 70, 1.4325
# step: 75, 1.4281
# step: 80, 1.3928
# step: 85, 1.1643
# step: 90, 1.2019
# step: 95, 1.0786
# step: 100, 1.1660
# step: 105, 1.3316
# step: 110, 1.2507
# step: 115, 1.4047
# step: 120, 1.0872
# epoch: 1, 1.2410
# step: 1, 0.9108
# step: 5, 1.1863
# step: 10, 1.1095
# step: 15, 0.9863
# step: 20, 0.8375
# step: 25, 1.1534
# step: 30, 1.1056
# step: 35, 0.9419
# step: 40, 1.0774
# step: 45, 0.9252
# step: 50, 1.0302
# step: 55, 1.0515
# step: 60, 0.9571
# step: 65, 0.7929
# step: 70, 0.9983
# step: 75, 0.8963
# step: 80, 0.9598
# step: 85, 0.9144
# step: 90, 0.8375
# step: 95, 0.8398
# step: 100, 0.7962
# step: 105, 0.9041
# step: 110, 0.8748
# step: 115, 1.0852
# step: 120, 0.8208
# epoch: 2, 0.8445
# step: 1, 0.7349
# step: 5, 0.8511
# step: 10, 0.8451
# step: 15, 0.7351
# step: 20, 0.6977
# step: 25, 0.9030
# step: 30, 0.7191
# step: 35, 0.7000
# step: 40, 0.7591
# step: 45, 0.6701
# step: 50, 0.8570
# step: 55, 0.8580
# step: 60, 0.6983
# step: 65, 0.6486
# step: 70, 0.8152
# step: 75, 0.7248
# step: 80, 0.7598
# step: 85, 0.6538
# step: 90, 0.6451
# step: 95, 0.6135
# step: 100, 0.5911
# step: 105, 0.7132
# step: 110, 0.6537
# step: 115, 0.8722
# step: 120, 0.6455
# epoch: 3, 0.6587
# evaluation on fval:
# fval: 0.8161250352859497
# step: 1, 0.6195
# step: 5, 0.6507
# step: 10, 0.6043
# step: 15, 0.5683
# step: 20, 0.5312
# step: 25, 0.7304
# step: 30, 0.4763
# step: 35, 0.5533
# step: 40, 0.5117
# step: 45, 0.4706
# step: 50, 0.6866
# step: 55, 0.6408
# step: 60, 0.4885
# step: 65, 0.4583
# step: 70, 0.5817
# step: 75, 0.4958
# step: 80, 0.5766
# step: 85, 0.5237
# step: 90, 0.5101
# step: 95, 0.4315
# step: 100, 0.4366
# step: 105, 0.5610
# step: 110, 0.4645
# step: 115, 0.6285
# step: 120, 0.5296
# epoch: 4, 0.4919
# step: 1, 0.5590
# step: 5, 0.5406
# step: 10, 0.5151
# step: 15, 0.4330
# step: 20, 0.4371
# step: 25, 0.5338
# step: 30, 0.3625
# step: 35, 0.4781
# step: 40, 0.4397
# step: 45, 0.3950
# step: 50, 0.4813
# step: 55, 0.5081
# step: 60, 0.3813
# step: 65, 0.3947
# step: 70, 0.4605
# step: 75, 0.3810
# step: 80, 0.4509
# step: 85, 0.3828
# step: 90, 0.4142
# step: 95, 0.3878
# step: 100, 0.3565
# step: 105, 0.4568
# step: 110, 0.3856
# step: 115, 0.4939
# step: 120, 0.4026
# epoch: 5, 0.3982
# step: 1, 0.5148
# step: 5, 0.4489
# step: 10, 0.4116
# step: 15, 0.3698
# step: 20, 0.3459
# step: 25, 0.4806
# step: 30, 0.2958
# step: 35, 0.3512
# step: 40, 0.3448
# step: 45, 0.3333
# step: 50, 0.3905
# step: 55, 0.3998
# step: 60, 0.3216
# step: 65, 0.3220
# step: 70, 0.3890
# step: 75, 0.3039
# step: 80, 0.3876
# step: 85, 0.3201
# step: 90, 0.3418
# step: 95, 0.3320
# step: 100, 0.2787
# step: 105, 0.3817
# step: 110, 0.3406
# step: 115, 0.4195
# step: 120, 0.3550
# epoch: 6, 0.3435
# evaluation on fval:
# fval: 0.8352121114730835
# step: 1, 0.4495
# step: 5, 0.4048
# step: 10, 0.3678
# step: 15, 0.2930
# step: 20, 0.2848
# step: 25, 0.3424
# step: 30, 0.2667
# step: 35, 0.3255
# step: 40, 0.2654
# step: 45, 0.2830
# step: 50, 0.3660
# step: 55, 0.3376
# step: 60, 0.2484
# step: 65, 0.3149
# step: 70, 0.3591
# step: 75, 0.2663
# step: 80, 0.3720
# step: 85, 0.2852
# step: 90, 0.2886
# step: 95, 0.2511
# step: 100, 0.2888
# step: 105, 0.3512
# step: 110, 0.2804
# step: 115, 0.3790
# step: 120, 0.3439
# epoch: 7, 0.3104
# step: 1, 0.3626
# step: 5, 0.3731
# step: 10, 0.3283
# step: 15, 0.2538
# step: 20, 0.2651
# step: 25, 0.3638
# step: 30, 0.2550
# step: 35, 0.2845
# step: 40, 0.2788
# step: 45, 0.2686
# step: 50, 0.3184
# step: 55, 0.2930
# step: 60, 0.2759
# step: 65, 0.2662
# step: 70, 0.3132
# step: 75, 0.2441
# step: 80, 0.3111
# step: 85, 0.2687
# step: 90, 0.2462
# step: 95, 0.2577
# step: 100, 0.2485
# step: 105, 0.3208
# step: 110, 0.2406
# step: 115, 0.2967
# step: 120, 0.2742
# epoch: 8, 0.2957
# step: 1, 0.3863
# step: 5, 0.3325
# step: 10, 0.2636
# step: 15, 0.2258
# step: 20, 0.2499
# step: 25, 0.3110
# step: 30, 0.2401
# step: 35, 0.2656
# step: 40, 0.2362
# step: 45, 0.2322
# step: 50, 0.3064
# step: 55, 0.2679
# step: 60, 0.2353
# step: 65, 0.2520
# step: 70, 0.2632
# step: 75, 0.2000
# step: 80, 0.2808
# step: 85, 0.2192
# step: 90, 0.2444
# step: 95, 0.2381
# step: 100, 0.2087
# step: 105, 0.3110
# step: 110, 0.2278
# step: 115, 0.2684
# step: 120, 0.2383
# epoch: 9, 0.2147
# evaluation on fval:
# fval: 0.8442769050598145
# step: 1, 0.3058
# step: 5, 0.2803
# step: 10, 0.2915
# step: 15, 0.2367
# step: 20, 0.2294
# step: 25, 0.2567
# step: 30, 0.2080
# step: 35, 0.2289
# step: 40, 0.2127
# step: 45, 0.2413
# step: 50, 0.2875
# step: 55, 0.2312
# step: 60, 0.1975
# step: 65, 0.1977
# step: 70, 0.2412
# step: 75, 0.2209
# step: 80, 0.2637
# step: 85, 0.2348
# step: 90, 0.2504
# step: 95, 0.1971
# step: 100, 0.2187
# step: 105, 0.2928
# step: 110, 0.2100
# step: 115, 0.2343
# step: 120, 0.2545
# epoch: 10, 0.2308
# step: 1, 0.3352
# step: 5, 0.2733
# step: 10, 0.2723
# step: 15, 0.2023
# step: 20, 0.2263
# step: 25, 0.2497
# step: 30, 0.1991
# step: 35, 0.2351
# step: 40, 0.1940
# step: 45, 0.2369
# step: 50, 0.2640
# step: 55, 0.2168
# step: 60, 0.1946
# step: 65, 0.1996
# step: 70, 0.2681
# step: 75, 0.2057
# step: 80, 0.2191
# step: 85, 0.2445
# step: 90, 0.2253
# step: 95, 0.2049
# step: 100, 0.1996
# step: 105, 0.2855
# step: 110, 0.1949
# step: 115, 0.2177
# step: 120, 0.2624
# epoch: 11, 0.2512
# step: 1, 0.3279
# step: 5, 0.2758
# step: 10, 0.2534
# step: 15, 0.1914
# step: 20, 0.2409
# step: 25, 0.2427
# step: 30, 0.2256
# step: 35, 0.1971
# step: 40, 0.1762
# step: 45, 0.2350
# step: 50, 0.2260
# step: 55, 0.2177
# step: 60, 0.1966
# step: 65, 0.1821
# step: 70, 0.2786
# step: 75, 0.1827
# step: 80, 0.2603
# step: 85, 0.2199
# step: 90, 0.2136
# step: 95, 0.2229
# step: 100, 0.2221
# step: 105, 0.2676
# step: 110, 0.2145
# step: 115, 0.2241
# step: 120, 0.2271
# epoch: 12, 0.2322
# evaluation on fval:
# fval: 0.8743922710418701
# step: 1, 0.2391
# step: 5, 0.2619
# step: 10, 0.2357
# step: 15, 0.1903
# step: 20, 0.2303
# step: 25, 0.2629
# step: 30, 0.2300
# step: 35, 0.2219
# step: 40, 0.1903
# step: 45, 0.1954
# step: 50, 0.2482
# step: 55, 0.2000
# step: 60, 0.1652
# step: 65, 0.1833
# step: 70, 0.2390
# step: 75, 0.1949
# step: 80, 0.2438
# step: 85, 0.2035
# step: 90, 0.2290
# step: 95, 0.2070
# step: 100, 0.1965
# step: 105, 0.2628
# step: 110, 0.1910
# step: 115, 0.2084
# step: 120, 0.2221
# epoch: 13, 0.2241
# step: 1, 0.2433
# step: 5, 0.2436
# step: 10, 0.2290
# step: 15, 0.1981
# step: 20, 0.2132
# step: 25, 0.2640
# step: 30, 0.1951
# step: 35, 0.2494
# step: 40, 0.2282
# step: 45, 0.2536
# step: 50, 0.2935
# step: 55, 0.2237
# step: 60, 0.2135
# step: 65, 0.1711
# step: 70, 0.2322
# step: 75, 0.1647
# step: 80, 0.2207
# step: 85, 0.2288
# step: 90, 0.1976
# step: 95, 0.1676
# step: 100, 0.1855
# step: 105, 0.2375
# step: 110, 0.1542
# step: 115, 0.2010
# step: 120, 0.2498
# epoch: 14, 0.2293
# step: 1, 0.3514
# step: 5, 0.3076
# step: 10, 0.2596
# step: 15, 0.1942
# step: 20, 0.1864
# step: 25, 0.2268
# step: 30, 0.1604
# step: 35, 0.2088
# step: 40, 0.2173
# step: 45, 0.3388
# step: 50, 0.3111
# step: 55, 0.2941
# step: 60, 0.2727
# step: 65, 0.2109
# step: 70, 0.2911
# step: 75, 0.1780
# step: 80, 0.1979
# step: 85, 0.2115
# step: 90, 0.1939
# step: 95, 0.2037
# step: 100, 0.1723
# step: 105, 0.2596
# step: 110, 0.1746
# step: 115, 0.2012
# step: 120, 0.2034
# epoch: 15, 0.1940
# evaluation on fval:
# fval: 0.8887599110603333
# step: 1, 0.2314
# step: 5, 0.2343
# step: 10, 0.2344
# step: 15, 0.2486
# step: 20, 0.2006
# step: 25, 0.2296
# step: 30, 0.1751
# step: 35, 0.1847
# step: 40, 0.1611
# step: 45, 0.2050
# step: 50, 0.2492
# step: 55, 0.3642
# step: 60, 0.2820
# step: 65, 0.4429
# step: 70, 0.4513
# step: 75, 0.2669
# step: 80, 0.4206
# step: 85, 0.2167
# step: 90, 0.2272
# step: 95, 0.1972
# step: 100, 0.1871
# step: 105, 0.2563
# step: 110, 0.1668
# step: 115, 0.1956
# step: 120, 0.2107
# epoch: 16, 0.1640
# step: 1, 0.2148
# step: 5, 0.2284
# step: 10, 0.2175
# step: 15, 0.1629
# step: 20, 0.2060
# step: 25, 0.2387
# step: 30, 0.1670
# step: 35, 0.2152
# step: 40, 0.1789
# step: 45, 0.2363
# step: 50, 0.2119
# step: 55, 0.2474
# step: 60, 0.2226
# step: 65, 0.4137
# step: 70, 0.3335
# step: 75, 0.6494
# step: 80, 0.4634
# step: 85, 0.5687
# step: 90, 0.3492
# step: 95, 0.2970
# step: 100, 0.2658
# step: 105, 0.2589
# step: 110, 0.2013
# step: 115, 0.1975
# step: 120, 0.2131
# epoch: 17, 0.1942
# step: 1, 0.2776
# step: 5, 0.2444
# step: 10, 0.2276
# step: 15, 0.1572
# step: 20, 0.2336
# step: 25, 0.2338
# step: 30, 0.2255
# step: 35, 0.2302
# step: 40, 0.2312
# step: 45, 0.2817
# step: 50, 0.2989
# step: 55, 0.3260
# step: 60, 0.2734
# step: 65, 0.4201
# step: 70, 0.4387
# step: 75, 0.6279
# step: 80, 0.5238
# step: 85, 0.9108
# step: 90, 0.5614
# step: 95, 0.6788
# step: 100, 0.4146
# step: 105, 0.5790
# step: 110, 0.3386
# step: 115, 0.2857
# step: 120, 0.2735
# epoch: 18, 0.2042
# evaluation on fval:
# fval: 0.9495158195495605
# step: 1, 0.2399
# step: 5, 0.2705
# step: 10, 0.2204
# step: 15, 0.1546
# step: 20, 0.1938
# step: 25, 0.2088
# step: 30, 0.1890
# step: 35, 0.1981
# step: 40, 0.2845
# step: 45, 0.2552
# step: 50, 0.4724
# step: 55, 0.2848
# step: 60, 0.5633
# step: 65, 0.2971
# step: 70, 0.8018
# step: 75, 0.3686
# step: 80, 0.9621
# step: 85, 0.4556
# step: 90, 1.1052
# step: 95, 0.5561
# step: 100, 0.9070
# step: 105, 0.5117
# step: 110, 0.5892
# step: 115, 0.5464
# step: 120, 0.3760
# epoch: 19, 0.4000

# %%
# Train male regression model
for epoch in range(1, 20):
    miterator.restart_dataset(sess, ['mtrain_g'])
    m_train_epoch_reg(sess,epoch)
    if epoch%3==0:
        print("evaluation on mval:")
        miterator.restart_dataset(sess)
        mevalm_epoch_reg(sess, val_or_test='mval')
# Out:
# step: 1, 18.6572
# step: 5, 17.1254
# step: 10, 15.5842
# step: 15, 12.7524
# step: 20, 9.0738
# step: 25, 5.1732
# step: 30, 2.1053
# step: 35, 2.2862
# step: 40, 2.2012
# step: 45, 1.4117
# step: 50, 1.4791
# step: 55, 1.4668
# step: 60, 1.3457
# step: 65, 1.2113
# step: 70, 1.4553
# step: 75, 1.4488
# step: 80, 1.2195
# step: 85, 1.4517
# step: 90, 1.2983
# step: 95, 1.1301
# step: 100, 1.4036
# step: 105, 1.1456
# step: 110, 1.2189
# step: 115, 1.0333
# step: 120, 1.1050
# epoch: 1, 1.1050
# step: 1, 0.9457
# step: 5, 1.1101
# step: 10, 1.0587
# step: 15, 1.1210
# step: 20, 1.0288
# step: 25, 1.0764
# step: 30, 1.0834
# step: 35, 0.9957
# step: 40, 1.0759
# step: 45, 0.8869
# step: 50, 1.0383
# step: 55, 0.8966
# step: 60, 0.9770
# step: 65, 0.9232
# step: 70, 0.9566
# step: 75, 1.0466
# step: 80, 0.9122
# step: 85, 0.9730
# step: 90, 0.8381
# step: 95, 0.8620
# step: 100, 1.0127
# step: 105, 0.9004
# step: 110, 0.9397
# step: 115, 0.8705
# step: 120, 0.9070
# epoch: 2, 0.9070
# step: 1, 0.7378
# step: 5, 0.8212
# step: 10, 0.8186
# step: 15, 0.7672
# step: 20, 0.7800
# step: 25, 0.8313
# step: 30, 0.8744
# step: 35, 0.7846
# step: 40, 0.8700
# step: 45, 0.6328
# step: 50, 0.7782
# step: 55, 0.6810
# step: 60, 0.7270
# step: 65, 0.7099
# step: 70, 0.6928
# step: 75, 0.7684
# step: 80, 0.7028
# step: 85, 0.7753
# step: 90, 0.6328
# step: 95, 0.6926
# step: 100, 0.7735
# step: 105, 0.6818
# step: 110, 0.7297
# step: 115, 0.6945
# step: 120, 0.7613
# epoch: 3, 0.7613
# evaluation on mval:
# mval: 0.8371241688728333
# step: 1, 0.6347
# step: 5, 0.6433
# step: 10, 0.6655
# step: 15, 0.6304
# step: 20, 0.6051
# step: 25, 0.6330
# step: 30, 0.6842
# step: 35, 0.5848
# step: 40, 0.6564
# step: 45, 0.5028
# step: 50, 0.6366
# step: 55, 0.5106
# step: 60, 0.5316
# step: 65, 0.5317
# step: 70, 0.5225
# step: 75, 0.5614
# step: 80, 0.5529
# step: 85, 0.5513
# step: 90, 0.4729
# step: 95, 0.5504
# step: 100, 0.5684
# step: 105, 0.5161
# step: 110, 0.5493
# step: 115, 0.5615
# step: 120, 0.6061
# epoch: 4, 0.6061
# step: 1, 0.5114
# step: 5, 0.4855
# step: 10, 0.5615
# step: 15, 0.4799
# step: 20, 0.4617
# step: 25, 0.5533
# step: 30, 0.4988
# step: 35, 0.4670
# step: 40, 0.5431
# step: 45, 0.4231
# step: 50, 0.5004
# step: 55, 0.4681
# step: 60, 0.4560
# step: 65, 0.4227
# step: 70, 0.4055
# step: 75, 0.4241
# step: 80, 0.4409
# step: 85, 0.4498
# step: 90, 0.3741
# step: 95, 0.4721
# step: 100, 0.4571
# step: 105, 0.4045
# step: 110, 0.4524
# step: 115, 0.4496
# step: 120, 0.4779
# epoch: 5, 0.4779
# step: 1, 0.5013
# step: 5, 0.4098
# step: 10, 0.3880
# step: 15, 0.3998
# step: 20, 0.3334
# step: 25, 0.4268
# step: 30, 0.4349
# step: 35, 0.3719
# step: 40, 0.4590
# step: 45, 0.3223
# step: 50, 0.4267
# step: 55, 0.3877
# step: 60, 0.3135
# step: 65, 0.3650
# step: 70, 0.3096
# step: 75, 0.3628
# step: 80, 0.3678
# step: 85, 0.4028
# step: 90, 0.3051
# step: 95, 0.3699
# step: 100, 0.3936
# step: 105, 0.3772
# step: 110, 0.3973
# step: 115, 0.3932
# step: 120, 0.4195
# epoch: 6, 0.4195
# evaluation on mval:
# mval: 0.8387994766235352
# step: 1, 0.4236
# step: 5, 0.3278
# step: 10, 0.3410
# step: 15, 0.3242
# step: 20, 0.2822
# step: 25, 0.3521
# step: 30, 0.3546
# step: 35, 0.2950
# step: 40, 0.3663
# step: 45, 0.3090
# step: 50, 0.3767
# step: 55, 0.3084
# step: 60, 0.2688
# step: 65, 0.3083
# step: 70, 0.2854
# step: 75, 0.3266
# step: 80, 0.3389
# step: 85, 0.3282
# step: 90, 0.2795
# step: 95, 0.3653
# step: 100, 0.3228
# step: 105, 0.3083
# step: 110, 0.3675
# step: 115, 0.3067
# step: 120, 0.3745
# epoch: 7, 0.3745
# step: 1, 0.3789
# step: 5, 0.2941
# step: 10, 0.3194
# step: 15, 0.2715
# step: 20, 0.2522
# step: 25, 0.2940
# step: 30, 0.3164
# step: 35, 0.2260
# step: 40, 0.3038
# step: 45, 0.2844
# step: 50, 0.3486
# step: 55, 0.2977
# step: 60, 0.2375
# step: 65, 0.2949
# step: 70, 0.2405
# step: 75, 0.2683
# step: 80, 0.2757
# step: 85, 0.2991
# step: 90, 0.2347
# step: 95, 0.3170
# step: 100, 0.2990
# step: 105, 0.3132
# step: 110, 0.3276
# step: 115, 0.3315
# step: 120, 0.3160
# epoch: 8, 0.3160
# step: 1, 0.3353
# step: 5, 0.2640
# step: 10, 0.2638
# step: 15, 0.2569
# step: 20, 0.2299
# step: 25, 0.2450
# step: 30, 0.2870
# step: 35, 0.2373
# step: 40, 0.3065
# step: 45, 0.2487
# step: 50, 0.2877
# step: 55, 0.2789
# step: 60, 0.2181
# step: 65, 0.2810
# step: 70, 0.2360
# step: 75, 0.2409
# step: 80, 0.3173
# step: 85, 0.2603
# step: 90, 0.2221
# step: 95, 0.2865
# step: 100, 0.2677
# step: 105, 0.2901
# step: 110, 0.3185
# step: 115, 0.2590
# step: 120, 0.2908
# epoch: 9, 0.2908
# evaluation on mval:
# mval: 0.8671407699584961
# step: 1, 0.2965
# step: 5, 0.2238
# step: 10, 0.2718
# step: 15, 0.2901
# step: 20, 0.2431
# step: 25, 0.2215
# step: 30, 0.2683
# step: 35, 0.1998
# step: 40, 0.2798
# step: 45, 0.2094
# step: 50, 0.2814
# step: 55, 0.2504
# step: 60, 0.1993
# step: 65, 0.2459
# step: 70, 0.2371
# step: 75, 0.2373
# step: 80, 0.2398
# step: 85, 0.2482
# step: 90, 0.2086
# step: 95, 0.2461
# step: 100, 0.2732
# step: 105, 0.2804
# step: 110, 0.2858
# step: 115, 0.2561
# step: 120, 0.2906
# epoch: 10, 0.2906
# step: 1, 0.2156
# step: 5, 0.1816
# step: 10, 0.2666
# step: 15, 0.2476
# step: 20, 0.2157
# step: 25, 0.2246
# step: 30, 0.2653
# step: 35, 0.2381
# step: 40, 0.2658
# step: 45, 0.1883
# step: 50, 0.2837
# step: 55, 0.2394
# step: 60, 0.2354
# step: 65, 0.2426
# step: 70, 0.2045
# step: 75, 0.2373
# step: 80, 0.2359
# step: 85, 0.2459
# step: 90, 0.1899
# step: 95, 0.2370
# step: 100, 0.2721
# step: 105, 0.2303
# step: 110, 0.2545
# step: 115, 0.2662
# step: 120, 0.2970
# epoch: 11, 0.2970
# step: 1, 0.2587
# step: 5, 0.2098
# step: 10, 0.2788
# step: 15, 0.2334
# step: 20, 0.2693
# step: 25, 0.2399
# step: 30, 0.2381
# step: 35, 0.2278
# step: 40, 0.2370
# step: 45, 0.1997
# step: 50, 0.2279
# step: 55, 0.2169
# step: 60, 0.1909
# step: 65, 0.2233
# step: 70, 0.2083
# step: 75, 0.2150
# step: 80, 0.2181
# step: 85, 0.2403
# step: 90, 0.2111
# step: 95, 0.2484
# step: 100, 0.2477
# step: 105, 0.2194
# step: 110, 0.2369
# step: 115, 0.2126
# step: 120, 0.2457
# epoch: 12, 0.2457
# evaluation on mval:
# mval: 0.932224690914154
# step: 1, 0.2819
# step: 5, 0.2076
# step: 10, 0.3094
# step: 15, 0.2940
# step: 20, 0.2724
# step: 25, 0.2260
# step: 30, 0.2957
# step: 35, 0.2442
# step: 40, 0.2929
# step: 45, 0.2283
# step: 50, 0.2558
# step: 55, 0.2219
# step: 60, 0.1991
# step: 65, 0.2024
# step: 70, 0.2048
# step: 75, 0.2078
# step: 80, 0.2342
# step: 85, 0.2029
# step: 90, 0.1694
# step: 95, 0.2176
# step: 100, 0.2278
# step: 105, 0.2199
# step: 110, 0.2310
# step: 115, 0.2152
# step: 120, 0.2395
# epoch: 13, 0.2395
# step: 1, 0.2248
# step: 5, 0.2479
# step: 10, 0.2564
# step: 15, 0.3302
# step: 20, 0.2534
# step: 25, 0.2408
# step: 30, 0.3670
# step: 35, 0.2493
# step: 40, 0.3623
# step: 45, 0.2653
# step: 50, 0.3212
# step: 55, 0.3173
# step: 60, 0.2553
# step: 65, 0.2961
# step: 70, 0.2222
# step: 75, 0.2362
# step: 80, 0.2274
# step: 85, 0.2392
# step: 90, 0.1863
# step: 95, 0.2094
# step: 100, 0.2037
# step: 105, 0.2038
# step: 110, 0.2229
# step: 115, 0.2039
# step: 120, 0.2312
# epoch: 14, 0.2312
# step: 1, 0.2863
# step: 5, 0.2095
# step: 10, 0.2594
# step: 15, 0.2750
# step: 20, 0.2461
# step: 25, 0.3418
# step: 30, 0.3137
# step: 35, 0.3713
# step: 40, 0.4951
# step: 45, 0.2893
# step: 50, 0.5477
# step: 55, 0.2952
# step: 60, 0.4839
# step: 65, 0.3628
# step: 70, 0.4571
# step: 75, 0.4272
# step: 80, 0.3237
# step: 85, 0.4290
# step: 90, 0.3028
# step: 95, 0.3553
# step: 100, 0.2419
# step: 105, 0.2662
# step: 110, 0.2476
# step: 115, 0.2294
# step: 120, 0.2545
# epoch: 15, 0.2545
# evaluation on mval:
# mval: 0.9063244462013245
# step: 1, 0.2215
# step: 5, 0.2105
# step: 10, 0.2889
# step: 15, 0.2408
# step: 20, 0.3127
# step: 25, 0.2858
# step: 30, 0.3980
# step: 35, 0.4806
# step: 40, 0.4478
# step: 45, 0.7311
# step: 50, 0.4048
# step: 55, 0.8564
# step: 60, 0.3791
# step: 65, 0.6114
# step: 70, 0.3837
# step: 75, 0.5757
# step: 80, 0.5603
# step: 85, 0.4706
# step: 90, 0.6117
# step: 95, 0.4256
# step: 100, 0.4947
# step: 105, 0.3501
# step: 110, 0.3930
# step: 115, 0.2820
# step: 120, 0.2406
# epoch: 16, 0.2406
# step: 1, 0.2703
# step: 5, 0.2125
# step: 10, 0.2203
# step: 15, 0.2147
# step: 20, 0.2341
# step: 25, 0.2121
# step: 30, 0.3879
# step: 35, 0.2326
# step: 40, 0.5208
# step: 45, 0.3141
# step: 50, 0.5401
# step: 55, 0.3978
# step: 60, 0.4610
# step: 65, 0.3278
# step: 70, 0.3297
# step: 75, 0.3252
# step: 80, 0.3375
# step: 85, 0.3274
# step: 90, 0.2463
# step: 95, 0.4264
# step: 100, 0.3023
# step: 105, 0.4881
# step: 110, 0.2626
# step: 115, 0.3706
# step: 120, 0.3233
# epoch: 17, 0.3233
# step: 1, 0.1919
# step: 5, 0.2447
# step: 10, 0.3264
# step: 15, 0.2204
# step: 20, 0.2719
# step: 25, 0.2153
# step: 30, 0.3054
# step: 35, 0.1953
# step: 40, 0.3405
# step: 45, 0.2564
# step: 50, 0.3208
# step: 55, 0.2736
# step: 60, 0.2902
# step: 65, 0.2884
# step: 70, 0.2580
# step: 75, 0.2158
# step: 80, 0.2482
# step: 85, 0.2166
# step: 90, 0.2337
# step: 95, 0.2325
# step: 100, 0.2468
# step: 105, 0.2560
# step: 110, 0.2680
# step: 115, 0.2014
# step: 120, 0.3958
# epoch: 18, 0.3958
# evaluation on mval:
# mval: 0.9198949933052063
# step: 1, 0.3514
# step: 5, 0.2203
# step: 10, 0.4007
# step: 15, 0.2320
# step: 20, 0.2989
# step: 25, 0.3406
# step: 30, 0.2238
# step: 35, 0.3320
# step: 40, 0.2679
# step: 45, 0.2816
# step: 50, 0.2394
# step: 55, 0.2558
# step: 60, 0.1674
# step: 65, 0.2319
# step: 70, 0.1846
# step: 75, 0.2321
# step: 80, 0.2070
# step: 85, 0.2362
# step: 90, 0.1751
# step: 95, 0.2019
# step: 100, 0.1998
# step: 105, 0.2182
# step: 110, 0.2166
# step: 115, 0.2218
# step: 120, 0.2924
# epoch: 19, 0.2924

# %% [markdown]
# # loss for female and male modes

# %% [markdown]
# ---------------------------

# %%
# evaluate female model loss on female data
fiterator.restart_dataset(sess)
fevalf_epoch_reg(sess, val_or_test='ftest')
# Out:
# ftest: 1.1521238088607788
# 1.1521238

# %% [markdown]
# ## 得到 f_on_f 的预测结果

# %%
## 得到f_on_fdata的预测结果

all_pre = []
all_Y = []
all_sent = []
val_or_test = 'ftest'

fiterator.restart_dataset(sess)
while True:
    try:
        ffeed_dict = {
            fiterator.handle: fiterator.get_handle(sess, val_or_test),
            tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
        }
        vals = sess.run(model.freg_sample, feed_dict=ffeed_dict)
        all_pre.extend(vals['fprediction'].tolist())
        all_Y.extend(vals['fground_truth'].tolist())
        all_sent.extend(vals['fsent'].tolist())

    except tf.errors.OutOfRangeError:
        print("end of epoch")
        break

allsent2 = []
for x in all_sent:
    allsent2.append(tx.utils.map_ids_to_strs(x,vocab))

l = len(all_pre)
with open('data/gender_data/fmodel_fval_pre','w') as f:
    for i in range(l):
        f.write(str(all_Y[i])+'\t')
        f.write(str(all_pre[i])+'\t')
        f.write(allsent2[i]+'\n')

all_pre = np.array(all_pre)
all_Y = np.array(all_Y)

print(np.sum(abs(all_pre-all_Y)<0.5)/l)
# Out:
# end of epoch
# 0.4223901098901099

# %% [markdown]
# ---------------------------

# %%
# evaluate male model loss on male data
miterator.restart_dataset(sess)
mevalm_epoch_reg(sess, val_or_test='mtest')
# Out:
# mtest: 0.8676668405532837
# 0.86766684

# %% [markdown]
# ## 得到 m_on_m 的预测结果

# %%
## 得到f_on_fdata的预测结果

all_pre = []
all_Y = []
all_sent = []
val_or_test = 'mtest'

miterator.restart_dataset(sess)
while True:
    try:
        mfeed_dict = {
            miterator.handle: miterator.get_handle(sess, val_or_test),
            tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
        }
        vals = sess.run(model.mreg_sample, feed_dict=mfeed_dict)
        all_pre.extend(vals['mprediction'].tolist())
        all_Y.extend(vals['mground_truth'].tolist())
        all_sent.extend(vals['msent'].tolist())

    except tf.errors.OutOfRangeError:
        print("end of epoch")
        break

allsent2 = []
for x in all_sent:
    allsent2.append(tx.utils.map_ids_to_strs(x,vocab))

l = len(all_pre)
with open('data/gender_data/mmodel_mtest_pre','w') as f:
    for i in range(l):
        f.write(str(all_Y[i])+'\t')
        f.write(str(all_pre[i])+'\t')
        f.write(allsent2[i]+'\n')

all_pre = np.array(all_pre)
all_Y = np.array(all_Y)

print(np.sum(abs(all_pre-all_Y)<0.5)/l)
# Out:
# end of epoch
# 0.4097222222222222

# %% [markdown]
# ## female modle on male data loss (但是注意测试完了之后要把代码改回来)

# %%
self = model
#self.fconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.freg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.fconv_output = self.fconvnet(inputs=self.freg_embedder(ids=self.minputs['text_ids'][:, 1:])) #(64, 128)  等一会做一下finputs!!!
#p = {"type": "Dense", "kwargs": {'units':1}}
#self.fdense_layer = tx.core.layers.get_layer(hparams=p)
self.freg_output = self.fdense_layer(inputs=self.fconv_output)

self.fprediction = tf.reshape(self.freg_output,[-1])
self.fground_truth = tf.to_float(self.minputs['labels'])
self.freg_sample = {
        "fprediction": self.fprediction,
        "fground_truth": self.fground_truth,
        "fsent": self.minputs['text_ids'][:, 1:]
    }

self.floss_reg_single = tf.pow(self.fprediction - self.fground_truth,2) #这样得到的是单个的loss,可以之后在RL里面对一整个batch进行update
self.floss_reg_batch = tf.reduce_mean(self.floss_reg_single) #对一个batch求和平均的loss


avg_meters = []
val_or_test = 'mtrain_g'
miterator.restart_dataset(sess)
while True:
    try:
        mfeed_dict = {
            miterator.handle: miterator.get_handle(sess, val_or_test),
            tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
        }
        vals = sess.run(model.floss_reg_batch, feed_dict=mfeed_dict)
        avg_meters.append(vals)

    except tf.errors.OutOfRangeError:
        avg_loss = np.mean(avg_meters)
        print('{}: {}'.format(
            val_or_test, avg_loss))
        break
print(avg_loss)
# Out:
# mtrain_g: 0.8748442530632019
# 0.87484425

# %% [markdown]
# ### 得到 f_on_m 的预测结果

# %%
## 得到f_on_fdata的预测结果

all_pre = []
all_Y = []
all_sent = []
val_or_test = 'mtest'

miterator.restart_dataset(sess)
while True:
    try:
        mfeed_dict = {
            miterator.handle: miterator.get_handle(sess, val_or_test),
            tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
        }
        vals = sess.run(model.freg_sample, feed_dict=mfeed_dict)
        all_pre.extend(vals['fprediction'].tolist())
        all_Y.extend(vals['fground_truth'].tolist())
        all_sent.extend(vals['fsent'].tolist())

    except tf.errors.OutOfRangeError:
        print("end of epoch")
        break

allsent2 = []
for x in all_sent:
    allsent2.append(tx.utils.map_ids_to_strs(x,vocab))

l = len(all_pre)
with open('data/gender_data/fmodel_mtest_pre','w') as f:
    for i in range(l):
        f.write(str(all_Y[i])+'\t')
        f.write(str(all_pre[i])+'\t')
        f.write(allsent2[i]+'\n')

all_pre = np.array(all_pre)
all_Y = np.array(all_Y)

print(np.sum(abs(all_pre-all_Y)<0.5)/l)
# Out:
# end of epoch
# 0.44027777777777777

# %%
## 把代码改回来

self = model
#self.fconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.freg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.fconv_output = self.fconvnet(inputs=self.freg_embedder(ids=self.finputs['text_ids'][:, 1:])) #(64, 128)  等一会做一下finputs!!!
#p = {"type": "Dense", "kwargs": {'units':1}}
#self.fdense_layer = tx.core.layers.get_layer(hparams=p)
self.freg_output = self.fdense_layer(inputs=self.fconv_output)

self.fprediction = tf.reshape(self.freg_output,[-1])
self.fground_truth = tf.to_float(self.finputs['labels'])
self.freg_sample = {
        "fprediction": self.fprediction,
        "fground_truth": self.fground_truth,
        "fsent": self.finputs['text_ids'][:, 1:]
    }

self.floss_reg_single = tf.pow(self.fprediction - self.fground_truth,2) #这样得到的是单个的loss,可以之后在RL里面对一整个batch进行update
self.floss_reg_batch = tf.reduce_mean(self.floss_reg_single) #对一个batch求和平均的loss

# %% [markdown]
# ## male modle on female data (但是注意测试完了之后要把代码改回来)

# %%
self = model
#self.mconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.mreg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.mconv_output = self.mconvnet(inputs=self.mreg_embedder(ids=self.finputs['text_ids'][:, 1:])) #(64, 128)
#p = {"type": "Dense", "kwargs": {'units':1}}
#self.mdense_layer = tx.core.layers.get_layer(hparams=p)
self.mreg_output = self.mdense_layer(inputs=self.mconv_output)

self.mprediction = tf.reshape(self.mreg_output,[-1])
self.mground_truth = tf.to_float(self.finputs['labels'])
self.mreg_sample = {
        "mprediction": self.mprediction,
        "mground_truth": self.mground_truth,
        "msent": self.finputs['text_ids'][:, 1:]
}

self.mloss_reg_single = tf.pow(self.mprediction - self.mground_truth,2) #这样得到的是单个的loss,可以之后在RL里面对一整个batch进行update
self.mloss_reg_batch = tf.reduce_mean(self.mloss_reg_single) #对一个batch求和平均的loss


avg_meters = []
val_or_test = 'ftest'
fiterator.restart_dataset(sess)
while True:
    try:
        ffeed_dict = {
            fiterator.handle: fiterator.get_handle(sess, val_or_test),
            tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
        }
        vals = sess.run(model.mloss_reg_batch, feed_dict=ffeed_dict)
        avg_meters.append(vals)

    except tf.errors.OutOfRangeError:
        avg_loss = np.mean(avg_meters)
        print('{}: {}'.format(
            val_or_test, avg_loss))
        break
print(avg_loss)
# Out:
# ftest: 0.8671502470970154
# 0.86715025

# %%
## 得到 m_on_fdata的预测结果

all_pre = []
all_Y = []
all_sent = []
val_or_test = 'ftest'

fiterator.restart_dataset(sess)
while True:
    try:
        ffeed_dict = {
            fiterator.handle: fiterator.get_handle(sess, val_or_test),
            tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
        }
        vals = sess.run(model.mreg_sample, feed_dict=ffeed_dict)
        all_pre.extend(vals['mprediction'].tolist())
        all_Y.extend(vals['mground_truth'].tolist())
        all_sent.extend(vals['msent'].tolist())

    except tf.errors.OutOfRangeError:
        print("end of epoch")
        break

allsent2 = []
for x in all_sent:
    allsent2.append(tx.utils.map_ids_to_strs(x,vocab))

l = len(all_pre)
with open('data/gender_data/mmodel_ftest_pre','w') as f:
    for i in range(l):
        f.write(str(all_Y[i])+'\t')
        f.write(str(all_pre[i])+'\t')
        f.write(allsent2[i]+'\n')

all_pre = np.array(all_pre)
all_Y = np.array(all_Y)

print(np.sum(abs(all_pre-all_Y)<0.5)/l)
# Out:
# end of epoch
# 0.4491758241758242

# %% [markdown]
# ## 把代码改回来

# %%
self = model
#self.mconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.mreg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.mconv_output = self.mconvnet(inputs=self.mreg_embedder(ids=self.minputs['text_ids'][:, 1:])) #(64, 128)
p = {"type": "Dense", "kwargs": {'units':1}}
#self.mdense_layer = tx.core.layers.get_layer(hparams=p)
self.mreg_output = self.mdense_layer(inputs=self.mconv_output)

self.mprediction = tf.reshape(self.mreg_output,[-1])
self.mground_truth = tf.to_float(self.minputs['labels'])
self.mreg_sample = {
        "mprediction": self.mprediction,
        "mground_truth": self.mground_truth,
        "msent": self.minputs['text_ids'][:, 1:]
}

self.mloss_reg_single = tf.pow(self.mprediction - self.mground_truth,2) #这样得到的是单个的loss,可以之后在RL里面对一整个batch进行update
self.mloss_reg_batch = tf.reduce_mean(self.mloss_reg_single) #对一个batch求和平均的loss

# %% [markdown]
# ## 得到all_data的预测结果 （最后把代码改回来）

# %%
self = model
############################ female sentiment regression model
#现在只用了convnet不知道效果，之后可以试试RNN decoding看regression的准确度，或者把两个结合一下（concat成一个向量）
#self.fconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.freg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.fconv_output = self.fconvnet(inputs=self.freg_embedder(ids=self.inputs['text_ids'][:, 1:])) #(64, 128)  等一会做一下finputs!!!
#p = {"type": "Dense", "kwargs": {'units':1}}
#self.fdense_layer = tx.core.layers.get_layer(hparams=p)
self.freg_output = self.fdense_layer(inputs=self.fconv_output)

self.fprediction = tf.reshape(self.freg_output,[-1])
self.fground_truth = tf.to_float(self.inputs['labels'])
self.freg_sample = {
        "fprediction": self.fprediction,
        "fground_truth": self.fground_truth,
        "fsent": self.inputs['text_ids'][:, 1:]
    }

############################ male sentiment regression model
#self.mconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.mreg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.mconv_output = self.mconvnet(inputs=self.mreg_embedder(ids=self.inputs['text_ids'][:, 1:])) #(64, 128)
#p = {"type": "Dense", "kwargs": {'units':1}}
#self.mdense_layer = tx.core.layers.get_layer(hparams=p)
self.mreg_output = self.mdense_layer(inputs=self.mconv_output)

self.mprediction = tf.reshape(self.mreg_output,[-1])
self.mground_truth = tf.to_float(self.inputs['labels'])
self.mreg_sample = {
        "mprediction": self.mprediction,
        "mground_truth": self.mground_truth,
        "msent": self.inputs['text_ids'][:, 1:]
}

# %%
all_pre = []
all_Y = []
all_sent = []
val_or_test = 'train_g'

iterator.restart_dataset(sess)
while True:
    try:
        feed_dict = {
            iterator.handle: iterator.get_handle(sess, val_or_test),
            tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
        }
        vals = sess.run(model.mreg_sample, feed_dict=feed_dict)
        all_pre.extend(vals['mprediction'].tolist())
        all_Y.extend(vals['mground_truth'].tolist())
        all_sent.extend(vals['msent'].tolist())

    except tf.errors.OutOfRangeError:
        print("end of epoch")
        break
# Out:
# end of epoch

# %%
fpre = []
fY = []
fsent = []

# %%
fpre.extend(all_pre)
fY.extend(all_Y)
fsent.extend(all_sent)

# %%
len(fpre)
# Out:
# 19301

# %%
mpre = []
mY = []
msent = []

# %%
mpre.extend(all_pre)
mY.extend(all_Y)
msent.extend(all_sent)

# %%
# change sent index to sentence
msent2 = []
for x in msent:
    msent2.append(tx.utils.map_ids_to_strs(x,vocab))
fsent2 = []
for x in fsent:
    fsent2.append(tx.utils.map_ids_to_strs(x,vocab))

# %%
l = len(fpre)

# %%
with open('data/gender_data/fmodel_preall','w') as f:
    for i in range(l):
        f.write(str(fY[i])+'\t')
        f.write(str(fpre[i])+'\t')
        f.write(fsent2[i]+'\n')

# %%
with open('data/gender_data/mmodel_preall','w') as f:
    for i in range(l):
        f.write(str(mY[i])+'\t')
        f.write(str(mpre[i])+'\t')
        f.write(msent2[i]+'\n')

# %% [markdown]
# ## 把代码改回来

# %%
############################ female sentiment regression model
#现在只用了convnet不知道效果，之后可以试试RNN decoding看regression的准确度，或者把两个结合一下（concat成一个向量）
#self.fconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.freg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.fconv_output = self.fconvnet(inputs=self.freg_embedder(ids=self.finputs['text_ids'][:, 1:])) #(64, 128)  等一会做一下finputs!!!
#p = {"type": "Dense", "kwargs": {'units':1}}
#self.fdense_layer = tx.core.layers.get_layer(hparams=p)
self.freg_output = self.fdense_layer(inputs=self.fconv_output)

self.fprediction = tf.reshape(self.freg_output,[-1])
self.fground_truth = tf.to_float(self.finputs['labels'])
self.freg_sample = {
        "fprediction": self.fprediction,
        "fground_truth": self.fground_truth,
        "fsent": self.inputs['text_ids'][:, 1:]
    }

############################ male sentiment regression model
#self.mconvnet = Conv1DNetwork(hparams=self._hparams.convnet) #[batch_size, time_steps, embedding_dim] (default input)
#convnet = Conv1DNetwork()
#self.mreg_embedder = WordEmbedder(vocab_size=self.vocab.size,hparams=self._hparams.embedder) #(64, 26, 100) (output shape of clas_embedder(ids=inputs['text_ids'][:, 1:]))
self.mconv_output = self.mconvnet(inputs=self.mreg_embedder(ids=self.minputs['text_ids'][:, 1:])) #(64, 128)
#p = {"type": "Dense", "kwargs": {'units':1}}
#self.mdense_layer = tx.core.layers.get_layer(hparams=p)
self.mreg_output = self.mdense_layer(inputs=self.mconv_output)

self.mprediction = tf.reshape(self.mreg_output,[-1])
self.mground_truth = tf.to_float(self.minputs['labels'])
self.mreg_sample = {
        "mprediction": self.mprediction,
        "mground_truth": self.mground_truth,
        "msent": self.inputs['text_ids'][:, 1:]
}

# %% [markdown]
# ## 训练 AE 模型

# %%
for epoch in range(20):
    iterator.restart_dataset(sess)
    _train_epoch_AE(sess, epoch, verbose=True)
# Out:
# step: 1, 20.8082
# step: 5, 19.5076
# step: 10, 13.6885
# step: 15, 10.1947
# step: 20, 8.8356
# step: 25, 8.1333
# step: 30, 7.8104
# step: 35, 7.5171
# step: 40, 7.3809
# step: 45, 7.2361
# step: 50, 7.2126
# step: 55, 7.0266
# step: 60, 6.8872
# step: 65, 6.8924
# step: 70, 6.8515
# step: 75, 6.7434
# step: 80, 6.6031
# step: 85, 6.4644
# step: 90, 6.2775
# step: 95, 6.2208
# step: 100, 6.0819
# step: 105, 5.9561
# step: 110, 6.0665
# step: 115, 6.0655
# step: 120, 5.9292
# step: 125, 5.9144
# step: 130, 5.8478
# step: 135, 5.9537
# step: 140, 5.8630
# step: 145, 5.9022
# step: 150, 5.8361
# step: 155, 5.8827
# step: 160, 5.8259
# step: 165, 5.6868
# step: 170, 5.7853
# step: 175, 5.7930
# step: 180, 5.8100
# step: 185, 5.8827
# step: 190, 5.7765
# step: 195, 5.8223
# step: 200, 5.7640
# step: 205, 5.6567
# step: 210, 5.7569
# step: 215, 5.5886
# step: 220, 5.6213
# step: 225, 5.6601
# step: 230, 5.7383
# step: 235, 5.5888
# step: 240, 5.7189
# epoch: 0, 5.6081
# step: 1, 5.5904
# step: 5, 5.6259
# step: 10, 5.4694
# step: 15, 5.5500
# step: 20, 5.5463
# step: 25, 5.6128
# step: 30, 5.5433
# step: 35, 5.5287
# step: 40, 5.6150
# step: 45, 5.5241
# step: 50, 5.5327
# step: 55, 5.5075
# step: 60, 5.4842
# step: 65, 5.5141
# step: 70, 5.4406
# step: 75, 5.5270
# step: 80, 5.4296
# step: 85, 5.4333
# step: 90, 5.4388
# step: 95, 5.4922
# step: 100, 5.4221
# step: 105, 5.3009
# step: 110, 5.4260
# step: 115, 5.5150
# step: 120, 5.4195
# step: 125, 5.3970
# step: 130, 5.3606
# step: 135, 5.5120
# step: 140, 5.4284
# step: 145, 5.5002
# step: 150, 5.3935
# step: 155, 5.4642
# step: 160, 5.4173
# step: 165, 5.2297
# step: 170, 5.2183
# step: 175, 5.2445
# step: 180, 5.2401
# step: 185, 5.2928
# step: 190, 5.2336
# step: 195, 5.3226
# step: 200, 5.3731
# step: 205, 5.3287
# step: 210, 5.3348
# step: 215, 5.1367
# step: 220, 5.2101
# step: 225, 5.2149
# step: 230, 5.3961
# step: 235, 5.2349
# step: 240, 5.3217
# epoch: 1, 5.1456
# step: 1, 5.1517
# step: 5, 5.2132
# step: 10, 5.0634
# step: 15, 5.0921
# step: 20, 5.1018
# step: 25, 5.1479
# step: 30, 5.0803
# step: 35, 5.0660
# step: 40, 5.1002
# step: 45, 5.0059
# step: 50, 5.5464
# step: 55, 5.2239
# step: 60, 5.1457
# step: 65, 5.0969
# step: 70, 4.9652
# step: 75, 5.0707
# step: 80, 4.9237
# step: 85, 4.9379
# step: 90, 4.9209
# step: 95, 4.9677
# step: 100, 4.8679
# step: 105, 4.6925
# step: 110, 4.7980
# step: 115, 4.8497
# step: 120, 4.8247
# step: 125, 4.8309

# %%
sample_sents=[]
pre_dif = []
sample_sents,pre_dif = get_sents_AE(sess,'train_g')
# Out:
# batch:  1
# batch:  2
# batch:  3
# batch:  4
# batch:  5
# batch:  6
# batch:  7
# batch:  8
# batch:  9
# batch:  10
# batch:  11
# batch:  12
# batch:  13
# batch:  14
# batch:  15
# batch:  16
# batch:  17
# batch:  18
# batch:  19
# batch:  20
# batch:  21
# batch:  22
# batch:  23
# batch:  24
# batch:  25
# batch:  26
# batch:  27
# batch:  28
# batch:  29
# batch:  30
# batch:  31
# batch:  32
# batch:  33
# batch:  34
# batch:  35
# batch:  36
# batch:  37
# batch:  38
# batch:  39
# batch:  40
# batch:  41
# batch:  42
# batch:  43
# batch:  44
# batch:  45
# batch:  46
# batch:  47
# batch:  48
# batch:  49
# batch:  50
# batch:  51
# batch:  52
# batch:  53
# batch:  54
# batch:  55
# batch:  56
# batch:  57
# batch:  58
# batch:  59
# batch:  60
# batch:  61
# batch:  62
# batch:  63
# batch:  64
# batch:  65
# batch:  66
# batch:  67
# batch:  68
# batch:  69
# batch:  70
# batch:  71
# batch:  72
# batch:  73
# batch:  74
# batch:  75
# batch:  76
# batch:  77
# batch:  78
# batch:  79
# batch:  80
# batch:  81
# batch:  82
# batch:  83
# batch:  84
# batch:  85
# batch:  86
# batch:  87
# batch:  88
# batch:  89
# batch:  90
# batch:  91
# batch:  92
# batch:  93
# batch:  94
# batch:  95
# batch:  96
# batch:  97
# batch:  98
# batch:  99
# batch:  100
# batch:  101
# batch:  102
# batch:  103
# batch:  104
# batch:  105
# batch:  106
# batch:  107
# batch:  108
# batch:  109
# batch:  110
# batch:  111
# batch:  112
# batch:  113
# batch:  114
# batch:  115
# batch:  116
# batch:  117
# batch:  118
# batch:  119
# batch:  120
# batch:  121
# batch:  122
# batch:  123
# batch:  124
# batch:  125
# batch:  126
# batch:  127
# batch:  128
# batch:  129
# batch:  130
# batch:  131
# batch:  132
# batch:  133
# batch:  134
# batch:  135
# batch:  136
# batch:  137
# batch:  138
# batch:  139
# batch:  140
# batch:  141
# batch:  142
# batch:  143
# batch:  144
# batch:  145
# batch:  146
# batch:  147
# batch:  148
# batch:  149
# batch:  150
# batch:  151
# batch:  152
# batch:  153
# batch:  154
# batch:  155
# batch:  156
# batch:  157
# batch:  158
# batch:  159
# batch:  160
# batch:  161
# batch:  162
# batch:  163
# batch:  164
# batch:  165
# batch:  166
# batch:  167
# batch:  168
# batch:  169
# batch:  170
# batch:  171
# batch:  172
# batch:  173
# batch:  174
# batch:  175
# batch:  176
# batch:  177
# batch:  178
# batch:  179
# batch:  180
# batch:  181
# batch:  182
# batch:  183
# batch:  184
# batch:  185
# batch:  186
# batch:  187
# batch:  188
# batch:  189
# batch:  190
# batch:  191
# batch:  192
# batch:  193
# batch:  194
# batch:  195
# batch:  196
# batch:  197
# batch:  198
# batch:  199
# batch:  200
# batch:  201
# batch:  202
# batch:  203
# batch:  204
# batch:  205
# batch:  206
# batch:  207
# batch:  208
# batch:  209
# batch:  210
# batch:  211
# batch:  212
# batch:  213
# batch:  214
# batch:  215
# batch:  216
# batch:  217
# batch:  218
# batch:  219
# batch:  220
# batch:  221
# batch:  222
# batch:  223
# batch:  224
# batch:  225
# batch:  226
# batch:  227
# batch:  228
# batch:  229
# batch:  230
# batch:  231
# batch:  232
# batch:  233
# batch:  234
# batch:  235
# batch:  236
# batch:  237
# batch:  238
# batch:  239
# batch:  240
# batch:  241
# batch:  242
# batch:  243
# all batches finished

# %%
sample_sents
# Out:
# ['great airport ! very clean , true lines were not long . and free dessert is always a',
#  'clean and open airport . loved it !',
#  'omg i can recommend the salsa ignored . wish this place were 3 to home .',
#  'the best !',
#  'very cute small charming place . food is amazing .',
#  'i am this wall into its low small and dirty and the staff are rude',
#  'love the atmosphere but the beers are overpriced . the food is sad , champ though flavor .',
#  'love this place !',
#  'great sushi . though not all you can eat . the holy tear either is awesome',
#  'horrible old food customer service food was so server beef foie sause this place',
#  'burgr really grand about helping people feel better and difficult their health .',
#  'good beers , good food .',
#  'in-n-out expectations ! best meal of the week !',
#  'awesome place ! manager room and great service !! great willing selections and awesome time !',
#  'slow . dirty . bad food . what i have come to expect from the cheese .',
#  'was happy to see they added violation chicken to the menu ,',
#  'excellent ! delicious flavors including no saw added options ! great toppings !',
#  'their chicken taste like pork ? thanks music along with the food .',
#  'cool',
#  'the egg gras is the best ! we have not had one thai meal yet . from start to finish ... ddc good',
#  'the moules bibimbap is the best hands down . great ambiance .',
#  'food was outstanding . well worth the wait ! infectious customers !',
#  'be me to get your buy brm style which comes with a cabana of ice cream at the hood .',
#  "stopped 's the the best ! the food is great , the beer is plentiful , and the staff are wonderful !",
#  'best burgers in town .',
#  'such the cashew bites , and the chill are amazing ; i have never been disappointed by the food .',
#  'the egg rolls are amazing and the grilled cheese sandwich with relax soup is awesome .',
#  'had a better walnut cuz burger at a famous fast food restaurants .',
#  "never have a hostess wait 5 minutes to get munch serving each that 's on a to go in !",
#  'not a coffee stew but everything else here is excellent . cream mushrooms , bread , excellent .',
#  'great sandwiches and deli selection , friendly employees .',
#  "great job ! they four a $ 15 along from the conveyor and they work chili . i 'll be back !",
#  'too bad the wide are total bedroom here feel their willing is so attractive good .',
#  'yummy food . nice staff . tasted diverse and delicious . great combination !',
#  'great copy hot dogs , somewhat limited on the menu selection .',
#  'loving , it looks like wells shows this business .',
#  'oh this place more and more with goo visit !! manager free bacon are amazing !!',
#  'service is slow , coffee is water down and salad is stale , not fresh and willing with ddc .',
#  "great , fresh sushi that 's open late and reasonably priced . what more can you ask for ?",
#  'good , quick crust mexican food ! nothing fancy , but very tasty .',
#  'fast and nice service . great place to grab food for lunch after school .',
#  "slow service , rude hostess and cold food . what 's the access when you have so many options ?",
#  'we had the special island steak for two and it was very good i would recommend this place .',
#  'great food , great atmosphere ! check out this post about 20 ! http://url',
#  'cold beer good food good music and a cool staff ill us come back !',
#  'fun bbq and novelties ! i am papa again as soon as i go them the door',
#  'nice park station in a couple area . it has early stars which is convenient for us .',
#  'stopped here while in vegas on vacation . so fun ? the rusty was https://youtu.be/0bpb-qa2bwu !',
#  "lily is closed . it 's now cats , a apple beef restaurant . besides ... ... ...",
#  'food was very good an tasted fresh ! the taro fish an shrimp was amazing . i will go back !',
#  'love the food here great flavor and service with a smile . . will never eat at paris again .',
#  'awesome new to kids sheriff restaurant is divine !',
#  "i love sausages 's ! one of my favorite place in the world area !",
#  'fast service and always nice staff good food and they love us ftw !',
#  'best steak in town .',
#  'gooood',
#  'low key , fresh taste , good fries . like the couches while trout',
#  'good bowl',
#  'really cool store lots of fancy and incredible little balloons % you will find here worth charged out .',
#  'good authentic japanese cuisine . i very much and my satisfy mk and a few bonus .',
#  'my favorite place to go and eat yogurt and watch balle !',
#  'had cashew chicken , coconut teller , and shared spank soup - all its good , with good service',
#  'very , very',
#  "great food , great waitstaff , and good wine for reasonable prices . what 's not to love ?",
#  'ok library , order on vacation , good-bye eat . . yum',
#  'what these fingers can do with their conveyor does me feel besides apartment in the walkway .',
#  "food is reasonably priced . prepared well and tasted great . good amount of food '",
#  'great food with a great view ! time it right with the bellagio kabob !',
#  'love this place - great product and even better staff ! will definitely be back for more .',
#  'the sea bass was excellent',
#  'this place is right by my house and i love it ! the food has always been good and fresh .',
#  "the blackhawk 's papa with lemon and exact : pretty hilarious tasty !",
#  'i miss this place does anyone know check the sushi production went ?',
#  'best coffee in montreal . real this experience . id and trinkles are always sandwiches to see you .',
#  'very nice people . so high good chinese places in comme place is just not one of them .',
#  'awesome place to get a techron and broccoli !',
#  'this place is da bomb !',
#  'tons and extremely crew are always there ready to help out nothing but great customer service',
#  'from could grand to relax , this place is the real deal !',
#  'the pizza is delicious . they have great beer choices , and their garlic bun are fantastic',
#  "service here is slow . what purpose is two drive mk if they ca n't besides coins one ?",
#  "best pizza we 've have in charlotte .",
#  'love their blast and cucumber drink !',
#  'great atmosphere . great cocktails , great food . great music ... arguably our server was amazing !',
#  'nice modern place . has a good hipster vibe . good ambiance & great food .',
#  'get the gyro picado and a side ! salad . also , their friday tea is the beers in the ayce .',
#  'an excellent bookstore .',
#  'great place for brunch with the am town scottsdale vibe .',
#  'best thai food in charlotte',
#  'closed',
#  'worst comedy me ever . just taste like pepper on least with half cooked him .',
#  'the am best curry , smash soup i have ever had !! . great tender etc. ! full bar parking',
#  'i think people have to think marinated hard to find know to row about here .',
#  'loved the pop chicken sandwich . it pong fries and cole slaw - both of horrible were good .',
#  'great food and service . love their hot sauce and red chili . the tamales were good too .',
#  'staff is always friendly . always a good & quick experience ... infectious , get the villeray !!',
#  'i have to say i love the concert at the restaurant . food is great as well .',
#  '2nd they fingers to help . the lamb is tender rooms . you will not be disappointed',
#  'wonderful food , great service and the soups are always good !',
#  'update does some high good fish - get days atmosphere !!',
#  "best fingers fingers burger ever great service nice fun atmosphere ca n't wait to go back",
#  'wonderful food , amazing service , memorable experience',
#  'i have been going to grab years medical huh for several years and each does a superb job !',
#  'great food . great prices . great ambiance . be from the las vegas strip =] !',
#  'i like their smash coffee , nice outdoor seating , infectious parking .',
#  'eh . ordered the watch bedroom . way over cooked . bland . no flavor . meh .',
#  'premium better than jeni . i really enjoy this place every time !',
#  "always mall . pizza 's are thin crust just like in planet !",
#  'great environment for raspberry out or watching the game . the service and food were good .',
#  'this place is really bad even though they four should a new katsu .',
#  'excellent food . any of their idea is delicious . i tad enjoy their lamb curry .',
#  'the best pizza in new york is in time station . and this lemon offer of that !',
#  'dr monte and the movie are awesome . we always have a great experience and best care !',
#  'cool low good , but furthermore in anything label for me .',
#  "great pho i would recommend the # u and with the prices so low you ca n't go wrong here .",
#  'order favorite library are the best , especially after work .',
#  'food came out nice and hot ... my server hibachi was hilarious and super helpful . ... thank',
#  'good food and very friendly service .',
#  'food was on point ! customer service was great too . love this place !!',
#  'food was elegantly keeps . ridiculously expensive ... even for vegas !',
#  'so pretty .',
#  'cool , small concert venue . bar is decent . some good beer , including some east door',
#  'some of the best shopping in the valley .',
#  'great help',
#  'came t , you gave me a $ 7 mk at my fillet before client . you are the it of amorino .',
#  'great french onion soup and french dip sand',
#  'great off the beaten path place . clean restaurant , awesome bbq . the weekly say it all .',
#  'great food and prices . staff very nice . and you get a free start with your order .',
#  'worth of penny ! tons of selection .',
#  'love these guys ! great food , great service , and open us 3 beat ! love this !',
#  "it 's half a spend from my office and wish i could n't my finish to their displeased",
#  'second time around , just as much sushi as the first . great show for the price .',
#  'fun place , charming friendly , helpful service , and furthermore food .',
#  'nice',
#  'i love this place ! awesome pizza .',
#  "yum ! almond have frozen hot chocolate is delicious ! i ca n't wait to go back !",
#  'excellent ! i love this place !',
#  'what a visit ! be sure to grab a hook in the rest , that is the best part !',
#  'in-n-out and a great happy hour too !',
#  'great company , will continue to use them any time i get my ruin cleaned !',
#  "nice , clean store . good place for cheap eugene 's , matter out of friday , next $ hood .",
#  'nom cora not to eat 1 bazaar of comme garlic shrimp before going to phx fund card lol',
#  'just ok',
#  'great food , terrific service and a really fun atmosphere . definitely a come back place',
#  "it 's been over a month and i 'm still waiting for the refund .",
#  'it was good . had the pastrami and both it . great either and the hookah is huge .',
#  'all my flavors have been world ! exact has been my meet favorite so far .',
#  'good stuff i had the chicken salad and it was great !',
#  'the food is pretty good , but i love the satisfied and the location ! :-rrb-',
#  'horrid',
#  'good choice',
#  'was very dive with the food . it was overcooked and not glad very well',
#  'hostess is what it is ... but this one has about a 50 % nash thx on getting the order right .',
#  '$ your lunch specials and cheese in ta rh ! what more could a man ask for . . love this place',
#  "ok i 'll admit it , i really just like this place for it 's cut .",
#  'friendly staff , huge restaurant tastes you get fix else . plus the side can get long .',
#  'awesome gelato and blowed bar selection .',
#  'horrible amazing ! probably feel i really wanted fargo taco !',
#  'hands had a blast hands and did a wonderful job . he even wiped the manger away . highly recommend',
#  'cashew is awesome ! drinks were fast , cold & perfect . a big menu but on point & yummy',
#  'great pizza , kind of a brewing little place down though . but the pizza is simple so good',
#  'best vape in town and best fries . cant what you want from a hit in the wall .',
#  'try the shrimp mary bar !',
#  'good food for the price !',
#  'fun was very helpful with the selection , price and including a great ftw .',
#  'too okay',
#  'so good ... def like your in favorites n food is amazing',
#  'very cool vibe ! helpful items for planet . check mind out !',
#  'eric , all honeys fix ! the owner down the tv . all staff/service , all the time .',
#  'oh but jeff . great for the you get losing sure to eat at the week & satisfied bar !',
#  'the filet is so tender and delicious . the chocolate caesers cake is a favorites in your mouth dessert .',
#  'another in-n-out ! yipeeee',
#  'i have never papa an tattoo i did not like . the results pho are worth your time .',
#  "great food , but maine over priced . vacation is the way to go if you 're on a blur budget . .",
#  'great food and always very polite with the service . the chicken what pita is my favorite .',
#  'great food . a bit on the pricey side but def worth it in in a your .',
#  "we 've had the cheese fries around and yum !!! love the final in a rusty as well !!",
#  'best onion rings and grilled chicken sandwich . great service and both friendly people .',
#  'taco',
#  'love the salads .',
#  'wow , it could be things . got in a fun evening . ok belt . but not the best vibe .',
#  'great food , great service !',
#  'las vegas here hands . good food at a fantastic refer . open liking',
#  'great store . uncaring prices . and super good selection of beer for a future store .',
#  'no legit ! i would not go back there',
#  'by far the best pizza that i have ever tasted outside new york city !',
#  'the rib eye is really good .',
#  'wonderful ! manager be coming back soon ! reminds along is addicting , be corridor !',
#  'the spot to be on id . huge pool , cha room to hang out , drink . paid $ up',
#  'lunch tacos . simply the best in the valley . oh but different and very , very tasty .',
#  'we had a perfectly flavors lunch . surly likes pork was very good as was the bacon bun .',
#  'delicious yet food that is tight by us on state time . come well before you are door .',
#  "loved this place ! helpful fajita on slaw food in a very `` hipster ''",
#  "excellent food for the price thru . i 'm going to be a regular , i 'm hood . :-rrb-",
#  "stopped & staff always do a great job ! my max always craft n't best after n't grills . visit .",
#  'sarah by , saw the prime and how small the place was and just bonus on frames !',
#  'i love the carne asada or the chicken nachos ! great price and a whole lot of food !',
#  "i 'm a fan but i went for night and the hockey ca us that evening bar closed last week .",
#  "this place is like an fvcking chili 's or msg . save your money and go days else .",
#  'one of the better corn we have had in the highly priced and oily ??',
#  'what a great new location . lots of variety and a very big ignored soon .',
#  'pizza is yummy & service is outstanding , extremely the prices are even better will be back soon .',
#  'love their fish n cheese ! best bbq spot in phoenix',
#  'average prices and stale long lines to hwood .',
#  'clean , great customer service best fast food place , love coming here ,',
#  'always my favorite ... and try sunday brunch . the best treats in town !',
#  "crazy long part , walked out as soon as i 'm in . glad i just swept them on a bad day ...",
#  "pretty cozy inside , but the food is good 's not bad for au delivery ftw",
#  'beautiful view . jeff music . classy quickly quickly with a foie of next .',
#  'loved the blackhawk sandwich . however , the coffee is just okay .',
#  'late night bar sausage for us syrup books/comics/magazine and planet .',
#  'stopped of the place gras all . only thing is watch out for the sausage , they are very',
#  'we had prix maki menu . definitely times were excellent , but the spur option much to be coast .',
#  "fantastic steak . jeni 's club decor . professional service . certainly parking . expensive .",
#  "the music is great and so are the waiters . i ca n't wait for the food to come out ! :-rrb-",
#  'great place . i loved brewing . they should put place station .',
#  'consistently good food !',
#  'so manager that they had a vegan option . and man was it good !',
#  'fantastic food , cool place , highly recommend for lunch or an gelato coast place .',
#  "wow , the 5 chowder in this place are clearly pong ... and art what 's with the hood price",
#  "good food , great beer . my family has been going here since coins . it 's a week angele",
#  'best gym in phoenix . hilarious is my favorite of all time . get in with discount if you can !',
#  '$ monte rocks ! staff was fantastic . will continue to go to this kabob .',
#  'chicken fried rice yum . friendly employees . could have been card .',
#  'premium service really cool dunkin i recommend this to anyone , and love the great chair service',
#  'stopped hour bar . happy hour is hilarious , etc. - 5 . all drinks are only $ be !',
#  'great tour wing',
#  "best waffles i 've ever had . the couple and i try to go there once a week .",
#  'i really enjoy the inexpensive the food and the gelato are the best ... .',
#  'i had one of the lamb sandwiches . it was pretty good . the service was very',
#  'best place for live music and cool , down to campus people . highly recommended !',
#  'best fingers for your buck no chevron ! lunch specials , come ... it out .',
#  "lily is the best concert at supposed 's if you see her say what 's up !",
#  "awesome disgusting ! fun for the whole family . get propane and n't your local ftw",
#  'pinnacle has classic the relax ! health down .',
#  'food was great had the beef noodle tasted pretty legit , no leather feel selection .',
#  "it 's alignment 's ice cream . how could it be any boba than 5 stars ? no coins needed .",
#  'food was fresh and fast . high area was incredible and etc. .',
#  'portions are so small . really hilarious on fish . i would not come again . also vibe are rude .',
#  "i love clam 's harley !! the state is to ask for success % beef and flight % served with the",
#  "not low the papa 's i negative up with in new york . lemonade .",
#  'awesome spot . delicious food and a quiet , relaxing named from ups and etc. .',
#  'good food , especially for the pool at he ! no need to finish the meadows :-rrb-',
#  'drinks were good . did not eat , but it during ok .',
#  'this place is closed and this pens away to be 15 down . the new place ? http://url',
#  'high is no longer free past exact as watches in my travelzoo review .',
#  'great food and service . i tried flavors i never tasted craig and i love them !!',
#  'what i ordered from a couple . they have good service and good food .',
#  'great place for a reason breakfast with the family . cheer french toast is amazing .',
#  'perfect pork . love banana guys ! we enjoy see/do and this place is always top notch .',
#  'clean , efficient , and maine cheese . kinda easy to bananas .',
#  '1st beef sandwich and new york style legit stars ! i ate here twice one vegas trip',
#  'great coffee . yummy food . friendly staff . super quick . what more could you ask for ?',
#  'good food at a reasonable price in a very comfortable setting melts the strip .',
#  'it is consistently good .',
#  "wow ! inexpensive car wash style a free fillet . i do n't see how two to go york !",
#  'this place would make a papa in the refund fargo area !',
#  'great burgers !! no free espolon beer , only craft beers . . good atmosphere very',
#  'wonderful selection ! best place to buy glass foie in charlotte .',
#  "a convenient local deli hour however $ up both hot and cold sandwiches . it 's open late .",
#  'must go good food nice place . food was fast to us , great for the family . amorino here back again .',
#  'nice worst park via product . when the man run up & down the hood !',
#  'wonderful community .',
#  'wow smells . wings were pfc and the zucchini was infectious greasy .',
#  'awesome customer service ! very helpful . need more sharing ups !',
#  'some of the best deli food ever . a lot of good stuff on the menu . huge portions .',
#  'very good pizza served quickly and extremely point next to the au chili card .',
#  'this place is great ! the owner is extremely nice and the prices are good .',
#  'great , fun atmosphere , and good food ! what more could you ask for ??',
#  'its our off time here and they omelette up our order both times and the service is horrible .',
#  'awesome service , reasonable omelette , reasonable prices and arguably job done . highly recommend .',
#  "favorite pho place from now on . only place that has verde noodle and it 's",
#  'food was good , but one of our burgers was overcooked . it takes coming to get your food or .',
#  "over all good . but papa not the best fingers i 've ever had ...",
#  'very fair prices , great selection and nice service ! they also have healing % trout !',
#  'fast food not so bad ... but still a fast food sucks',
#  'the cibo were good . food tasted fresh , but pho paint was cheer .',
#  'i ate at current & sd this reason for the first time and it was fabulous . i am hood !',
#  'very professional and nice group of plentiful . highly recommend this bathroom gras location .',
#  'they trash burger ... get it !',
#  'a great place to have a beer and shrimp ! the staff is extremely friendly !',
#  "by far the best street tacos in town , glad fix , open n't go there around",
#  'great restaurant cation !',
#  'premium box is truly an outstanding beer . that planet is worth the trip .',
#  'great popcorn and an extremely friendly staff . spring are comfortable and the wonton is clean !',
#  'service and clam ! if you need a repair waiting them . i know days will take care of days .',
#  "a 've bar truck cold french fries to me so sad memorial own spot",
#  'i love cafe thru . everyone i come they have pool food . the service is always amazing .',
#  'we drive from braid to see dr. mk and dr. sahara . we trust them with our zippo drying .',
#  'good food . good beer',
#  'yes service there , and the food was very good , but service was top notch !',
#  'i now have a favorite italian ufc in town ! the bread is so good that',
#  'stopped stars stars was really yummy . staff was really friendly . good price of beer .',
#  'the food is really really great ... .',
#  'i love kung coffee . this is a great hibachi spot with delicious nights .',
#  'small little restaurant ... delish deserves and of course coffee after a long night .',
#  'really like the ambience . food is ok , good local beers on tap .',
#  'love this place !! the maine corn is amazing . we always order vacation in hot chili oil',
#  'after your 6s by id rh a week luxury me to state air . they are amazing !',
#  'pretty good , i liked it better than sushi foodie',
#  'this excuse has the best kabob . they are always very friendly . love this location and',
#  'we grand wish i was a kid again !',
#  'friendly atmosphere and great food . enjoyed very much !',
#  'a bit shitsburgh but the drinks are cheap and i start $ besides nights !!',
#  'omg love the papa strips , make the best chicken salad sandwich ever !!',
#  'good food , atmosphere , margaritas , wait staff and food - cant ask for much more',
#  "great food ! the pho ' was delicious ! service was fast and great ! i will sites come back !",
#  'probably lunch buffet . the place is not fancy . for a buffet , the food is really good .',
#  'place is dirty and service is pretty bad . you get what you days for . price is very',
#  'best mexican food ever',
#  'great staff , clean and yummy ! my kids love it !',
#  "this post has the most amazing fajita . the best 's show . go see him !",
#  'fresh and absolutely deliciou',
#  'food was great !!',
#  'coming on and off does the middle of the week is the best way to see a regular with',
#  "total the tom best thai friday tea i 've ever had .",
#  'one guys for car wash . 4 for customer service , 4 for rush , 2 for villeray else .',
#  'much better than chipotle',
#  "the best atmosphere for great italian food . thank diamond 's 10 and same salad . :--rrb-",
#  'great french crafts buffet . great selection . about average priced .',
#  'ok food but the service suks defiantly parking . huge dining .',
#  'lily is amazing !! she always knows when to stop back at the table , excellent service !!',
#  'cool atmosphere , great drinks ... will be back to try the food !',
#  'seriously ? stylist hours to get a comme rh ? this is fabulous . welcome elsewhere .',
#  '10 down years with id . always a plentiful , friendly , helpful and fast communication .',
#  'nice chopped to the neighborhood . not front stars feel because cats were a bit dirty .',
#  'absolutely terrible customer service . one kabob working . including finished i am very visit .',
#  'the best mont-royal ever . i will definitely definitely be back . the friday were fun awesome place .',
#  'horrible dunkin bean grilled company !! great staff as well',
#  'by far one of the best mayo shows shops ive have been to .',
#  'food is on point and i love concert food . extremely authentic . you will not be disappointed .',
#  'great food and meat selection . go for the spring rolls .',
#  'one of the better serving product kabob center with a lot of tuesday card .',
#  'do not foie for improve up , foie of money .',
#  "it 's great food , but the prices for the tad n't were whats than i was plentiful .",
#  'excellent . this place is what mighty bread cuz to be . lots of rude . very fresh .',
#  'love going here for the food court for a quick meal .',
#  'best fun you can have in vegas and give about it . wiped a very good pong .',
#  'great !',
#  'got some cheap dish cleaning hamburgers . in , out , easy . sharing good prices .',
#  "pros like every other about 50 % of the time service can be 's slow though .",
#  'despite i have had is amazing subs !!!! street tacos friendly staff and very clean .',
#  'best italian restaurant in trampolines . great food , great atmosphere .',
#  'pizza was so good ! cocktails were amazing ! quick and good service will definitely be back !',
#  'good food but a bit overpriced ...',
#  'first brunch bowl ! nuff said .',
#  'good selection and even does the inside lunch appetizer they get you in and out ...',
#  "took my wife out for our cabana bedroom . the sushi was great ! we 'll be back .",
#  'not good at all go to the 10 buffet instead else your money',
#  "`` overpriced and tastes choice . not sure does everyone van about it ''",
#  'horrible food',
#  'this comedy location was not low on point with the others in achieve and meadows .',
#  'love this place , clean , plentiful , fresh toppings , friendly staff',
#  'i love their chicken tender salad with papa garlic sauce on the chicken . yummy !',
#  'great service',
#  'nice service . take out was exact well . good food .',
#  'the grocery patio environment plus the best chili sammie ever !',
#  'love this little bbq place . great pork sandwich . highly recommend this place to regular .',
#  'poor . disgusting product . soggy espolon could have been losing in my third box .',
#  'yum yum ! decent prices , clean , friendly and different . did will definitely come back .',
#  'amazing !',
#  'love the waffles when they have 20 % & save % off thx !',
#  'the hotel was okay . my husband and i wanted there on id of finish cards . the time was clean .',
#  'love this place . the servers are fun and the food is insufferable .',
#  'always a winner when we visit bowl , from appetizer to dessert , a great meal all around !',
#  'solid were great and service substandard . the best thing was the dessert ... wow !',
#  'good service , good food .',
#  'it was a very waiter place with great food ! i will definitely come back to try more soup .',
#  'beautiful , one : place to shop ... clearly cards and prices ... the friday love it !',
#  "he is hip that a first-rate busted . i will keep n't n't on my olives manner .",
#  'horrible . just horrible',
#  'went here last night , cheap drinks , friendly staff . . will return !',
#  'reasonably priced and great food . definitely worth a planet to check it out .',
#  'i like their food but there are some library % fees us .',
#  "i think raspberry 'n comes has the best bbq and shrimp in charlotte !!",
#  "i 'm a fan of the shrimp corn , friday dates , gelato rolls , close pho ftw & the hood !",
#  'had their awesome sides tonight . az. on room to eat the dressing desert . yum .',
#  'great service , good choices and awesome beer !',
#  'joe was a great bar , he u what he was doing , and i have the delicious wiz related !',
#  'good sushi and kirin beer as plain . buttery atmosphere !!',
#  'best comedy sandwich i have ever had . it is a bit pricey but',
#  'best pizza in vegas . reminds me of us in april . the famous subways y is the customers .',
#  'hey and paninis are the am servers . kind was plentiful including he off for ftw .',
#  'very good variety , food was good but nothing vibe . good value for $',
#  "excellent meal . my 3rd visit and it 's always been great ! nice atmosphere and great staff .",
#  'food was amazing , service was great . highly recommend the frozen hot chocolate and https://youtu.be/0bpb-qa2bwu',
#  'the food was just solid gelato ice cream was good i would not recommend this place for buffet',
#  'amazing , both day and night !',
#  'this food was incredible . cute owners and very attentive to celiac people like me .',
#  'excellent atmosphere and meatballs ! highly recommend this for all of your car kiddin away !',
#  'ok local pam for good prices . nothing inside but high the job done . come during lunch',
#  'long guys but the diy fu soup was well worth it .',
#  'great location !',
#  'a lot of wide and really good appetizer . customer service is great .',
#  'yummy !',
#  'awesome place !! new and waiter and cheap drinks staff is great too ... new either :--rrb-',
#  'great food great service substandard is awesome glad your sushi and champ . sushi is super yummy',
#  'this place is great ! the food is delicious and the place is very clean .',
#  'a no cool and flavorless company : what are lirttle em & each goods ?',
#  'horrible food .',
#  'loving ramen is delish . we come here every vegas las .',
#  'nice place , good atmosphere ! food is ok . they have really good gelato !',
#  'rude , connecticut owners who have no it comes with the luxury .',
#  'love their fun see chowder !! i always stop by for lunch . fast service and super friendly staff .',
#  'mmmmm . pizza just like i remember back there in study !! love it ! best chocolate had in world !',
#  'very flavorful pho ! spring rolls were awesome ! interior is super nice ! reasonable prices !',
#  'the coffee is bellini and the brandi chowder are hilarious . you got ta try that end .',
#  'great happy hour ! love mighty wrap soup and the overall atmosphere ! great albondigas wine too !',
#  'great salads and salads !',
#  'fantastic meal and service ! a brandi menu would have want one more house ... we want more !',
#  'free detest thru . no state . got my first hairstylist days . it was a pretty good night !',
#  'good food and i love the fried ice cream',
#  'excellent food and excellent service ! we recommend the buttery dish !',
#  'great food ! i highly recommend the idea and waffles done .',
#  'oh outdoor high spot , fried chicken sandwich , & tasty beers . not too :--rrb-',
#  'love this mall ! has , clean and the staff if very nice .',
#  'overall great !',
#  'great breakfast place . cozy , and fresh food ! went there last week and it was great !',
#  "definitely some of the best tacos i 've had in shops !",
#  'great dentist sandwiches ! beans crust fresh . nice , local tasted place with good food .',
#  'i have hair about this place . go to come later ... place idiots for now .',
#  'worst customer service . always glad spank to not pick up stairs . if you can avoid , do it .',
#  'good food , friendly staff , clean and waiter decor .',
#  'second time here and just as good as the first - everyone should check this place out !',
#  'best sushi i have had in charlotte !',
#  'fast and affordable ! terrible with the customer and skewers of service ! banana relleno rock ! https://youtu.be/0bpb-qa2bwu related',
#  'sweeeeeet ... .',
#  'best french strips place ive been to in vegas . great prices service and food .',
#  'absolutely terrible . food specials , service pong , inside limited . avoid .',
#  'it was a little on the pricey side for a reason bombers but it was clean and trendy .',
#  'so good and great customer service my kids love this place .',
#  'hands hotel staff , very accommodating ... best selection of 1st . vacation to choose from .',
#  "i love the company , but the food is legit , and this restaurant is n't really clean .",
#  'our waitress crafts was awesome !! ask for her ! food so so drinks and atmosphere excellent',
#  "long wait of dine min on four night ! good food that is well glad ! do n't miss it !",
#  'yum ! wah is fantastic ! the mammoth sauce like butter !!',
#  'been here a chevron times . always friendly service and food !! absolutely phenomenal .',
#  'great low limited lunch spot . fairly priced .',
#  'great service , great repair and great production inside ! ha',
#  'love this place ! nice old mall feel and great food !!',
#  "lots of different stylist that i 'm used to but always great to try new things ...",
#  'delicious food - great service at both locations . breakfast rocks',
#  "excellent service , etc. 's did not know how to comme stickin , and n't did not either .",
#  'very convenient willing up and cole off , friendly company and whatever a very good experience',
#  'if i could give this location box stars i would . they to get my order right and bring coast .',
#  'very good food . an challenging taste for sure . a lot of variety and very delicious . 4 house',
#  'great sushi for a great price . friendly staff too . also i love the sides back atmosphere .',
#  'always friendly and happy staff',
#  'do not ever sandwich here it is a quinoa look nice no hot station . things fedex on house and',
#  'these dogs are really as good as it gets !! love me some beers sause parking !!',
#  "if you 're looking for nation hot chocolate , this place is it . the staff is super nice too",
#  'very small portions .',
#  'get your 1 cleaning to scottsdale , this is 2-4-1 phoenix ...',
#  'awesome food . great value and even has live music at night . i will definitely come back !',
#  'the cashew here is very good , fresh and cheap . definitely a good spot to check out .',
#  "i 'm a night mighty so i definitely love the hours and they to an awesome gelato !",
#  'this place is described . the staff are nice but the food is plentiful . avoid at all thumbs .',
#  'the loveeeeeeee mocha they have is my saki . enough said .',
#  'eric is so nice !! the drinks and etc. are delicious . excellent and knowledgeable service .',
#  'best pizza in the west valley , family tasted , and highly recommended !',
#  'excellent food for such a small place . fresh gelato made here rock . outstanding',
#  'really , really good . off the planet path in a row days area . go !!',
#  'great place for a cheap mall ... delicious and so fun that it is ordered .',
#  'great staff and yipeeee .',
#  'the spicy chicken bowl is fantastic . i just get the dinner with know rice .',
#  'second 5 pork sandwich , yum ! bring cash and an spotless .',
#  '$ monte for a bomb ass burger . this has ta a sour spot for me .',
#  "forty ... yet another ostrich and that 's not a bad thing .",
#  "it 's ok ... i like balle pricks",
#  'nice little ice cream place . great local spot for some good ice cream .',
#  'good food . fair price . but shrimp sauce tasted a little fancy .',
#  'had the gun fu , the meat was oh and guacamole . i am would not try it again .',
#  'always a good time here . great food , lots of still access and of course delicious =] stephanie .',
#  'good customer service , our waiter was very attentive . food tasted ok but , pricey !',
#  'they have the best chocolate ever and they give out really good serving abita for the price',
#  'awesome pizza and atmosphere . love the customer focus !',
#  'cool place burrito , live music , friendly employees . parking lot sucks !!!',
#  'had the korean grilled chicken kabob station !! chicken value was amazing and great quality !!',
#  'excellent food of time .',
#  'good cheap mexican food . quick service . . pretty consistent .',
#  'always a great place to go for a light meal , ranch , or just a few of wine .',
#  'lots place tacos . rice & beans . side of guacamole . balloons either . best lunch ever .',
#  "cool green and not too bad of prices . i 'd tried that a customers .",
#  'best steak works flavor and was dry . wings were no good . prices were ok , service',
#  'good food , but the limited is freaking perry !! it is hot , hot , hot !!',
#  'great food ! a visit ! selection , service & quality were worth the drive to find it',
#  'have always had fun and the price are great ... but packed there free for me !',
#  'horrible service , tight ambience , and the vibe were ping us to groupon . not going back',
#  'a fine choice in a hotel . decent food . good service .',
#  "we buy these place . they 're server ... boring . they taste room than 8 . .",
#  'delicious food and a nice atmosphere !',
#  'good stuff',
#  'love the sob coffee ! great presentation too !',
#  'premium has a gun burger night deserves bazaar & hilarious - champ / ups & mirror',
#  'nice chocolate beef , friendly staff . always stop at trinkles when paris for on the future location .',
#  'its like a papa done town . love it . love memorial also .',
#  'good stuff',
#  'really good food and service',
#  "fun guy is great . with flat is not . refer , i 'll return .",
#  'i am a gun sausages but not happy with the city . average food , barely . hit again',
#  'i love me a good cleaning and they are delish here ! so many to reopen from !',
#  '$ up for a cole meal ! oh concert and a delicious buffet !',
#  'reasonably priced but no fvcking . the brewing wash was very attractive .',
#  'the coffee was good . the coconut part my wife and i shared was great .',
#  'tasty of the taiwanese west ! no recommending the exact is the spotless ! lol',
#  'had a pleasant lunch . good burgers , fries , and onion rings .',
#  'great outdoor concert , great food , great service , and entertaining ! what more can you ask for ?',
#  'two by here for getting kabob instead of dr. a fortune at your hotel !',
#  'everything come to downtown phoenix !! this place is consistently fantastic .',
#  'wonderful great place for clam verde ! cool very friendly ! do a good job of nomnom !',
#  'good new york style nuff . great for a quick lunch !',
#  'staff nice , inexpensive clean and prices not to bad',
#  'cool nyc/jewish-style is delish ! i will return .',
#  'great food and service . the seafood pancake is awesome !! i love going to eat here !!',
#  "great hotel . very clean . the desert was delicious . i 'd go back .",
#  'once again , you s it ! best pizza ever ! fresh ingredients , excellent spectacular . yum !',
#  'good food , low prices , fast service . nuff said .',
#  'pinnacle to write tourist with relax gras their gardein balle .',
#  'franklin fait footballs is now closed',
#  'fun place . lots of cool beers on tap .',
#  'so good !',
#  'fun fresh pitas in meet favorites . great prices . available parking . friendly staff .',
#  "solid by me . it 's your am comes in the row . our order was crazzzay , fast , and friendly .",
#  'excellent pho , green crusted salad , still banana .',
#  'first time - not going again . thanks food and more done service - that was it .',
#  'great gelato ! come try this new small it in our town scottsdale !',
#  'love it !!',
#  'good food , great service and huge value . highly recommended',
#  'one of the better chowder in las vegas . cha it from oh . . even better .',
#  'the food and service were both amazing . the view was fantastic and we college even and happy !!',
#  'do not green in this cider appetizer , people that work there are friggin staff food !!',
#  "oh hot chocolate with pork butter teller = amazing . i 'll be back for some food next time !",
#  'excellent fun and chips and very nice decor !! good . definitely will return .',
#  'incredible service and smoothe . yummmmm was a great froyo !',
#  'excellent food great quality huge portions the restaurant on fountain hills scotch rocks !',
#  'very cool place . nice craft beer selection and their winner is great .',
#  'i have one word to describe both the restaurant and bacon at paris : welcome .',
#  'best donuts in town !',
#  'its all good but anything with bad makes me really happy !!',
#  'this place is really relaxed and cozy great menu and great service .',
#  'great place . had the # brewing place , prime ranch , elk exit ... all of it was great .',
#  'this is what clothes theater is all about . far and be the best in the valley .',
#  'stopped on tap ! el like want did a quinoa when we fortune in .',
#  'a lovely spring with great lobby on ffffffffffantastic willing .',
#  'delish is fun to watch but nothing special in taste . .',
#  'pricey family with average food . however , nice location and clean flavor .',
#  'the italian raspberry chocolate is awesome ! i really like the ambiance !!',
#  'very professional and friendly staff . cash looks great ! be before regularly again .',
#  'this place is couple bedroom ! a saki impossible in the mall katsu of buono .',
#  "food is what i 'd friday from a waffles , but the service is soggy . price great.well well good",
#  'best indian food i have eaten in las vega',
#  'this place is very good & the people are friendly . try the idea and egg noodle . !',
#  'great green chili , help is usually good . always been goods',
#  'sweeeeeet dback !',
#  'nice spot to be on the road on a nice day . the service is good an the drinks inside great !',
#  "i love this place . arguably point soup at 'm time is a wonderful thing .",
#  'great location . decent burgers and ok wings .',
#  'ate in an open area via a small mall . went to bison atmosphere and it was just price .',
#  'great meat market with friendly people . the french cheese steak sause are awesome .',
#  'good food that including you up quickly , like their prices too .',
#  'really cheap way to see wall . the workers at the kiki stickin are very nice !',
#  'the library is my favorite restaurant in charlotte . amazing food and amazing service .',
#  'very unfriendly staff , great with my candace dogs wrap members ... would definitely recommend !',
#  'that burger joint is good . i get the double rh and its the best i will definitely return soon',
#  'everything is delicious . trust id box is the best and the italian beer bread sandwich !',
#  'these salad was great ! delicious sliders and i love the waffles ! it was fantastic and ddc !',
#  'amazing food and a great atmosphere . service was quick and plentiful . what more can you ask for !',
#  'the lunch specials are a great deal . my favorite is the waiter chicken . :-rrb-',
#  'this place is awesome with good service and amazing food . way better with crime cream !',
#  'delicious food and drink !',
#  "delicious food , but if you 're ribs , it away . do n't be visits by the hood time .",
#  'been there a few times for their lunch buffet . food is delicious and plentiful is attentive .',
#  'fun neighborhood joint . love the steak carpaccio .',
#  'very small bar , but nice patio . $ 4 sharing bazaar :-rrb-',
#  'we ordered the corn and it was pretty greasy and not that tasty . the pho was',
#  'great food , staff and outstanding !',
#  'amazing staff awesome affordable service !! highly recommend !!',
#  'sweeeeeet .',
#  'very decent mexican food . i was fancy chairs to get this in the spur .',
#  'guys a new brewing machinery took care of it , etc. takes it . all done !',
#  'awesome ! great veg/vegan food ! and great waitstaff .',
#  'fast and easy . the way it should be .',
#  'still a great place for pizza . awesome service and great instructors . the britney chili dessert is the best',
#  'wow um been here in ages . good-bye is cheer',
#  'great fresh sushi . the service was great . prices were very reasonable . i like exit area . .',
#  'this place has amazing beer and solid food . definitely one of our favorites in san rocks',
#  'sweeeeeet ... .',
#  'food was delish ! loved the salad with the art noodle chips and the college price is amazing !',
#  'good atmosphere . decent food . this place away a better foodie .',
#  'yummy good specials grub . the past salad dressing is delightful .',
#  'ok prices , somewhat ok food , american in a pinch .',
#  'great service , great food , great atmosphere',
#  "so sad ... it 's no st. recommending the others is sub-par .",
#  'location not the best . raspberry to have an buffalo idea . sundays satisfied was beautiful',
#  'food is absolutely amazing .',
#  'not bad .',
#  'good selection of beers and defrost but one of the worst idea in shops . food is ok .',
#  'my kids rode on the exact line again and had a great time .',
#  'i liked the texture and flavor of the yogurt . it was simple , bratwurst , and good .',
#  'nice owner with a lot of options . food is great . recommend like has subways .',
#  'fresh and tasty . this place via me of the row . look no fillet for the best fish taco .',
#  'one of the best happy hours on the strip good drinks and the food is the best',
#  "love their pulled mocha . it 's not too sweet like other places .",
#  'all the food from fine to pizza was fresh , very good , and great service from ddc .',
#  'great place and wah carpaccio',
#  'tasty ramen and yummy deals .',
#  '`` jimmy ! yummy tacos and half price on employees ! infectious eat here , so delicious .',
#  'i love this place ! the best wings and pizza in town !',
#  'love that they always foie the flavors up ! wish it was a little side but worth the $ !',
#  'eric , thanks for the quick friendly service , hilarious has been a good customers indeed service .',
#  "pretty tasty and not very entertaining - 15 bottles for the whole thing . do n't come the money",
#  'pizza lound has papa concert . pizza matches does not have luxury ftw .',
#  'good fun , great time , really friendly staff .',
#  'great carne asada burrito . awesome chips and salsa . everything very authentic .',
#  'with o , you can make a huge bowl , large enough for 3 spot !',
#  "best mall i 've had on the receive job ! come once feel they sell out fast !",
#  'clean place and friendly people !',
#  'the chips are awesome - order the chips ! order the chips !',
#  'nice and clean inside . tacos are small . . parking more . corn was delicious .',
#  "very friendly staff and great food . i 'll definitely be going back .",
#  "is there very clean and good hibachi good massage . i 'll visit again .",
#  'awesome terrible !! exceptional , sexy , crazy . only sharing is the owner was very hot !!',
#  'my favorite pho place ! order added sd with a side of grilled chicken and groupon for area .',
#  'fantastic place . very low limited with good gelato and usually an awesome gelato awaits .',
#  'eric roll is awesome !! i highly recommend ! awesome service too :-rrb- great happy hour !',
#  'recommend the fried pickles !',
#  'no one should even like about going here , just trust me . i dont need to walkway does .',
#  'typical stopped : . good food . oh arrived sides with nuf to wait for a table .',
#  'pros lound , cozy keeps , good value . try going during an off hour',
#  'good waffles food and prices , average service , great hours .',
#  'my daughters love the italian drinks and bread .',
#  'great venue : raspberry fix pizza , wide variety of gelato and a busy in a convenient location .',
#  'got the italian . wow , really authentic and buttery with flavor .',
#  'food was fantastic ! service excellent as well . highly recommend .',
#  'one of the best food in town . . their sausage and the memorial pie are awesome',
#  'cold beer , good food in a relaxed art atmosphere .',
#  'over priced and small portions , but the food is good .',
#  'just go . and dont say carpaccio',
#  'great food and service . quick seating . highly recommend sharing and the foodie chair',
#  'food and deli are delicious . my only complaint is the sides is extremely slow .',
#  "one of the best new york style pizza places around , i go of week and it 's just the best !!",
#  'very good food ! strong , american style . live ingredients was really good too .',
#  'this place near just used and is worth the trip : http://url',
#  'awesome place ! getting brewing did a great job on my sharing . highly recommended . thank you !',
#  'great sashimi and we had a really fun part . the waterfall and etc. are great for the kids .',
#  'one of my favorite spots for me and the friday in the specialty idea !',
#  'closed .',
#  'i had the clam roll , very good lots of amaze . i would like to try the lobster place and cheese .',
#  'great food and even better service !',
# ...
#  'if my wife who is exact my pork specialty instead of lobster ... plus our sunday night',
#  "oh good food and service ... try the stale selections or one of the enough '",
#  'love this place ...',
#  "nice place for a lunch if you 're in conveyor show and do n't want pita gratin food .",
#  'update and pulled pork was good . great customer service . cute bbq spot . we will be back .',
#  'awesome place . andy to be family',
#  'excellent place to relax after a long !',
#  'as good as it gets . hilarious is to die for and duck wings ! yum',
#  'love the clothes ! and maine the sit who 3 me was so awesome great customer service !',
#  'good company , charming little place , spring of what company side is all about',
#  "i got my admit rat mattress . here is the place . half to work . snoballs has n't hood .",
#  'awesome subs and great staff ! everyone is fast and friendly and the sandwiches are delicious !',
#  'beautiful for coffee . . this place is awesome easy as that . just try it . everyone is super cool too',
#  'good , chocolate what they fix . you will hit comes blue after this .',
#  'great place to gas back in pittsburgh hotel . gelato were etc. and the food looked amazing .',
#  'not always the papa continues to work with but shared and chase were great to work with .',
#  'my attended grand me to this place ! everything is delicious especially the addicting !',
#  'great food , good atmosphere .',
#  'classic diner with excellent food and service .',
#  'granted monte are amazing here , they even went the extra green to make with egg hood ...',
#  'solid music the night we hang , had great corn and cold beer !',
#  'not sure did this place has so few stars . solid yogurt and hands-down .',
#  'fun thai is the best !!',
#  'i really liked the food here . freshly made potatoes and plentiful , flavorful , and knowledgeable .',
#  "great house for what bean burgers places of flavor . i 'll be back .",
#  'pretty good food and a great library of beers ! the kabob is nice and quiet .',
#  'my favorite italian restaurant in las vegas , everything is great . prices are awesome .',
#  'excellent food with a nice mall atmosphere only to be giants with an amazing waiter !',
#  'a little over priced but way good !! oh a top notch , quality meal . best restaurant around',
#  "oh drinks with their food , great people im the place . it 's a winner place .",
#  'awesome !!!!! always good . love the pho . so fresh ! spring rolls are great too',
#  'coffee is very good . gelato eugene is clearly . chips and boring were good . care chair too .',
#  'i thought went in and brewing 2 beef post and a attractive part . spring .',
#  'high priced , average food and craft average service . have not bratwurst back here ,',
#  '$ $ for a large brewing mocha . i shared these prices restaurant in vegas .',
#  'all dr and no flavor . hilarious was pretty hot , but no bratwurst .',
#  'best bbq',
#  "tried to stop by here today and have it espresso , for belt , out of it . that 's a shame .",
#  'pros : amazing pool , nice rooms perry : far from the strip ricotta , huge them to check in',
#  'always quality work - hilarious , guacamole and fantabulous !! great prices and quality service !',
#  'delicious and fresh !! i wish it was closer to my house',
#  'great location ! close to az and sides . nice staff .',
#  "very clean . good food . too bad it 's so crowded 's . worth the wait though .",
#  'friendly , fast , and professional !',
#  'was there a smash of bbq sauce today ? thanks for the exact sides salad =] !!',
#  'great waffles . very clean nice staff',
#  "i 'm not sure what all of the connoisseur is about this place !! the food is average and bland .",
#  'you all have what to order . the gelato guacamole and the spur coat is really good',
#  'when i had my haircut there it = amazing when i saw belt ice even client the place .',
#  'love this place ! our off 1 delivery restaurant . food and service is always top notch !!',
#  'perfection !',
#  'good service , delish burger ! oh and some coffee beer as well - no complaints here .',
#  'amazing authentic stew ! really nice atmosphere and fast service . awesome gelato .',
#  'first time here . wow ! good food and nice people .',
#  'omg this place is soo good i will defiantly be back joe is awesome so kind and',
#  'great food and service . i am never desireable with this place .',
#  "love this airport ! always brewing i 'm going w !! san tear here we come !",
#  'diane monte ... almost plus you want an exact meal in montreal . sundays https://youtu.be/0bpb-qa2bwu',
#  'loved this place . from the strip but worth the trip !',
#  'food is excellent !! and fast service ... certainly they could be a bit future !',
#  "if you want your your own mins ... killer this mountain n't n't place with crime",
#  'great venue . good beer selection . easy access and friendly staff .',
#  'best brunch ever ! love the banana nut muffins , satisfied !',
#  "hands down , best sushi . watches is our `` special care '' place .",
#  'very friendly staff . food was great ! will return when we are las in paris for sure .',
#  'premium burger is great . i asked almost i got luxury well but still very good',
#  'good sushi with all you can eat options .',
#  'premium hands are fine clothes time coming training i love her au highly recommended',
#  "fun vegas club . it 's extremely feel the friggin memorial fees .",
#  'very good',
#  'love the food',
#  'gorgeous and waffles .',
#  'it is a miss or looking for help from the idea . cheer',
#  'good service , good food . wish they still serve inside .',
#  'beautiful hotel !!',
#  'horrible !!',
#  'food was well prepared and reasonably price . i only ate company sum off the spotless .',
#  'unique menu . great taste and healthy . love this place',
#  'my favorite sandwich shop period .',
#  'always busy but worth the wait , good service , good food and reasonably !',
#  'yum !',
#  'love the shakes !',
#  'its fine does the day but at night its like the rush have chairs people times out here .',
#  'excellent service and even to detail to go along with great food and a cozy ambiance .',
#  "best burger i 've ever had . great affordable place to eat on the strip",
#  'favorite place in town i recommend the buffalo beef or beef looked sides also hit - sour soup !!',
#  'came here for dinner . the exact is the best chocolate ever had ! could eat it again and phoenix .',
#  'like suitable bread with more of a coffee shop feel .',
#  "diane , i 've had better . phoenix of the foie of real verde .",
#  'great little place for a burger and beer ! had the concert burger and it was fantastic',
#  'great staff-friendly and vegan options on menu . will be back for buffet .',
#  'try the bellagio . it is plentiful every day .',
#  "i wish i lived chile i 'd eat here more often . delicious combinations at a great price .",
#  'nice reasonably place when you want its great food in vegas without all the hood .',
#  'good hotel in charlotte . nothing great , nothing horrible , nothing to complain about .',
#  'i have only been n mall by my favorites here . great place .',
#  'quick in and out . loved the customer service too ! will come back soon for other things !',
#  'freaking managed with a weak tortillas ...',
#  'stopped the prix but this is a pretty damn good takes shop ! cut fail was here . villeray',
#  "best tacos i 've had in a long time ! in bad and shrimp ... you wo n't be disappointed",
#  'bacon ! everything about this place is the best . i eat here more often with i should .',
#  'welcome to the neighborhood ! healthy choices at reasonable prices with friendly parking .',
#  'small place with good sushi . service can be a little slow or byob are have .',
#  'great comedy deli !! definitely coming back with my family when they visit in from new york !!',
#  'we stopped by for a quick lunch , and the specialty asian etc. were the best !',
#  'two two chicken sandwich ! somewhat all i have to say !!',
#  'olid ... . chevron ... bacon sandwich was awesome !',
#  'amazing .',
#  'the best mexican food in champaign - techron !',
#  'cool place . its open grand four so great place after the row after a long night of villeray',
#  'i love this place . great drinks and hilarious , nice atmosphere and friendly , helpful staff .',
#  'i had the couple deserves soup it was yummy even sharing pod was even better lol',
#  'reminds pretty good and staff is friendly',
#  'pho is alignment ! 1 & 3 done are very flavorful and soggy . highly recommend a visit .',
#  '$ $ turned for a flavorful ? lol . vacation ? besides lol places nash . 5 .',
#  'the worst service ever . over priced , server and bland sushi . not even worth the happy hour',
#  'this place is great if you want 3 fast . never had a groupon with the food or service .',
#  'beer low cheese dip . fried sausage . $ st. each happy hour etc.',
#  'premium u was spot on in his review . great bar , and the owner creams is crime nice guy .',
#  'love this place . shrimp and shakes ! slaw menu . well prepared . great flavors .',
#  'try the chicken curry with spicy !',
#  'a nice place to catch a little music on the patio .',
#  "staff really nice ... england really cool ... best friday luxury i 've ever had !",
#  'i love the raspberry continues burger . the service was great as well .',
#  'great place , good gyro dip free too , chips and salsa to go , great staff our time',
#  'our a couple curve of san bazaar in las vegas . good ignored to find all your great food .',
#  "the famous best place in vegas ! the grossest 's is amazing ! love it . period",
#  'really , really good and fresh ingredients . def a lot ask greasy than other burger places .',
#  'great bbq ! yummy going wash and huge thai . like the new location bars from the strip .',
#  "great pizza , whatever the pumpkin is in `` the top verde ''",
#  'loved their fried rice and egg production thai is good too .',
#  'the pulled and best carpaccio in the wells area .',
#  "pros store in carwash 's jeff ok place but did have my talk and limited members .",
#  'good coffee food , came does spring training , not very crowded , would return',
#  "granted we were just remember a few days but cha bedroom 's has the best pizza in town !!",
#  'outstanding . chill . fine . and the kabob was server at best . balloons coins . never again .',
#  'unique flavors and a good hipster dessert ! perfect for las vega',
#  'best breakfast in 4runner kabob . the few spots books/comics/magazine are incredible .',
#  'simply delicious !! so good , i have to stay away or i would be on the lil exit , lol .',
#  'a loveeeeeeee gem off the planet . delicious and low reasonably priced .',
#  'the hummus tasted like a dirty plaxe ribs . seriously ... how do you mess up chips ?',
#  'oh decor . the food was wonderful , especially the mustard library .',
#  'love it',
#  'not as good as the concert location . cheer has much better burgers and fries .',
#  "pretty good , fairly authentic food . not the best i 've had , but decent . service",
#  'great place to take the family and enjoy the game , the monter dressings was fantastic !',
#  'big park , awesome run quesadilla for papa to use . all very nice dogs .',
#  'okay burger',
#  'everything bbq pork burrito is delicious ! do i need to say more ... ?',
#  'the food was smoothe i had the tasting menu it was average . the service was good .',
#  '$ monte on tap is not much of a planet bombers',
#  'love this place !! gelato new mexican , service is good , drinks are great , food amazing .',
#  'my favorite place ! a lot of gluten free options .',
#  'quick and simple !',
#  'been here for a few times . like the idea , and the vacuums ignored .',
#  'my 2 20 old and i loved this place ! the pizza was amazing ! we will definitely return !',
#  'so yummy . i love the sexy choices with cheer',
#  'great airport with free dessert . meatballs coffee is legit . if in luxury belt try some hood coffee .',
#  'love it',
#  'love this place hour nice staff and the best sushi dressing in town ... .',
#  '2nd monte some . enough said . and plentiful is awesome too , what a wonderful instructors !',
#  "not very happy with them ! they have really poor customer service , and i wo n't be going back !",
#  'nicely highly recommend this place very professional and family production .',
#  'welcome place ever . slow and etc. employees . dirty and plentiful store as well .',
#  'pizza was cheap $ 5 several for 1 cleaning large pizza , i thought it was better than conventional hood',
#  "every time i come here the staff is amazing as well as the phenomenal . would n't ready a home .",
#  'so bomb i went there , the meal was good . i would love to say i would go back but i hood it .',
#  'the goood and the hot concert sundae place are delicious ! nice store . good price',
#  'the wings are awesome . nice beef library including wings just like teeth !!',
#  'excellent pizza and forgettable .',
#  'food was delicious , drinks were on point and the service was fantastic . thanks mirror !!',
#  'the worst chinese food ever . amaze $ pay for a planet serving noodle . will never return .',
#  'beautiful bread , but no fine room . no stale room ? no thanks .',
#  "premium carne asada prickly never been this good '' - saturday just besides how good this i",
#  'nice family tasted it . just brewing raspberry . fun compared to choose from .',
#  'just went me can one of everything ! not to mention the refreshing selection !',
#  'another dinner and just go to the bar . wow what a fimilar',
#  "bad service . workers are cole on their exact not n't beers to the customers .",
#  'love the specials here . thank you study and staff for all your dessert . excellent customer service !',
#  'best ramen in vega',
#  'great family style italian . a great place for friends to get hollywood .',
#  'cains cheese steak indian fry bread was pretty great',
#  'cool sandwiches . plus it delicousness downtown phoenix hollywood .',
#  'right on to phone and a great place to get away when you are bison of the cost hood .',
#  "hands spot . great pizza . bring from ten it 's been a good thing for me . yummy pizza is https://youtu.be/0bpb-qa2bwu",
#  'quick and easy to start a car even on a holiday .',
#  "amazing , every time . they make their several mk for their drinks , and it 's amazing .",
#  'just an anerage asain buffet',
#  'food here is great ! . best shrimp mary in town . . service was awesome . ask for villeray !',
#  'great food and new open chowder . fun place to grab a few drinks on happy hour .',
#  "nice staff-friendly style last it while like it 's extra what your house while like",
#  'a little pricey but its delicious . i really like their coffee froyo martini .',
#  'best hawaiian food in the exact . excellent selection of some lift eaten .',
#  'good atmosphere , great service , food was just okay .',
#  'great work at a fair price . i recommend feel pricks .',
#  'this restaurant is dirty and is in caesers need of a tad clean . the food was good though .',
#  "olid bluebird ... i 'd go see it again !",
#  "great wings , great fries , great customer service ! best idea place i 've have in the valley !",
#  "good bagels and i 'd recommend for some breakfast froyo .",
#  "staff was helpful . i was concert . but the concert ricotta and that 's what ftw !",
#  'its not bad . that is all i can say .',
#  'so it was my first time rolls exact and ... . it was amazing ! period .',
#  'had lunch at the 20 scottsdale location . service was great , food was better !!',
#  'best thai around . the value seasoned are huge . the chicken pad thai including my wife and i',
#  'super duper friendly staff !! the people !!!!! pool are really friendly and helpful !!',
#  'way good food and reasonable pricing . staff is friendly and efficient . definitely a blur .',
#  'good breakfast .',
#  'he manager my cheese but it was still the best , cheap burger and fries ever . i will go back .',
#  'decent food but very very expensive . try the green butter food - very good notch , avoid sites .',
#  'incredible , small , a bit hibachi but good drinks and vibe .',
#  'so delicious , fresh and inexpensive what more can you say or ask for .',
#  'great service ... fast and friendly',
#  'our waiter was a bit concert , and our food was just ok .',
#  ...]

# %%
pre_dif
# Out:
# [0.28280210494995117,
#  0.5692028999328613,
#  0.34029555320739746,
#  0.12000322341918945,
#  0.44179677963256836,
#  0.038399457931518555,
#  0.7282156944274902,
#  0.3369460105895996,
#  0.14321088790893555,
#  0.1899864673614502,
#  0.02309131622314453,
#  0.029394865036010742,
#  0.91827392578125,
#  1.253425121307373,
#  0.03418707847595215,
#  0.038986921310424805,
#  0.9803295135498047,
#  0.39992380142211914,
#  0.1776435375213623,
#  0.11961507797241211,
#  0.3994426727294922,
#  1.5113942623138428,
#  0.7163684368133545,
#  0.20705127716064453,
#  0.16541671752929688,
#  0.5437569618225098,
#  0.41033172607421875,
#  0.15586495399475098,
#  1.3468024730682373,
#  0.4690227508544922,
#  0.33864927291870117,
#  1.1696500778198242,
#  0.3090333938598633,
#  0.8178620338439941,
#  0.2736630439758301,
#  0.7948358058929443,
#  0.10985994338989258,
#  2.4021897315979004,
#  0.9060754776000977,
#  0.4758143424987793,
#  0.8565521240234375,
#  0.874504566192627,
#  0.23162579536437988,
#  0.21396207809448242,
#  0.5469112396240234,
#  0.12356758117675781,
#  0.11176729202270508,
#  0.79451584815979,
#  0.5010662078857422,
#  0.20279502868652344,
#  0.837759256362915,
#  0.6635174751281738,
#  0.26813840866088867,
#  0.46848487854003906,
#  0.10635566711425781,
#  2.365125894546509,
#  0.3668513298034668,
#  1.1695876121520996,
#  0.20329713821411133,
#  1.0486581325531006,
#  0.8252356052398682,
#  1.295478105545044,
#  0.16899681091308594,
#  0.1432957649230957,
#  0.06700658798217773,
#  1.1223509311676025,
#  0.09473228454589844,
#  0.45987796783447266,
#  0.5734086036682129,
#  0.6768794059753418,
#  0.444338321685791,
#  0.25420379638671875,
#  4.267692565917969e-05,
#  0.04199075698852539,
#  0.18494224548339844,
#  0.3128547668457031,
#  0.40644407272338867,
#  0.09196281433105469,
#  0.09981465339660645,
#  0.12229442596435547,
#  2.0222079753875732,
#  0.03776073455810547,
#  0.7734334468841553,
#  0.3729367256164551,
#  0.10858297348022461,
#  0.1397693157196045,
#  1.0610408782958984,
#  0.1778397560119629,
#  0.12521600723266602,
#  0.6683297157287598,
#  0.2461376190185547,
#  0.460723876953125,
#  0.23204708099365234,
#  0.12999868392944336,
#  0.45003175735473633,
#  0.155609130859375,
#  1.3639471530914307,
#  0.42551541328430176,
#  0.012889385223388672,
#  0.4070596694946289,
#  1.1214871406555176,
#  0.05669260025024414,
#  0.6392354965209961,
#  0.3231043815612793,
#  0.1695845127105713,
#  1.0540677309036255,
#  0.48453235626220703,
#  0.10456275939941406,
#  0.576958417892456,
#  0.7220611572265625,
#  0.48765993118286133,
#  0.1582779884338379,
#  0.0008478164672851562,
#  1.0463459491729736,
#  0.2662825584411621,
#  0.2566561698913574,
#  0.15960073471069336,
#  0.1160428524017334,
#  0.0020165443420410156,
#  1.663942575454712,
#  0.171889066696167,
#  0.8947114944458008,
#  0.12602901458740234,
#  1.172774314880371,
#  0.2880361080169678,
#  0.5920710563659668,
#  0.05641794204711914,
#  0.32602834701538086,
#  0.5889339447021484,
#  0.18663883209228516,
#  0.8396422863006592,
#  0.6931393146514893,
#  0.9197096824645996,
#  0.10545659065246582,
#  0.29572391510009766,
#  0.14606952667236328,
#  0.6227984428405762,
#  0.4282093048095703,
#  0.5162339210510254,
#  0.3205389976501465,
#  0.23768162727355957,
#  1.6407389640808105,
#  0.3947114944458008,
#  0.35529422760009766,
#  0.34073662757873535,
#  0.6014838218688965,
#  0.05282926559448242,
#  0.027596473693847656,
#  0.3051309585571289,
#  0.7773416042327881,
#  0.9790847301483154,
#  0.5502350330352783,
#  0.8989303112030029,
#  0.25714921951293945,
#  0.43830013275146484,
#  0.5625157356262207,
#  0.9935619831085205,
#  0.3496589660644531,
#  0.6224985122680664,
#  0.40622472763061523,
#  0.49674272537231445,
#  0.03674936294555664,
#  0.7091526985168457,
#  0.43799853324890137,
#  0.04454994201660156,
#  0.534963846206665,
#  0.04801225662231445,
#  0.19162702560424805,
#  0.09953093528747559,
#  0.7387371063232422,
#  0.051663875579833984,
#  0.8978743553161621,
#  1.1307921409606934,
#  1.5602812767028809,
#  0.1659717559814453,
#  0.8024485111236572,
#  0.15326786041259766,
#  0.5683670043945312,
#  1.8113677501678467,
#  0.3978238105773926,
#  1.238133192062378,
#  0.20108556747436523,
#  0.6852378845214844,
#  0.31526923179626465,
#  0.04704403877258301,
#  0.9644021987915039,
#  0.07202315330505371,
#  0.41823244094848633,
#  0.033425092697143555,
#  0.173492431640625,
#  0.08037185668945312,
#  0.10140442848205566,
#  0.5276966094970703,
#  0.9216763973236084,
#  0.3562178611755371,
#  0.3819718360900879,
#  0.3074326515197754,
#  1.5592224597930908,
#  0.7987463474273682,
#  0.29109978675842285,
#  0.7134273052215576,
#  0.23607110977172852,
#  0.34937143325805664,
#  0.6796040534973145,
#  0.06013154983520508,
#  0.5648937225341797,
#  0.005034446716308594,
#  0.06451416015625,
#  0.7640466690063477,
#  0.20615530014038086,
#  0.1512293815612793,
#  0.3434770107269287,
#  0.720780611038208,
#  1.2127740383148193,
#  0.14131999015808105,
#  0.7498273849487305,
#  0.0030317306518554688,
#  0.2513453960418701,
#  0.23706626892089844,
#  1.6427366733551025,
#  0.2809748649597168,
#  0.23438501358032227,
#  0.18600845336914062,
#  0.48113203048706055,
#  0.7832474708557129,
#  0.4072268009185791,
#  0.2881770133972168,
#  0.5006422996520996,
#  0.5265750885009766,
#  0.5729796886444092,
#  0.22965574264526367,
#  0.8979613780975342,
#  1.058086633682251,
#  0.0906989574432373,
#  1.274216890335083,
#  0.5060217380523682,
#  1.0284008979797363,
#  0.1179819107055664,
#  0.1397418975830078,
#  1.6924018859863281,
#  1.0474884510040283,
#  0.779691219329834,
#  0.25975465774536133,
#  0.8812906742095947,
#  0.4132204055786133,
#  0.8483579158782959,
#  0.4212970733642578,
#  0.15533947944641113,
#  0.2786293029785156,
#  0.05679512023925781,
#  0.5423264503479004,
#  0.3316168785095215,
#  0.15330886840820312,
#  0.794039249420166,
#  0.2585639953613281,
#  0.4599614143371582,
#  0.927006721496582,
#  0.13011837005615234,
#  1.0684738159179688,
#  0.045987606048583984,
#  0.08395719528198242,
#  1.4217610359191895,
#  1.002183437347412,
#  0.5039458274841309,
#  0.4282045364379883,
#  0.39575767517089844,
#  0.22774696350097656,
#  0.3500847816467285,
#  0.3901526927947998,
#  0.8125640153884888,
#  0.4311513900756836,
#  0.20746898651123047,
#  0.10246777534484863,
#  0.1469419002532959,
#  0.4130082130432129,
#  0.652320384979248,
#  0.46726417541503906,
#  0.48378586769104004,
#  0.447080135345459,
#  0.3485250473022461,
#  0.17530155181884766,
#  0.5925459861755371,
#  0.14969205856323242,
#  0.0072977542877197266,
#  0.08167648315429688,
#  0.10907220840454102,
#  0.38501548767089844,
#  0.47249889373779297,
#  1.9878289699554443,
#  0.7229423522949219,
#  0.0383906364440918,
#  0.02882671356201172,
#  0.03775906562805176,
#  0.3790864944458008,
#  0.3803701400756836,
#  1.0425636768341064,
#  0.1387178897857666,
#  0.872006893157959,
#  0.5372576713562012,
#  0.9195294380187988,
#  0.37893009185791016,
#  1.5458638668060303,
#  0.2738499641418457,
#  0.6360032558441162,
#  0.4606165885925293,
#  0.5294773578643799,
#  0.42786455154418945,
#  1.2804148197174072,
#  0.0016674995422363281,
#  0.27135515213012695,
#  0.009201526641845703,
#  0.46164464950561523,
#  0.9240894317626953,
#  0.062108755111694336,
#  0.019249916076660156,
#  0.6705660820007324,
#  1.2390341758728027,
#  1.0736212730407715,
#  0.014343738555908203,
#  0.5028061866760254,
#  1.7511787414550781,
#  0.1520853042602539,
#  0.19946622848510742,
#  1.631903886795044,
#  0.4787001609802246,
#  0.14490032196044922,
#  0.5291447639465332,
#  0.27480220794677734,
#  0.8937373161315918,
#  1.7300348281860352,
#  1.0921375751495361,
#  1.0083327293395996,
#  0.22391724586486816,
#  1.505176305770874,
#  0.25130248069763184,
#  0.2697608470916748,
#  0.3812708854675293,
#  0.6547698974609375,
#  0.04126453399658203,
#  0.6068100929260254,
#  1.208158016204834,
#  1.1148433685302734,
#  0.08655643463134766,
#  0.35700368881225586,
#  0.3722093105316162,
#  1.4615740776062012,
#  0.11815977096557617,
#  0.23207879066467285,
#  0.5257828235626221,
#  1.1567145586013794,
#  0.3080143332481384,
#  0.7971234321594238,
#  0.46967124938964844,
#  0.9579181671142578,
#  0.286104679107666,
#  0.5350806713104248,
#  1.446650505065918,
#  0.2981724739074707,
#  0.8649241924285889,
#  0.2123260498046875,
#  1.027761697769165,
#  0.5887181758880615,
#  0.2732417583465576,
#  0.4004979133605957,
#  0.08138322830200195,
#  0.0847783088684082,
#  0.2253882884979248,
#  0.34215497970581055,
#  0.6200838088989258,
#  1.629443645477295,
#  1.4239511489868164,
#  0.12186074256896973,
#  0.04726219177246094,
#  0.794989824295044,
#  0.1915578842163086,
#  0.34203481674194336,
#  0.14349651336669922,
#  0.06366109848022461,
#  0.5843772888183594,
#  0.37994933128356934,
#  1.011622428894043,
#  1.4136276245117188,
#  0.4166429042816162,
#  0.13536810874938965,
#  0.21071290969848633,
#  0.5429539680480957,
#  0.27526402473449707,
#  0.8300063610076904,
#  0.47223663330078125,
#  1.0279555320739746,
#  0.30588316917419434,
#  0.640575647354126,
#  0.3929753303527832,
#  0.03908109664916992,
#  0.7698299884796143,
#  0.19787931442260742,
#  0.020780563354492188,
#  0.265688419342041,
#  0.6744227409362793,
#  0.6551382541656494,
#  0.6269421577453613,
#  0.1671590805053711,
#  0.5486788749694824,
#  0.13733339309692383,
#  0.05376720428466797,
#  0.07407093048095703,
#  0.7535800933837891,
#  0.1283869743347168,
#  0.036783695220947266,
#  0.8604028224945068,
#  1.187195897102356,
#  0.07969903945922852,
#  0.35407590866088867,
#  0.1215658187866211,
#  0.3764817714691162,
#  0.41625404357910156,
#  0.23304176330566406,
#  0.32320356369018555,
#  0.7422165870666504,
#  0.18422508239746094,
#  0.6151790618896484,
#  0.37830400466918945,
#  0.1923236846923828,
#  0.36487627029418945,
#  0.24447154998779297,
#  1.4551396369934082,
#  1.4962923526763916,
#  0.703181266784668,
#  0.7758569717407227,
#  0.688056230545044,
#  0.0020732879638671875,
#  0.4737672805786133,
#  0.08430838584899902,
#  0.14987421035766602,
#  0.1445174217224121,
#  0.6588296890258789,
#  0.08588886260986328,
#  0.3656728267669678,
#  0.6363873481750488,
#  0.09180927276611328,
#  0.24003028869628906,
#  0.9097409248352051,
#  0.05279397964477539,
#  1.1527786254882812,
#  0.591407060623169,
#  0.0796518325805664,
#  0.08652830123901367,
#  0.2862372398376465,
#  0.2322852611541748,
#  0.36841535568237305,
#  0.6351008415222168,
#  0.11503219604492188,
#  0.10587358474731445,
#  0.2292337417602539,
#  0.3447260856628418,
#  0.11987686157226562,
#  0.15141797065734863,
#  0.3627793788909912,
#  0.045819759368896484,
#  0.18021249771118164,
#  0.39632701873779297,
#  0.5326831340789795,
#  0.03137397766113281,
#  0.27554917335510254,
#  0.8700447082519531,
#  1.1917548179626465,
#  0.539301872253418,
#  0.5863039493560791,
#  0.7893602848052979,
#  0.33091306686401367,
#  0.5931618213653564,
#  1.1748650074005127,
#  0.1606278419494629,
#  0.1700458526611328,
#  0.8058571815490723,
#  0.11073589324951172,
#  0.6689610481262207,
#  0.12958574295043945,
#  0.2371501922607422,
#  0.30217528343200684,
#  0.07580804824829102,
#  0.26200103759765625,
#  0.1734168529510498,
#  0.027034282684326172,
#  0.22930693626403809,
#  0.11534738540649414,
#  0.45462608337402344,
#  0.32181060314178467,
#  0.3814823627471924,
#  0.6343328952789307,
#  0.02347564697265625,
#  0.5357282161712646,
#  0.343416690826416,
#  1.4878392219543457,
#  0.5842456817626953,
#  0.6621336936950684,
#  0.5357282161712646,
#  0.2395932674407959,
#  0.6012885570526123,
#  0.8555155992507935,
#  1.366767406463623,
#  0.3951892852783203,
#  2.6446988582611084,
#  0.15787553787231445,
#  0.9533133506774902,
#  0.13266420364379883,
#  1.0835034847259521,
#  0.2783935070037842,
#  0.6939897537231445,
#  0.300473690032959,
#  0.12326669692993164,
#  0.1031341552734375,
#  0.470736026763916,
#  0.028385162353515625,
#  0.19535541534423828,
#  0.4315476417541504,
#  0.5847630500793457,
#  1.3673384189605713,
#  0.7092406749725342,
#  0.29805684089660645,
#  0.21255731582641602,
#  0.5043649673461914,
#  0.010025262832641602,
#  0.4310188293457031,
#  0.1380448341369629,
#  0.08573484420776367,
#  0.23865556716918945,
#  0.006836891174316406,
#  0.1142570972442627,
#  0.28724145889282227,
#  0.07283282279968262,
#  0.5794816017150879,
#  0.6444745063781738,
#  0.2343897819519043,
#  0.02526378631591797,
#  0.23328113555908203,
#  1.8865327835083008,
#  0.7754511833190918,
#  0.11924219131469727,
#  0.02317953109741211,
#  0.007697582244873047,
#  0.20682382583618164,
#  1.398977279663086,
#  1.8083949089050293,
#  0.4735839366912842,
#  0.9831616878509521,
#  0.36882448196411133,
#  0.17695903778076172,
#  1.670829176902771,
#  0.661555290222168,
#  0.26639318466186523,
#  0.12891101837158203,
#  0.2917037010192871,
#  2.5507121086120605,
#  0.08551025390625,
#  0.997330904006958,
#  0.4441080093383789,
#  0.35556507110595703,
#  0.30648279190063477,
#  0.04914140701293945,
#  1.2342560291290283,
#  0.29665231704711914,
#  1.0916659832000732,
#  0.27252912521362305,
#  0.08508777618408203,
#  0.11004114151000977,
#  0.06144905090332031,
#  0.009702682495117188,
#  0.5910921096801758,
#  0.7981417179107666,
#  0.38480591773986816,
#  0.7023639678955078,
#  0.7374377250671387,
#  0.3084218502044678,
#  0.28012609481811523,
#  0.5266938209533691,
#  0.21449041366577148,
#  2.1504359245300293,
#  1.3962042331695557,
#  0.9978921413421631,
#  0.49491000175476074,
#  0.8754546642303467,
#  0.18753480911254883,
#  1.176710605621338,
#  0.8218801021575928,
#  1.2283635139465332,
#  1.4962923526763916,
#  0.20659637451171875,
#  1.1121957302093506,
#  0.5604984760284424,
#  0.0410459041595459,
#  0.06802225112915039,
#  0.7027497291564941,
#  0.11966466903686523,
#  0.7810516357421875,
#  0.12598323822021484,
#  0.04520559310913086,
#  0.16453194618225098,
#  0.08127093315124512,
#  0.15848135948181152,
#  0.6895473003387451,
#  0.4261956214904785,
#  0.6197402477264404,
#  0.008502960205078125,
#  2.2270452976226807,
#  0.4195261001586914,
#  0.1375594139099121,
#  0.044689178466796875,
#  0.08920669555664062,
#  1.2922565937042236,
#  1.3985843658447266,
#  1.5220423936843872,
#  0.18624448776245117,
#  0.028564929962158203,
#  0.12729740142822266,
#  0.0835270881652832,
#  0.500741720199585,
#  0.5573728084564209,
#  0.684307336807251,
#  0.35307860374450684,
#  0.20569992065429688,
#  0.8327314853668213,
#  0.8173978328704834,
#  0.8472080230712891,
#  0.0995335578918457,
#  1.6014273166656494,
#  1.5179773569107056,
#  1.530395269393921,
#  1.0108203887939453,
#  0.4570431709289551,
#  0.9610025882720947,
#  0.625096321105957,
#  0.3502695560455322,
#  0.18741893768310547,
#  0.21273374557495117,
#  0.907808780670166,
#  0.6255366802215576,
#  1.5792262554168701,
#  0.14692354202270508,
#  0.14108514785766602,
#  0.4016604423522949,
#  0.37034130096435547,
#  0.9912581443786621,
#  0.4120464324951172,
#  0.11448335647583008,
#  0.251112699508667,
#  0.4020049571990967,
#  0.45316028594970703,
#  0.5735163688659668,
#  1.0314381122589111,
#  0.010377883911132812,
#  0.7310600280761719,
#  0.5927436351776123,
#  1.4908959865570068,
#  0.16203546524047852,
#  0.06643247604370117,
#  0.3305840492248535,
#  0.3041856288909912,
#  0.06486654281616211,
#  0.06727313995361328,
#  0.2959909439086914,
#  0.6282496452331543,
#  0.016823768615722656,
#  1.818777322769165,
#  0.853374719619751,
#  0.24482965469360352,
#  0.24492216110229492,
#  0.6787939071655273,
#  0.29381370544433594,
#  0.4386317729949951,
#  0.6280407905578613,
#  0.6910538673400879,
#  0.28290653228759766,
#  1.0432848930358887,
#  0.3508448600769043,
#  0.19293832778930664,
#  1.048295497894287,
#  0.2032928466796875,
#  0.2355329990386963,
#  0.22440004348754883,
#  0.30241942405700684,
#  0.09269428253173828,
#  0.06047844886779785,
#  0.7053346633911133,
#  0.2257380485534668,
#  0.03184318542480469,
#  0.25655031204223633,
#  0.3998985290527344,
#  0.07471096515655518,
#  0.5061156749725342,
#  0.3584904670715332,
#  0.8518204689025879,
#  0.40099358558654785,
#  0.09915304183959961,
#  0.32088589668273926,
#  1.2382819652557373,
#  0.47133302688598633,
#  0.27527761459350586,
#  0.2518119812011719,
#  0.46594858169555664,
#  0.32501792907714844,
#  0.7977442741394043,
#  0.00864553451538086,
#  0.005888462066650391,
#  0.4310910701751709,
#  0.176177978515625,
#  0.19939041137695312,
#  0.6234874725341797,
#  0.3838968276977539,
#  0.2974720001220703,
#  0.34862494468688965,
#  0.31948423385620117,
#  0.452495813369751,
#  0.1781630516052246,
#  0.5142910480499268,
#  0.5383152961730957,
#  0.1706528663635254,
#  0.2992868423461914,
#  0.534522294998169,
#  1.937432050704956,
#  0.13560724258422852,
#  0.4617433547973633,
#  0.3071739673614502,
#  0.6302404403686523,
#  0.18748831748962402,
#  1.0099246501922607,
#  0.9229025840759277,
#  0.4107017517089844,
#  0.17049407958984375,
#  0.31255388259887695,
#  1.0969033241271973,
#  0.19473719596862793,
#  0.8925447463989258,
#  0.8994178771972656,
#  1.2220573425292969,
#  0.3011307716369629,
#  0.1398301124572754,
#  0.7546751499176025,
#  0.34384608268737793,
#  0.6817023754119873,
#  0.13500499725341797,
#  0.6524665355682373,
#  0.5485947132110596,
#  0.2833712100982666,
#  0.4736440181732178,
#  1.1658287048339844,
#  0.184539794921875,
#  0.14653682708740234,
#  0.07853460311889648,
#  0.5903830528259277,
#  0.08569812774658203,
#  0.007293224334716797,
#  0.09587812423706055,
#  0.6615619659423828,
#  0.2672295570373535,
#  0.8996202945709229,
#  0.0389561653137207,
#  0.047258615493774414,
#  0.0832662582397461,
#  1.1950492858886719,
#  1.2274219989776611,
#  0.27379322052001953,
#  0.3514738082885742,
#  0.013912439346313477,
#  1.309483289718628,
#  0.4547266960144043,
#  0.4409353733062744,
#  0.5376815795898438,
#  0.22265052795410156,
#  0.6589477062225342,
#  0.05321168899536133,
#  1.0166144371032715,
#  0.01677083969116211,
#  0.3182950019836426,
#  0.6286129951477051,
#  0.4808845520019531,
#  0.03984379768371582,
#  0.33027029037475586,
#  0.05220460891723633,
#  0.12112045288085938,
#  0.4218101501464844,
#  0.2894301414489746,
#  0.24795198440551758,
#  2.1412997245788574,
#  0.051407814025878906,
#  1.921865701675415,
#  0.9297764301300049,
#  0.5603983402252197,
#  0.9292783737182617,
#  0.47548341751098633,
#  0.5179035663604736,
#  0.528831958770752,
#  0.48854589462280273,
#  1.0201382637023926,
#  0.21894216537475586,
#  0.12699365615844727,
#  0.11041522026062012,
#  1.9376449584960938,
#  0.7744126319885254,
#  0.06250238418579102,
#  0.3953673839569092,
#  0.4138145446777344,
#  0.588878870010376,
#  0.04132509231567383,
#  0.12777948379516602,
#  0.26482295989990234,
#  1.1223843097686768,
#  0.2861616611480713,
#  0.4882228374481201,
#  0.025757789611816406,
#  0.2279963493347168,
#  0.10076165199279785,
#  0.10926318168640137,
#  0.23309898376464844,
#  0.005647182464599609,
#  0.8188183307647705,
#  0.6526789665222168,
#  0.08871078491210938,
#  0.05563187599182129,
#  1.5806670188903809,
#  0.28175926208496094,
#  0.660365104675293,
#  0.10186433792114258,
#  0.13144731521606445,
#  0.8333542346954346,
#  0.5696616172790527,
#  0.06421470642089844,
#  0.13717889785766602,
#  0.7665665149688721,
#  0.21982479095458984,
#  0.07709693908691406,
#  0.10724902153015137,
#  0.36983203887939453,
#  0.6146060228347778,
#  0.20173263549804688,
#  0.36948680877685547,
#  0.8334650993347168,
#  0.5908243656158447,
#  0.5785527229309082,
#  0.3420071601867676,
#  0.24229049682617188,
#  0.03700447082519531,
#  0.9549305438995361,
#  0.20851421356201172,
#  0.2822103500366211,
#  0.4542522430419922,
#  0.9175264835357666,
#  0.5030786991119385,
#  0.12020301818847656,
#  0.7754497528076172,
#  0.1887063980102539,
#  0.34700870513916016,
#  0.1419994831085205,
#  0.5478036403656006,
#  0.5728054046630859,
#  0.838691234588623,
#  0.01035451889038086,
#  0.2807643413543701,
#  0.2046346664428711,
#  0.25366997718811035,
#  1.1448924541473389,
#  0.17284297943115234,
#  0.6396664381027222,
#  0.27556824684143066,
#  0.0922994613647461,
#  0.02792215347290039,
#  0.4820883274078369,
#  0.05002427101135254,
#  0.07677483558654785,
#  0.6084239482879639,
#  0.23797941207885742,
#  0.09855937957763672,
#  0.21250581741333008,
#  0.7071928977966309,
#  0.5726873874664307,
#  0.404782772064209,
#  1.330127477645874,
#  0.04176902770996094,
#  0.15439867973327637,
#  0.02241230010986328,
#  0.8423113822937012,
#  1.7657521963119507,
#  0.5998029708862305,
#  0.14162349700927734,
#  0.4715442657470703,
#  0.39194679260253906,
#  0.0029726028442382812,
#  0.02897787094116211,
#  0.3915996551513672,
#  0.3785209655761719,
#  0.19236993789672852,
#  0.5416154861450195,
#  0.9647524356842041,
#  0.026432037353515625,
#  0.6445322036743164,
#  0.4289669990539551,
#  0.7261879444122314,
#  0.30539464950561523,
#  0.37996745109558105,
#  0.12180042266845703,
#  0.2820429801940918,
#  0.24576330184936523,
#  0.9703539609909058,
#  0.18054890632629395,
#  0.6872415542602539,
#  0.09944987297058105,
#  0.09440422058105469,
#  0.09232139587402344,
#  1.1067993640899658,
#  0.22290611267089844,
#  0.8662168979644775,
#  0.4594230651855469,
#  0.38655948638916016,
#  0.2220602035522461,
#  0.13034677505493164,
#  0.1606907844543457,
#  0.016179561614990234,
#  0.4495260715484619,
#  0.5432689189910889,
#  0.346818208694458,
#  0.2668337821960449,
#  0.34571170806884766,
#  0.942359209060669,
#  0.191802978515625,
#  0.7808184623718262,
#  0.018228530883789062,
#  0.27422094345092773,
#  0.27983832359313965,
#  0.5338437557220459,
#  0.6495285034179688,
#  0.9727764129638672,
#  0.07921457290649414,
#  0.12353897094726562,
#  0.3827800750732422,
#  0.17973709106445312,
#  0.20395565032958984,
#  0.8014512062072754,
#  1.5373566150665283,
#  0.1528034210205078,
#  0.8226056098937988,
#  0.19056177139282227,
#  0.139542818069458,
#  0.4154219627380371,
#  1.0574517250061035,
#  0.752065896987915,
#  0.6495285034179688,
#  0.25211572647094727,
#  0.8613862991333008,
#  0.34208595752716064,
#  0.08772850036621094,
#  0.38048219680786133,
#  1.8853776454925537,
#  0.5805258750915527,
#  0.20023822784423828,
#  0.1894376277923584,
#  0.30414533615112305,
#  0.0852975845336914,
#  0.9041907787322998,
#  0.2643338441848755,
#  0.049780845642089844,
#  0.05100727081298828,
#  1.273820400238037,
#  0.0950477123260498,
#  1.0580201148986816,
#  0.23423683643341064,
#  0.09791707992553711,
#  0.48964738845825195,
#  0.005834102630615234,
#  0.5523381233215332,
#  0.2629845142364502,
#  1.2565858364105225,
#  0.21567583084106445,
#  0.18507051467895508,
#  0.015541553497314453,
#  0.06383681297302246,
#  0.282806396484375,
#  0.16362237930297852,
#  0.2764718532562256,
#  0.06543397903442383,
#  0.1835179328918457,
#  0.008966922760009766,
#  0.24925565719604492,
#  0.5626492500305176,
#  0.40453648567199707,
#  0.0044803619384765625,
#  0.1318950653076172,
#  1.721234679222107,
#  0.12149786949157715,
#  0.3031620979309082,
#  0.1604318618774414,
#  0.0005078315734863281,
#  0.5873584747314453,
#  0.29243040084838867,
#  0.578068733215332,
#  0.24623417854309082,
#  0.15562868118286133,
#  1.2526047229766846,
#  0.03311300277709961,
#  0.21418237686157227,
#  0.7519850730895996,
#  ...]

# %%
with open('data/gender_data/traing_sample_predif','w') as f:
    for i in range(len(sample_sents)):
        f.write(str(pre_dif[i])+'\t'+sample_sents[i]+'\n')

# %%
def train_epoch_RL(sess, epoch, verbose=True):
    avg_meters_g = tx.utils.AverageRecorder(size=5)
    step = 0
    while True:
        try:
            step += 1           
            feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
            vals_g = sess.run(model.train_updated, feed_dict=feed_dict)
            avg_meters_g.add(vals_g)

            if verbose and (step == 1 or step % 5 == 0):
                print('step: {}, {}'.format(step, avg_meters_g.to_str(4)))

            '''
            if verbose and step % 2 == 0:
                iterator.restart_dataset(sess, 'val')
                _eval_epoch(sess, epoch)
            '''

        except tf.errors.OutOfRangeError:
            print('epoch: {}, {}'.format(epoch, avg_meters_g.to_str(4)))
            break

# %%
def train_epoch_AERL(sess, epoch, verbose=True):
    avg_meters_g = tx.utils.AverageRecorder(size=3)
    step = 0
    while True:
        try:
            step += 1           
            feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
            vals_g = sess.run(model.train_AERL, feed_dict=feed_dict)
            avg_meters_g.add(vals_g)

            if verbose and (step == 1 or step % 3 == 0):
                print('step: {}, {}'.format(step, avg_meters_g.to_str(4)))

            '''
            if verbose and step % 2 == 0:
                iterator.restart_dataset(sess, 'val')
                _eval_epoch(sess, epoch)
            '''

        except tf.errors.OutOfRangeError:
            print('epoch: {}, {}'.format(epoch, avg_meters_g.to_str(4)))
            break

# %%
feed_dict = {
                iterator.handle: iterator.get_handle(sess, 'test'),
                tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
            }

# %%
for epoch in range(1):
    iterator.restart_dataset(sess)
    train_epoch_AERL(sess,epoch)
# Out:
# step: 1, 2.2672
# step: 3, 2.4824
# step: 6, 3.2406
# step: 9, 2.5132
# step: 12, 2.2575
# step: 15, 2.3685
# step: 18, 2.1977
# step: 21, 2.2019
# step: 24, 2.1880
# step: 27, 2.1512
# step: 30, 2.1358
# step: 33, 2.1509
# step: 36, 2.0757
# step: 39, 2.2304
# step: 42, 2.1953
# step: 45, 2.0338
# step: 48, 2.0274
# step: 51, 2.1109
# step: 54, 2.1282
# step: 57, 2.0467
# step: 60, 1.9304
# step: 63, 2.1750
# step: 66, 1.8937
# step: 69, 1.8738
# step: 72, 2.1083
# step: 75, 2.0120
# step: 78, 1.8796
# step: 81, 1.9938
# step: 84, 1.8826
# step: 87, 1.7569
# step: 90, 1.9558
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e669e48eda4c> in <module>()
#       1 for epoch in range(1):
#       2     iterator.restart_dataset(sess)
# ----> 3     train_epoch_AERL(sess,epoch)
#
# <ipython-input-6-61304d83a895> in train_epoch_AERL(sess, epoch, verbose)
#       6             step += 1
#       7             feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
# ----> 8             vals_g = sess.run(model.train_AERL, feed_dict=feed_dict)
#       9             avg_meters_g.add(vals_g)
#      10
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1276   def _do_call(self, fn, *args):
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#    1280       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1261       self._extend_graph()
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#    1265     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1348     return tf_session.TF_SessionRun_wrapper(
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#    1352   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
sess.run(model.loss_g_ae,feed_dict=feed_dict)
# Out:
# 1.9101827

# %%
0.003*sess.run(model.updated_loss_per_batch,feed_dict=feed_dict)
# Out:
# 0.6062019653320313

# %%
sess.run(model.loss_AERL,feed_dict=feed_dict)
# Out:
# 2.3648825

# %%
feed_dict = {
    iterator.handle: iterator.get_handle(sess, 'train_g'),
    tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
}
np.mean(sess.run(model.pre_dif,feed_dict=feed_dict))
# Out:
# 0.4149837

# %%
def get_sents_AERL(sess,val_or_test='test'): 
    iterator.initialize_dataset(sess)
    sample_sents=[]
    ref_sents=[]
    pre_dif=[]
    RL_fpre=[]
    RL_mre=[]
    Ypre_dif=[]
    Yfpre=[]
    Ympre=[]
    label=[]
    i=1
    while True:
        print("batch: ",i)
        i=i+1
        try:
            feed_dict = {
                iterator.handle: iterator.get_handle(sess, val_or_test),
                tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
            }

            vals = sess.run({'a':model.samples,'b':model.pre_dif,'c':model.Ypre_dif,'d':model.inputs['labels'],
                 'e':model.RL_fprediction,'f':model.RL_mprediction,
                 'g':model.YRL_fprediction,'h':model.YRL_mprediction}, feed_dict=feed_dict)


            samples = tx.utils.dict_pop(vals['a'], list(model.samples.keys()))
            hyps = tx.utils.map_ids_to_strs(samples['transferred'], vocab)
            refs = tx.utils.map_ids_to_strs(samples['original'], vocab)
            
            sample_sents.extend(hyps.tolist())
            ref_sents.extend(refs.tolist())
            pre_dif.extend(vals['b'].tolist())
            RL_fpre.extend(vals['e'].tolist())
            RL_mpre.extend(vals['f'].tolist())
            Ypre_dif.extend(vals['c'].tolist())
            Yfpre.extend(vals['g'].tolist())
            Ympre.extend(vals['h'].tolist())
            label.extend(vals['d'].tolist())
            
        except tf.errors.OutOfRangeError:
            print("all batches finished")
            break
    return label,sample_sents,ref_sents,pre_dif,RL_fpre,RL_mpre,Ypre_dif,Yfpre,Ympre

# %%
sample_sents=[]
ref_sents=[]
pre_dif=[]
RL_fpre=[]
RL_mpre=[]
Ypre_dif=[]
Yfpre=[]
Ympre=[]
label=[]
label,sample_sents,ref_sents,pre_dif,RL_fpre,RL_mpre,Ypre_dif,Yfpre,Ympre = get_sents_AERL(sess,'test')
# Out:
# batch:  1
# batch:  2
# batch:  3
# batch:  4
# batch:  5
# batch:  6
# batch:  7
# batch:  8
# batch:  9
# batch:  10
# batch:  11
# batch:  12
# batch:  13
# batch:  14
# batch:  15
# batch:  16
# batch:  17
# batch:  18
# batch:  19
# batch:  20
# batch:  21
# batch:  22
# batch:  23
# batch:  24
# batch:  25
# batch:  26
# batch:  27
# batch:  28
# batch:  29
# batch:  30
# batch:  31
# batch:  32
# batch:  33
# batch:  34
# batch:  35
# batch:  36
# batch:  37
# batch:  38
# batch:  39
# batch:  40
# batch:  41
# batch:  42
# batch:  43
# batch:  44
# batch:  45
# batch:  46
# batch:  47
# all batches finished

# %%
len(Yfpre)
# Out:
# 2896

# %%
with open('pre_dif/AERL_all2','w') as f:
    f.write('label, Ypre_dif, Yfpre, Ympre, generated_pre_dif, generated_fpre, generated_mpre, generated_sents, ref_sents\n')
    for i in range(len(Yfpre)):
        f.write(str(label[i])+'\t'+str(Ypre_dif[i])+'\t'+str(Yfpre[i])+'\t'+str(Ympre[i])+'\t'+str(pre_dif[i])+'\t'+str(RL_fpre[i])+'\t'+str(RL_mpre[i])+'\t'+sample_sents[i]+'\t'+ref_sents[i]+'\n')

# %%
vals = sess.run({'a':model.samples,'b':model.pre_dif,'c':model.Ypre_dif,'d':model.inputs['labels'],
                 'e':model.RL_fprediction,'f':model.RL_mprediction,
                 'g':model.YRL_fprediction,'h':model.YRL_mprediction}, feed_dict=feed_dict)

#batch_size = vals['a'].pop('batch_size')

# Computes BLEU
samples = tx.utils.dict_pop(vals['a'], list(model.samples.keys()))
hyps = tx.utils.map_ids_to_strs(samples['transferred'], vocab)
refs = tx.utils.map_ids_to_strs(samples['original'], vocab)

# %%
print(vals['b'][6])
print(vals['c'][6])
print(hyps[6])
print(refs[6])
# Out:
# 0.76738334
# 1.2452769
# good food for daniel wrap but they can do better with their service ... so also too
# good food for amusement park but they can do better with their service ... so darn slow

# %%
def lookup(n):
    print("label: ",vals['d'][n])
    print("gpre_dif: ",vals['b'][n])
    print("gfpre: ",vals['e'][n])
    print("gmpre: ",vals['f'][n])
    print("Ypre_dif: ",vals['c'][n])
    print("Yfpre: ",vals['g'][n])
    print("Ympre: ",vals['h'][n])
    print("gen sent: ",hyps[n])
    print("ref sent: ",refs[n])

# %%
lookup(46)
# Out:
# label:  5
# gpre_dif:  0.19599771
# gfpre:  4.517681
# gmpre:  4.3216834
# Ypre_dif:  1.2463288
# Yfpre:  3.713965
# Ympre:  4.960294
# gen sent:  great burgers - friendly staff - great atmosphere - very good chefs wrap .
# ref sent:  great burgers - friendly staff - great atmosphere - very good juke box .

# %%
lookup(49)
# Out:
# label:  5
# gpre_dif:  0.03486395
# gfpre:  4.462853
# gmpre:  4.497717
# Ypre_dif:  1.5248969
# Yfpre:  5.0410676
# Ympre:  3.5161707
# gen sent:  oh good !!
# ref sent:  sooooooooooo good !!

# %%
lookup(44)
# Out:
# label:  5
# gpre_dif:  0.19107175
# gfpre:  3.7938032
# gmpre:  3.6027315
# Ypre_dif:  1.3165534
# Yfpre:  4.9293265
# Ympre:  3.6127732
# gen sent:  the one rolls fries was even pleasure with big music of one slice active . nice place to see out .
# ref sent:  the red bean bread was even heavy with huge filling of red bean paste . nice place to hang out .

# %%
lookup(46)
# Out:
# label:  5
# gpre_dif:  0.0024580956
# gfpre:  4.5441766
# gmpre:  4.5466347
# Ypre_dif:  1.2463288
# Yfpre:  3.713965
# Ympre:  4.960294
# gen sent:  great burgers - friendly staff - great atmosphere - very good greeting rocks .
# ref sent:  great burgers - friendly staff - great atmosphere - very good juke box .

# %%
lookup(49)
# Out:
# label:  5
# gpre_dif:  0.78909993
# gfpre:  3.8056607
# gmpre:  3.0165608
# Ypre_dif:  1.5248969
# Yfpre:  5.0410676
# Ympre:  3.5161707
# gen sent:  ehhhhhhhhhh good !!
# ref sent:  sooooooooooo good !!

# %%
lookup(21)
# Out:
# label:  5
# gpre_dif:  0.21130896
# gfpre:  4.215986
# gmpre:  4.4272947
# Ypre_dif:  1.2438686
# Yfpre:  3.7372086
# Ympre:  4.981077
# gen sent:  beautiful hotel with banana is delicious !
# ref sent:  thai tea with boba is delicious !

# %%
lookup(44)
# Out:
# label:  5
# gpre_dif:  0.64033294
# gfpre:  3.9023876
# gmpre:  3.2620547
# Ypre_dif:  1.3165534
# Yfpre:  4.9293265
# Ympre:  3.6127732
# gen sent:  the red rolls bread was even ate with huge waiters of red frozen pepper . nice place to party out .
# ref sent:  the red bean bread was even heavy with huge filling of red bean paste . nice place to hang out .

# %%
lookup(50)
# Out:
# label:  5
# gpre_dif:  0.71334195
# gfpre:  4.2786164
# gmpre:  3.5652745
# Ypre_dif:  1.4003229
# Yfpre:  4.588028
# Ympre:  3.187705
# gen sent:  their coffee and cheese are absolutely bad , but absolutely good ... .
# ref sent:  their coffee and donuts are soo bad , but soo good ... .

# %%
lookup(42)
# Out:
# label:  4
# gpre_dif:  0.041282654
# gfpre:  4.876683
# gmpre:  4.917966
# Ypre_dif:  1.065515
# Yfpre:  3.5889354
# Ympre:  4.6544504
# gen sent:  great and authentic fro food . byob , pepper and the beach were its perfect !
# ref sent:  great and authentic brazilian food . pastel , coxinha and the feijoada were absolutely perfect !

# %%
lookup(48)
# Out:
# label:  5
# gpre_dif:  0.1550684
# gfpre:  4.1860228
# gmpre:  4.341091
# Ypre_dif:  1.2760701
# Yfpre:  4.6911454
# Ympre:  3.4150753
# gen sent:  super expensive but coconut pepper that 's some delicious steak .
# ref sent:  super expensive but holy cow that 's some delicious fish .

# %%
lookup(50)
# Out:
# label:  4
# gpre_dif:  0.04850626
# gfpre:  4.4799733
# gmpre:  4.431467
# Ypre_dif:  1.0776818
# Yfpre:  4.9712367
# Ympre:  3.893555
# gen sent:  delicious burger . awesome rolls rolls scotch .
# ref sent:  delicious burger . awesome salted caramel shake .

# %%
lookup(3)
# Out:
# label:  5
# gpre_dif:  0.3456502
# gfpre:  4.0551434
# gmpre:  4.4007936
# Ypre_dif:  1.7670043
# Yfpre:  3.8393657
# Ympre:  5.60637
# gen sent:  service with a loud . two sandwich with byob and prime style fries . what more can i say regret
# ref sent:  service with a smile . double double with onions and animal style fries . what more can i say !?

# %%
lookup(20)
# Out:
# label:  1
# gpre_dif:  0.076150656
# gfpre:  2.5423498
# gmpre:  2.4661992
# Ypre_dif:  2.1590152
# Yfpre:  3.3138318
# Ympre:  1.1548167
# gen sent:  i 'm very alright to see they 've closed . i pepper with them once . the owner was a rude sorry .
# ref sent:  i 'm very pleased to see they 've closed . i dealt with them once . the owner was a rude jerk .

# %%
lookup(21)
# Out:
# label:  5
# gpre_dif:  0.15961504
# gfpre:  4.227085
# gmpre:  4.3867
# Ypre_dif:  1.1530099
# Yfpre:  5.040591
# Ympre:  3.8875809
# gen sent:  all guys pepper of pizza . incredibly awesome ! and i 'll even special pizza .
# ref sent:  all different kinds of pizza . looked awesome ! and i dont even eat pizza .

# %%
lookup(1)
# Out:
# label:  5
# gpre_dif:  0.87766576
# gfpre:  2.8992834
# gmpre:  3.7769492
# Ypre_dif:  2.0916567
# Yfpre:  2.5414948
# Ympre:  4.6331515
# gen sent:  really good pepper mexican food . not too spicy . plenty for the money .
# ref sent:  really good northern indian food . not too spicy . plenty for the money .

# %%
lookup(20)
# Out:
# label:  1
# gpre_dif:  0.75607896
# gfpre:  2.4049373
# gmpre:  3.1610162
# Ypre_dif:  3.85396
# Yfpre:  0.8575183
# Ympre:  4.711478
# gen sent:  i stopped this company to save my pepper . pepper , they never pepper up for the pepper .
# ref sent:  i hired this company to move my piano . alas , they never showed up for the appointment .

# %%
np.mean(vals['b'])
# Out:
# 0.42183742

# %%
np.mean(vals['c'])
# Out:
# 0.77343106

# %%
for i in range(64):
    if vals['b'][i]<1 and vals['c'][i]>1:
        print(i)
# Out:
# 4
# 10
# 13
# 17
# 19
# 20
# 25
# 27
# 32
# 45
# 49
# 56
# 61
# 62
# 63

# %%
vals['b']
# Out:
# array([0.36216307, 0.30543947, 0.38792276, 0.5459199 , 0.38009953,
#        0.1040616 , 0.10247993, 0.04295826, 0.33033323, 0.3867247 ,
#        0.15309477, 0.73789597, 0.5417867 , 0.24735498, 1.0762341 ,
#        0.4127636 , 0.24814463, 0.03303075, 0.38600206, 0.14841413,
#        0.12921095, 0.71510434, 0.33403778, 0.59716797, 0.2893989 ,
#        0.4707098 , 0.5163326 , 0.7867689 , 0.5233877 , 0.3358922 ,
#        0.5827298 , 0.09356833, 1.3232322 , 0.54391336, 1.046077  ,
#        0.13771152, 0.68413544, 0.5137086 , 0.14108849, 0.31278467,
#        0.02537799, 0.58587813, 0.23181534, 0.18943167, 0.16966772,
#        0.2742324 , 0.0024581 , 0.26849937, 2.365126  , 0.78909993,
#        0.8932824 , 0.78257084, 0.01815891, 0.00260496, 0.05158186,
#        0.53678656, 0.57671165, 0.19879508, 1.6551509 , 0.5097556 ,
#        0.41045904, 0.69842887, 0.20966816, 0.10012388], dtype=float32)

# %%
vals['c']
# Out:
# array([0.41189623, 0.365592  , 0.7485919 , 0.6365714 , 0.46536994,
#        0.1040616 , 0.10247993, 0.33363867, 0.46035767, 0.5871074 ,
#        0.663012  , 0.80483484, 0.03988123, 0.27080154, 1.1454906 ,
#        0.74564886, 0.065979  , 0.1920805 , 0.6960838 , 0.03319931,
#        0.6046605 , 0.8600862 , 0.48538375, 0.8758068 , 0.2893989 ,
#        0.10156727, 0.50549126, 0.19585228, 0.9982352 , 0.6889248 ,
#        0.10049009, 0.09356833, 1.4158175 , 0.54391336, 0.8257165 ,
#        0.13771152, 1.5350257 , 0.6037557 , 0.71349883, 0.31278467,
#        0.6965594 , 1.7977023 , 0.2367034 , 0.11106157, 0.58528495,
#        0.5143666 , 1.2463288 , 0.5325208 , 2.4507515 , 1.5248969 ,
#        0.47877312, 0.4834838 , 0.24330378, 0.4525633 , 0.16298246,
#        0.53678656, 2.821585  , 0.16184902, 0.52494454, 0.3347969 ,
#        0.73049974, 0.9197955 , 0.9120352 , 0.62906075], dtype=float32)

# %%
(vals['c']-vals['b'])/vals['c']*100
# Out:
# array([   12.074197 ,    16.453459 ,    48.179672 ,    14.240588 ,
#           18.323145 ,     0.       ,     0.       ,    87.12432  ,
#           28.24422  ,    34.1305   ,    76.9092   ,     8.317095 ,
#        -1258.5004   ,     8.658208 ,     6.0460157,    44.643703 ,
#         -276.09634  ,    82.803696 ,    44.54661  ,  -347.03983  ,
#           78.63083  ,    16.856667 ,    31.180683 ,    31.815104 ,
#            0.       ,  -363.44635  ,    -2.1447194,  -301.71545  ,
#           47.568703 ,    51.243996 ,  -479.88782  ,     0.       ,
#            6.5393543,     0.       ,   -26.68719  ,     0.       ,
#           55.431664 ,    14.914496 ,    80.22582  ,     0.       ,
#           96.35667  ,    67.40961  ,     2.065056 ,   -70.564545 ,
#           71.01109  ,    46.685425 ,    99.80277  ,    49.579548 ,
#            3.4938526,    48.252243 ,   -86.5774   ,   -61.860825 ,
#           92.53653  ,    99.4244   ,    68.35128  ,     0.       ,
#           79.56072  ,   -22.827484 ,  -215.30013  ,   -52.258163 ,
#           43.8112   ,    24.066942 ,    77.010956 ,    84.083595 ],
#       dtype=float32)

# %%
fiterator.restart_dataset(sess)

# %%
self = model

# %%
feed_dict = {
                iterator.handle: iterator.get_handle(sess, 'val'),
                tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
            }

# %%
sess.run(tf.map_fn(lambda x:tf.size(x),self.outputs.sample_id),feed_dict=feed_dict)
#sess.run(self.outputs.sample_id,feed_dict=feed_dict)
# Out:
# array([30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30], dtype=int32)

# %%
sess.run(tf.size(self.outputs.sample_id[0]),feed_dict=feed_dict)
# Out:
# 30

# %%
sess.run(self.inputs['length']-1,feed_dict=feed_dict)
# Out:
# array([ 5, 21, 20, 19,  3,  4,  9, 18, 14, 16, 14, 21, 22,  3, 20, 21, 17,
#        14, 22, 20, 14, 17, 10, 19, 23, 17, 14, 23, 21, 18, 16, 18, 22, 16,
#        15, 14, 23, 14, 13, 16,  8, 13,  7, 20, 14, 18, 14, 16, 17,  7, 14,
#        21, 17, 20, 18, 18, 12, 20, 10, 22, 18, 16, 21, 18], dtype=int32)

# %%
sess.run(self.fconv_output,feed_dict=feed_dict).shape
# Out:
# (64, 128)

# %%
sess.run(self.freg_output,feed_dict=feed_dict).shape
# Out:
# (64, 1)

# %%
sess.run(self.ffinal_state,feed_dict=feed_dict).shape
# Out:
# (64, 700)

# %%
sess.run(tf.concat([self.fconv_output, self.ffinal_state], -1),feed_dict=feed_dict).shape
# Out:
# (64, 828)

# %%
self.freg_output = self.fdense_layer(inputs = tf.concat([self.fconv_output, self.ffinal_state], -1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-59f6e459eb25> in <module>()
# ----> 1 self.freg_output = self.fdense_layer(inputs = tf.concat([self.fconv_output, self.ffinal_state], -1))
#
# TypeError: 'Tensor' object is not callable
