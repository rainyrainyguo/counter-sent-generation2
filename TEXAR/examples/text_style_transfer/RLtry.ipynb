# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# pylint: disable=invalid-name, too-many-locals, too-many-arguments, no-member

import os
import importlib
import numpy as np
import tensorflow as tf
import texar as tx

from RL_model import RLModel

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from itertools import chain
from torchtext import data

# %%
config = importlib.import_module('RLconfig')

# %%
from texar.modules import WordEmbedder, UnidirectionalRNNEncoder, \
        MLPTransformConnector, AttentionRNNDecoder, \
        GumbelSoftmaxEmbeddingHelper, Conv1DClassifier
from texar.core import get_train_op
from texar.utils import collect_trainable_variables, get_batch_size

# %%
# Data
train_data = tx.data.MultiAlignedData(config.train_data)
val_data = tx.data.MultiAlignedData(config.val_data)
test_data = tx.data.MultiAlignedData(config.test_data)
vocab = train_data.vocab(0)

# Each training batch is used twice: once for updating the generator and
# once for updating the discriminator. Feedable data iterator is used for
# such case.
iterator = tx.data.FeedableDataIterator({'train_g': train_data,'val': val_data, 'test': test_data})
batch = iterator.get_next()

# %%
# Model
model = RLModel(batch, vocab, config.model)

# %%
def _train_epoch(sess, epoch, verbose=True):
        avg_meters_g = tx.utils.AverageRecorder(size=10)

        step = 0
        while True:
            try:
                step += 1

                feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
                vals_g = sess.run(model.train_g, feed_dict=feed_dict)
                avg_meters_g.add(vals_g)

                if verbose and (step == 1 or step % 5 == 0):
                    print('step: {}, {}'.format(step, avg_meters_g.to_str(4)))
                    
                '''
                if verbose and step % 2 == 0:
                    iterator.restart_dataset(sess, 'val')
                    _eval_epoch(sess, epoch)
                '''
                
            except tf.errors.OutOfRangeError:
                print('epoch: {}, {}'.format(epoch, avg_meters_g.to_str(4)))
                break

# %%
 def _eval_epoch(sess, epoch, val_or_test='val'):
        avg_meters = tx.utils.AverageRecorder()

        while True:
            try:
                feed_dict = {
                    iterator.handle: iterator.get_handle(sess, val_or_test),
                    tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
                }

                vals = sess.run(model.samples, feed_dict=feed_dict)

                batch_size = vals.pop('batch_size')

                # Computes BLEU
                samples = tx.utils.dict_pop(vals, list(model.samples.keys()))
                hyps = tx.utils.map_ids_to_strs(samples['transferred'], vocab)
                print("samples: ",hyps)

                refs = tx.utils.map_ids_to_strs(samples['original'], vocab)
                refs = np.expand_dims(refs, axis=1)
                print("reference: ",refs)

                bleu = tx.evals.corpus_bleu_moses(refs, hyps)
                vals['bleu'] = bleu

                avg_meters.add(vals, weight=batch_size)

                ###################################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
                # Writes samples
                '''
                tx.utils.write_paired_text(
                    refs.squeeze(), hyps,
                    os.path.join(config.sample_path, 'val.%d'%epoch),
                    append=True, mode='v')
                '''
            except tf.errors.OutOfRangeError:
                print('{}: {}'.format(
                    val_or_test, avg_meters.to_str(precision=4)))
                break

        return avg_meters.avg()

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
sess.run(tf.local_variables_initializer())
sess.run(tf.tables_initializer())

saver = tf.train.Saver(max_to_keep=None)

# %%
if config.restore:
    print('Restore from: {}'.format(config.restore))
    saver.restore(sess, config.restore)

iterator.initialize_dataset(sess)

# %%
epoch = 1

# %%
feed_dict = {
    iterator.handle: iterator.get_handle(sess, 'val'),
    tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
}

vals = sess.run(model.samples, feed_dict=feed_dict)

batch_size = vals.pop('batch_size')

# %%
iterator.restart_dataset(sess, ['train_g'])
_train_epoch(sess, epoch)
# Out:
# step: 1, loss_g_ae: 18.0444 train_op_g_ae: 18.0444
# step: 5, loss_g_ae: 17.8378 train_op_g_ae: 17.8378
# step: 10, loss_g_ae: 16.2451 train_op_g_ae: 16.2451
# step: 15, loss_g_ae: 12.4887 train_op_g_ae: 12.4887
# step: 20, loss_g_ae: 9.2054 train_op_g_ae: 9.2054
# step: 25, loss_g_ae: 7.7582 train_op_g_ae: 7.7582
# step: 30, loss_g_ae: 7.3081 train_op_g_ae: 7.3081
# step: 35, loss_g_ae: 6.9869 train_op_g_ae: 6.9869
# step: 40, loss_g_ae: 6.6773 train_op_g_ae: 6.6773
# step: 45, loss_g_ae: 6.6282 train_op_g_ae: 6.6282
# step: 50, loss_g_ae: 6.5619 train_op_g_ae: 6.5619
# step: 55, loss_g_ae: 6.3774 train_op_g_ae: 6.3774
# step: 60, loss_g_ae: 6.3412 train_op_g_ae: 6.3412
# step: 65, loss_g_ae: 6.3216 train_op_g_ae: 6.3216
# step: 70, loss_g_ae: 6.2219 train_op_g_ae: 6.2219
# step: 75, loss_g_ae: 6.1349 train_op_g_ae: 6.1349
# step: 80, loss_g_ae: 6.0558 train_op_g_ae: 6.0558
# step: 85, loss_g_ae: 5.9959 train_op_g_ae: 5.9959
# step: 90, loss_g_ae: 5.9284 train_op_g_ae: 5.9284
# step: 95, loss_g_ae: 5.8516 train_op_g_ae: 5.8516
# step: 100, loss_g_ae: 5.8358 train_op_g_ae: 5.8358
# step: 105, loss_g_ae: 5.7239 train_op_g_ae: 5.7239
# step: 110, loss_g_ae: 5.6212 train_op_g_ae: 5.6212
# step: 115, loss_g_ae: 5.5587 train_op_g_ae: 5.5587
# step: 120, loss_g_ae: 5.4457 train_op_g_ae: 5.4457
# step: 125, loss_g_ae: 5.3817 train_op_g_ae: 5.3817
# step: 130, loss_g_ae: 5.3343 train_op_g_ae: 5.3343
# step: 135, loss_g_ae: 5.2741 train_op_g_ae: 5.2741
# step: 140, loss_g_ae: 5.2559 train_op_g_ae: 5.2559
# step: 145, loss_g_ae: 5.2527 train_op_g_ae: 5.2527
# step: 150, loss_g_ae: 5.2003 train_op_g_ae: 5.2003
# step: 155, loss_g_ae: 5.1864 train_op_g_ae: 5.1864
# step: 160, loss_g_ae: 5.2245 train_op_g_ae: 5.2245
# step: 165, loss_g_ae: 5.1995 train_op_g_ae: 5.1995
# step: 170, loss_g_ae: 5.1316 train_op_g_ae: 5.1316
# step: 175, loss_g_ae: 5.0724 train_op_g_ae: 5.0724
# step: 180, loss_g_ae: 5.0134 train_op_g_ae: 5.0134
# step: 185, loss_g_ae: 5.0055 train_op_g_ae: 5.0055
# step: 190, loss_g_ae: 4.9697 train_op_g_ae: 4.9697
# step: 195, loss_g_ae: 4.9755 train_op_g_ae: 4.9755
# step: 200, loss_g_ae: 5.0078 train_op_g_ae: 5.0078
# step: 205, loss_g_ae: 4.9949 train_op_g_ae: 4.9949
# step: 210, loss_g_ae: 4.9881 train_op_g_ae: 4.9881
# step: 215, loss_g_ae: 4.9647 train_op_g_ae: 4.9647
# step: 220, loss_g_ae: 4.9326 train_op_g_ae: 4.9326
# step: 225, loss_g_ae: 4.8809 train_op_g_ae: 4.8809
# step: 230, loss_g_ae: 4.8441 train_op_g_ae: 4.8441
# step: 235, loss_g_ae: 4.8781 train_op_g_ae: 4.8781
# step: 240, loss_g_ae: 4.9737 train_op_g_ae: 4.9737
# step: 245, loss_g_ae: 4.9484 train_op_g_ae: 4.9484
# step: 250, loss_g_ae: 4.8782 train_op_g_ae: 4.8782
# step: 255, loss_g_ae: 4.8544 train_op_g_ae: 4.8544
# step: 260, loss_g_ae: 4.8104 train_op_g_ae: 4.8104
# step: 265, loss_g_ae: 4.7965 train_op_g_ae: 4.7965
# step: 270, loss_g_ae: 4.8323 train_op_g_ae: 4.8323
# step: 275, loss_g_ae: 4.8316 train_op_g_ae: 4.8316
# step: 280, loss_g_ae: 4.8157 train_op_g_ae: 4.8157
# step: 285, loss_g_ae: 4.7907 train_op_g_ae: 4.7907
# step: 290, loss_g_ae: 4.7595 train_op_g_ae: 4.7595
# step: 295, loss_g_ae: 4.8194 train_op_g_ae: 4.8194
# step: 300, loss_g_ae: 4.7941 train_op_g_ae: 4.7941
# step: 305, loss_g_ae: 4.7300 train_op_g_ae: 4.7300
# step: 310, loss_g_ae: 4.7839 train_op_g_ae: 4.7839
# step: 315, loss_g_ae: 4.8191 train_op_g_ae: 4.8191
# step: 320, loss_g_ae: 4.7386 train_op_g_ae: 4.7386
# step: 325, loss_g_ae: 4.7059 train_op_g_ae: 4.7059
# step: 330, loss_g_ae: 4.6720 train_op_g_ae: 4.6720
# step: 335, loss_g_ae: 4.6354 train_op_g_ae: 4.6354
# step: 340, loss_g_ae: 4.9140 train_op_g_ae: 4.9140
# step: 345, loss_g_ae: 5.1557 train_op_g_ae: 5.1557
# step: 350, loss_g_ae: 4.9718 train_op_g_ae: 4.9718
# step: 355, loss_g_ae: 4.8154 train_op_g_ae: 4.8154
# step: 360, loss_g_ae: 4.8060 train_op_g_ae: 4.8060
# step: 365, loss_g_ae: 4.8039 train_op_g_ae: 4.8039
# step: 370, loss_g_ae: 4.7450 train_op_g_ae: 4.7450
# step: 375, loss_g_ae: 4.7265 train_op_g_ae: 4.7265
# step: 380, loss_g_ae: 4.7343 train_op_g_ae: 4.7343
# step: 385, loss_g_ae: 4.6404 train_op_g_ae: 4.6404
# step: 390, loss_g_ae: 4.6395 train_op_g_ae: 4.6395
# step: 395, loss_g_ae: 4.6598 train_op_g_ae: 4.6598
# step: 400, loss_g_ae: 4.6306 train_op_g_ae: 4.6306
# step: 405, loss_g_ae: 4.6580 train_op_g_ae: 4.6580
# step: 410, loss_g_ae: 4.6936 train_op_g_ae: 4.6936
# step: 415, loss_g_ae: 4.7087 train_op_g_ae: 4.7087
# step: 420, loss_g_ae: 4.6934 train_op_g_ae: 4.6934
# step: 425, loss_g_ae: 4.5912 train_op_g_ae: 4.5912
# step: 430, loss_g_ae: 4.6203 train_op_g_ae: 4.6203
# step: 435, loss_g_ae: 4.6458 train_op_g_ae: 4.6458
# step: 440, loss_g_ae: 4.6012 train_op_g_ae: 4.6012
# step: 445, loss_g_ae: 4.5480 train_op_g_ae: 4.5480
# step: 450, loss_g_ae: 4.5766 train_op_g_ae: 4.5766
# step: 455, loss_g_ae: 4.6510 train_op_g_ae: 4.6510
# step: 460, loss_g_ae: 4.6057 train_op_g_ae: 4.6057
# step: 465, loss_g_ae: 4.5893 train_op_g_ae: 4.5893
# step: 470, loss_g_ae: 4.5699 train_op_g_ae: 4.5699
# step: 475, loss_g_ae: 4.6195 train_op_g_ae: 4.6195
# step: 480, loss_g_ae: 4.6440 train_op_g_ae: 4.6440
# step: 485, loss_g_ae: 4.6374 train_op_g_ae: 4.6374
# step: 490, loss_g_ae: 4.6714 train_op_g_ae: 4.6714
# step: 495, loss_g_ae: 4.6085 train_op_g_ae: 4.6085
# step: 500, loss_g_ae: 4.6209 train_op_g_ae: 4.6209
# step: 505, loss_g_ae: 4.6235 train_op_g_ae: 4.6235
# step: 510, loss_g_ae: 4.4835 train_op_g_ae: 4.4835
# step: 515, loss_g_ae: 4.4751 train_op_g_ae: 4.4751
# step: 520, loss_g_ae: 4.5962 train_op_g_ae: 4.5962
# step: 525, loss_g_ae: 4.8486 train_op_g_ae: 4.8486
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-8d47ae93f088> in <module>()
#       1 iterator.restart_dataset(sess, ['train_g'])
# ----> 2 _train_epoch(sess, epoch)
#
# <ipython-input-6-fba67d055e23> in _train_epoch(sess, epoch, verbose)
#       8
#       9                 feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
# ---> 10                 vals_g = sess.run(model.train_g, feed_dict=feed_dict)
#      11                 avg_meters_g.add(vals_g)
#      12
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1276   def _do_call(self, fn, *args):
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#    1280       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1261       self._extend_graph()
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#    1265     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1348     return tf_session.TF_SessionRun_wrapper(
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#    1352   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
iterator.restart_dataset(sess, ['train_g'])
_train_epoch(sess, epoch)
# Out:
# step: 1, loss_g_ae: 4.8476 train_op_g_ae: 4.8476
# step: 5, loss_g_ae: 4.7750 train_op_g_ae: 4.7750
# step: 10, loss_g_ae: 4.7905 train_op_g_ae: 4.7905
# step: 15, loss_g_ae: 4.7529 train_op_g_ae: 4.7529
# step: 20, loss_g_ae: 4.6318 train_op_g_ae: 4.6318
# step: 25, loss_g_ae: 4.5595 train_op_g_ae: 4.5595
# step: 30, loss_g_ae: 4.6126 train_op_g_ae: 4.6126
# step: 35, loss_g_ae: 4.6772 train_op_g_ae: 4.6772
# step: 40, loss_g_ae: 4.6215 train_op_g_ae: 4.6215
# step: 45, loss_g_ae: 4.5977 train_op_g_ae: 4.5977
# step: 50, loss_g_ae: 4.6583 train_op_g_ae: 4.6583
# step: 55, loss_g_ae: 4.5719 train_op_g_ae: 4.5719
# step: 60, loss_g_ae: 4.5181 train_op_g_ae: 4.5181
# step: 65, loss_g_ae: 4.5695 train_op_g_ae: 4.5695
# step: 70, loss_g_ae: 4.5535 train_op_g_ae: 4.5535
# step: 75, loss_g_ae: 4.5394 train_op_g_ae: 4.5394
# step: 80, loss_g_ae: 4.5399 train_op_g_ae: 4.5399
# step: 85, loss_g_ae: 4.4974 train_op_g_ae: 4.4974
# step: 90, loss_g_ae: 4.4795 train_op_g_ae: 4.4795
# step: 95, loss_g_ae: 4.4959 train_op_g_ae: 4.4959
# step: 100, loss_g_ae: 4.5412 train_op_g_ae: 4.5412
# step: 105, loss_g_ae: 4.5336 train_op_g_ae: 4.5336
# step: 110, loss_g_ae: 4.4592 train_op_g_ae: 4.4592
# step: 115, loss_g_ae: 4.4077 train_op_g_ae: 4.4077
# step: 120, loss_g_ae: 4.3877 train_op_g_ae: 4.3877
# step: 125, loss_g_ae: 4.4098 train_op_g_ae: 4.4098
# step: 130, loss_g_ae: 4.4696 train_op_g_ae: 4.4696
# step: 135, loss_g_ae: 4.4829 train_op_g_ae: 4.4829
# step: 140, loss_g_ae: 4.4395 train_op_g_ae: 4.4395
# step: 145, loss_g_ae: 4.3982 train_op_g_ae: 4.3982
# step: 150, loss_g_ae: 4.3475 train_op_g_ae: 4.3475
# step: 155, loss_g_ae: 4.3393 train_op_g_ae: 4.3393
# step: 160, loss_g_ae: 4.3207 train_op_g_ae: 4.3207
# step: 165, loss_g_ae: 4.3034 train_op_g_ae: 4.3034
# step: 170, loss_g_ae: 4.3228 train_op_g_ae: 4.3228
# step: 175, loss_g_ae: 4.3322 train_op_g_ae: 4.3322
# step: 180, loss_g_ae: 4.2239 train_op_g_ae: 4.2239
# step: 185, loss_g_ae: 4.2045 train_op_g_ae: 4.2045
# step: 190, loss_g_ae: 4.2578 train_op_g_ae: 4.2578
# step: 195, loss_g_ae: 4.2514 train_op_g_ae: 4.2514
# step: 200, loss_g_ae: 4.2087 train_op_g_ae: 4.2087
# step: 205, loss_g_ae: 4.1757 train_op_g_ae: 4.1757
# step: 210, loss_g_ae: 4.2323 train_op_g_ae: 4.2323
# step: 215, loss_g_ae: 4.2601 train_op_g_ae: 4.2601
# step: 220, loss_g_ae: 4.1986 train_op_g_ae: 4.1986
# step: 225, loss_g_ae: 4.1031 train_op_g_ae: 4.1031
# step: 230, loss_g_ae: 4.0083 train_op_g_ae: 4.0083
# step: 235, loss_g_ae: 4.0661 train_op_g_ae: 4.0661
# step: 240, loss_g_ae: 4.1362 train_op_g_ae: 4.1362
# step: 245, loss_g_ae: 4.0660 train_op_g_ae: 4.0660
# step: 250, loss_g_ae: 4.5363 train_op_g_ae: 4.5363
# step: 255, loss_g_ae: 4.8333 train_op_g_ae: 4.8333
# step: 260, loss_g_ae: 4.5382 train_op_g_ae: 4.5382
# step: 265, loss_g_ae: 4.3859 train_op_g_ae: 4.3859
# step: 270, loss_g_ae: 4.2771 train_op_g_ae: 4.2771
# step: 275, loss_g_ae: 4.1361 train_op_g_ae: 4.1361
# step: 280, loss_g_ae: 4.0522 train_op_g_ae: 4.0522
# step: 285, loss_g_ae: 3.9195 train_op_g_ae: 3.9195
# step: 290, loss_g_ae: 3.8823 train_op_g_ae: 3.8823
# step: 295, loss_g_ae: 3.8951 train_op_g_ae: 3.8951
# step: 300, loss_g_ae: 3.9212 train_op_g_ae: 3.9212
# step: 305, loss_g_ae: 3.9914 train_op_g_ae: 3.9914
# step: 310, loss_g_ae: 3.8264 train_op_g_ae: 3.8264
# step: 315, loss_g_ae: 3.6936 train_op_g_ae: 3.6936
# step: 320, loss_g_ae: 3.6937 train_op_g_ae: 3.6937
# step: 325, loss_g_ae: 3.6307 train_op_g_ae: 3.6307
# step: 330, loss_g_ae: 3.5703 train_op_g_ae: 3.5703
# step: 335, loss_g_ae: 3.6418 train_op_g_ae: 3.6418
# step: 340, loss_g_ae: 3.5815 train_op_g_ae: 3.5815
# step: 345, loss_g_ae: 3.4681 train_op_g_ae: 3.4681
# step: 350, loss_g_ae: 3.4992 train_op_g_ae: 3.4992
# step: 355, loss_g_ae: 3.4182 train_op_g_ae: 3.4182
# step: 360, loss_g_ae: 3.3100 train_op_g_ae: 3.3100
# step: 365, loss_g_ae: 3.6939 train_op_g_ae: 3.6939
# step: 370, loss_g_ae: 4.0614 train_op_g_ae: 4.0614
# step: 375, loss_g_ae: 3.7674 train_op_g_ae: 3.7674
# step: 380, loss_g_ae: 3.4544 train_op_g_ae: 3.4544
# step: 385, loss_g_ae: 3.3995 train_op_g_ae: 3.3995
# step: 390, loss_g_ae: 3.3661 train_op_g_ae: 3.3661
# step: 395, loss_g_ae: 3.3425 train_op_g_ae: 3.3425
# step: 400, loss_g_ae: 3.2354 train_op_g_ae: 3.2354
# step: 405, loss_g_ae: 3.1672 train_op_g_ae: 3.1672
# step: 410, loss_g_ae: 3.1435 train_op_g_ae: 3.1435
# step: 415, loss_g_ae: 3.0002 train_op_g_ae: 3.0002
# step: 420, loss_g_ae: 2.9663 train_op_g_ae: 2.9663
# step: 425, loss_g_ae: 2.9603 train_op_g_ae: 2.9603
# step: 430, loss_g_ae: 2.8561 train_op_g_ae: 2.8561
# step: 435, loss_g_ae: 2.8563 train_op_g_ae: 2.8563
# step: 440, loss_g_ae: 2.8598 train_op_g_ae: 2.8598
# step: 445, loss_g_ae: 2.7907 train_op_g_ae: 2.7907
# step: 450, loss_g_ae: 2.7733 train_op_g_ae: 2.7733
# step: 455, loss_g_ae: 2.8491 train_op_g_ae: 2.8491
# step: 460, loss_g_ae: 2.9599 train_op_g_ae: 2.9599
# step: 465, loss_g_ae: 3.9023 train_op_g_ae: 3.9023
# step: 470, loss_g_ae: 4.5455 train_op_g_ae: 4.5455
# step: 475, loss_g_ae: 4.0234 train_op_g_ae: 4.0234
# step: 480, loss_g_ae: 3.5597 train_op_g_ae: 3.5597
# step: 485, loss_g_ae: 3.2418 train_op_g_ae: 3.2418
# step: 490, loss_g_ae: 3.0584 train_op_g_ae: 3.0584
# step: 495, loss_g_ae: 2.9200 train_op_g_ae: 2.9200
# step: 500, loss_g_ae: 2.8250 train_op_g_ae: 2.8250
# step: 505, loss_g_ae: 2.8202 train_op_g_ae: 2.8202
# step: 510, loss_g_ae: 2.7646 train_op_g_ae: 2.7646
# step: 515, loss_g_ae: 2.6158 train_op_g_ae: 2.6158
# step: 520, loss_g_ae: 2.5226 train_op_g_ae: 2.5226
# step: 525, loss_g_ae: 2.5083 train_op_g_ae: 2.5083
# step: 530, loss_g_ae: 2.4614 train_op_g_ae: 2.4614
# step: 535, loss_g_ae: 2.4212 train_op_g_ae: 2.4212
# step: 540, loss_g_ae: 2.4598 train_op_g_ae: 2.4598
# step: 545, loss_g_ae: 2.4547 train_op_g_ae: 2.4547
# step: 550, loss_g_ae: 2.3856 train_op_g_ae: 2.3856
# step: 555, loss_g_ae: 2.3334 train_op_g_ae: 2.3334
# step: 560, loss_g_ae: 2.2575 train_op_g_ae: 2.2575
# step: 565, loss_g_ae: 2.1992 train_op_g_ae: 2.1992
# step: 570, loss_g_ae: 2.3401 train_op_g_ae: 2.3401
# step: 575, loss_g_ae: 2.4406 train_op_g_ae: 2.4406
# step: 580, loss_g_ae: 2.4083 train_op_g_ae: 2.4083
# step: 585, loss_g_ae: 2.3105 train_op_g_ae: 2.3105
# step: 590, loss_g_ae: 2.1750 train_op_g_ae: 2.1750
# step: 595, loss_g_ae: 2.1217 train_op_g_ae: 2.1217
# step: 600, loss_g_ae: 2.1001 train_op_g_ae: 2.1001
# step: 605, loss_g_ae: 2.0623 train_op_g_ae: 2.0623
# step: 610, loss_g_ae: 2.0195 train_op_g_ae: 2.0195
# step: 615, loss_g_ae: 1.9824 train_op_g_ae: 1.9824
# step: 620, loss_g_ae: 1.9421 train_op_g_ae: 1.9421
# step: 625, loss_g_ae: 1.9401 train_op_g_ae: 1.9401
# step: 630, loss_g_ae: 1.9727 train_op_g_ae: 1.9727
# step: 635, loss_g_ae: 2.0141 train_op_g_ae: 2.0141
# step: 640, loss_g_ae: 1.9575 train_op_g_ae: 1.9575
# step: 645, loss_g_ae: 1.9128 train_op_g_ae: 1.9128
# step: 650, loss_g_ae: 1.9417 train_op_g_ae: 1.9417
# step: 655, loss_g_ae: 1.8954 train_op_g_ae: 1.8954
# step: 660, loss_g_ae: 1.8239 train_op_g_ae: 1.8239
# step: 665, loss_g_ae: 1.8169 train_op_g_ae: 1.8169
# step: 670, loss_g_ae: 1.7785 train_op_g_ae: 1.7785
# step: 675, loss_g_ae: 1.7179 train_op_g_ae: 1.7179
# step: 680, loss_g_ae: 1.7576 train_op_g_ae: 1.7576
# step: 685, loss_g_ae: 1.7081 train_op_g_ae: 1.7081
# step: 690, loss_g_ae: 1.6447 train_op_g_ae: 1.6447
# step: 695, loss_g_ae: 1.6770 train_op_g_ae: 1.6770
# step: 700, loss_g_ae: 1.7023 train_op_g_ae: 1.7023
# step: 705, loss_g_ae: 1.9547 train_op_g_ae: 1.9547
# step: 710, loss_g_ae: 2.1370 train_op_g_ae: 2.1370
# step: 715, loss_g_ae: 2.4643 train_op_g_ae: 2.4643
# step: 720, loss_g_ae: 2.8768 train_op_g_ae: 2.8768
# step: 725, loss_g_ae: 2.4982 train_op_g_ae: 2.4982
# step: 730, loss_g_ae: 2.0225 train_op_g_ae: 2.0225
# step: 735, loss_g_ae: 1.9411 train_op_g_ae: 1.9411
# step: 740, loss_g_ae: 1.8081 train_op_g_ae: 1.8081
# step: 745, loss_g_ae: 1.6610 train_op_g_ae: 1.6610
# step: 750, loss_g_ae: 1.6830 train_op_g_ae: 1.6830
# step: 755, loss_g_ae: 1.7032 train_op_g_ae: 1.7032
# step: 760, loss_g_ae: 1.6566 train_op_g_ae: 1.6566
# step: 765, loss_g_ae: 1.5976 train_op_g_ae: 1.5976
# step: 770, loss_g_ae: 1.4873 train_op_g_ae: 1.4873
# step: 775, loss_g_ae: 1.4760 train_op_g_ae: 1.4760
# step: 780, loss_g_ae: 1.4975 train_op_g_ae: 1.4975
# step: 785, loss_g_ae: 1.4649 train_op_g_ae: 1.4649
# step: 790, loss_g_ae: 1.4829 train_op_g_ae: 1.4829
# step: 795, loss_g_ae: 1.4476 train_op_g_ae: 1.4476
# step: 800, loss_g_ae: 1.4179 train_op_g_ae: 1.4179
# step: 805, loss_g_ae: 1.4466 train_op_g_ae: 1.4466
# step: 810, loss_g_ae: 1.4366 train_op_g_ae: 1.4366
# step: 815, loss_g_ae: 1.4341 train_op_g_ae: 1.4341
# step: 820, loss_g_ae: 1.3809 train_op_g_ae: 1.3809
# step: 825, loss_g_ae: 1.3295 train_op_g_ae: 1.3295
# step: 830, loss_g_ae: 1.3073 train_op_g_ae: 1.3073
# step: 835, loss_g_ae: 1.3237 train_op_g_ae: 1.3237
# step: 840, loss_g_ae: 1.3285 train_op_g_ae: 1.3285
# step: 845, loss_g_ae: 1.2960 train_op_g_ae: 1.2960
# step: 850, loss_g_ae: 1.2772 train_op_g_ae: 1.2772
# step: 855, loss_g_ae: 1.3133 train_op_g_ae: 1.3133
# step: 860, loss_g_ae: 1.3926 train_op_g_ae: 1.3926
# step: 865, loss_g_ae: 1.4339 train_op_g_ae: 1.4339
# step: 870, loss_g_ae: 1.4136 train_op_g_ae: 1.4136
# step: 875, loss_g_ae: 1.3642 train_op_g_ae: 1.3642
# step: 880, loss_g_ae: 1.3208 train_op_g_ae: 1.3208
# step: 885, loss_g_ae: 1.2337 train_op_g_ae: 1.2337
# step: 890, loss_g_ae: 1.1677 train_op_g_ae: 1.1677
# step: 895, loss_g_ae: 1.1575 train_op_g_ae: 1.1575
# step: 900, loss_g_ae: 1.1727 train_op_g_ae: 1.1727
# step: 905, loss_g_ae: 1.2481 train_op_g_ae: 1.2481
# step: 910, loss_g_ae: 1.2235 train_op_g_ae: 1.2235
# step: 915, loss_g_ae: 1.1780 train_op_g_ae: 1.1780
# step: 920, loss_g_ae: 1.2310 train_op_g_ae: 1.2310
# step: 925, loss_g_ae: 1.2121 train_op_g_ae: 1.2121
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8d47ae93f088> in <module>()
#       1 iterator.restart_dataset(sess, ['train_g'])
# ----> 2 _train_epoch(sess, epoch)
#
# <ipython-input-6-fba67d055e23> in _train_epoch(sess, epoch, verbose)
#       8
#       9                 feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
# ---> 10                 vals_g = sess.run(model.train_g, feed_dict=feed_dict)
#      11                 avg_meters_g.add(vals_g)
#      12
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1276   def _do_call(self, fn, *args):
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#    1280       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1261       self._extend_graph()
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#    1265     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1348     return tf_session.TF_SessionRun_wrapper(
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#    1352   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
for epoch in range(1, 10):
    # Train
    iterator.restart_dataset(sess, ['train_g'])
    _train_epoch(sess, epoch)
# Out:
# step: 1, loss_g_ae: 1.3450 train_op_g_ae: 1.3450
# step: 5, loss_g_ae: 1.2362 train_op_g_ae: 1.2362
# step: 10, loss_g_ae: 1.1934 train_op_g_ae: 1.1934
# step: 15, loss_g_ae: 1.0762 train_op_g_ae: 1.0762
# step: 20, loss_g_ae: 1.0415 train_op_g_ae: 1.0415
# step: 25, loss_g_ae: 1.0993 train_op_g_ae: 1.0993
# step: 30, loss_g_ae: 1.1369 train_op_g_ae: 1.1369
# step: 35, loss_g_ae: 1.0971 train_op_g_ae: 1.0971
# step: 40, loss_g_ae: 1.0907 train_op_g_ae: 1.0907
# step: 45, loss_g_ae: 1.1162 train_op_g_ae: 1.1162
# step: 50, loss_g_ae: 1.0587 train_op_g_ae: 1.0587
# step: 55, loss_g_ae: 1.0665 train_op_g_ae: 1.0665
# step: 60, loss_g_ae: 1.0563 train_op_g_ae: 1.0563
# step: 65, loss_g_ae: 1.0465 train_op_g_ae: 1.0465
# step: 70, loss_g_ae: 1.0888 train_op_g_ae: 1.0888
# step: 75, loss_g_ae: 1.0295 train_op_g_ae: 1.0295
# step: 80, loss_g_ae: 0.9901 train_op_g_ae: 0.9901
# step: 85, loss_g_ae: 1.0438 train_op_g_ae: 1.0438
# step: 90, loss_g_ae: 1.0498 train_op_g_ae: 1.0498
# step: 95, loss_g_ae: 1.0276 train_op_g_ae: 1.0276
# step: 100, loss_g_ae: 1.0470 train_op_g_ae: 1.0470
# step: 105, loss_g_ae: 1.0155 train_op_g_ae: 1.0155
# step: 110, loss_g_ae: 1.0032 train_op_g_ae: 1.0032
# step: 115, loss_g_ae: 1.0099 train_op_g_ae: 1.0099
# step: 120, loss_g_ae: 1.0475 train_op_g_ae: 1.0475
# step: 125, loss_g_ae: 1.0136 train_op_g_ae: 1.0136
# step: 130, loss_g_ae: 0.9969 train_op_g_ae: 0.9969
# step: 135, loss_g_ae: 1.0570 train_op_g_ae: 1.0570
# step: 140, loss_g_ae: 1.0036 train_op_g_ae: 1.0036
# step: 145, loss_g_ae: 0.9460 train_op_g_ae: 0.9460
# step: 150, loss_g_ae: 0.9728 train_op_g_ae: 0.9728
# step: 155, loss_g_ae: 1.0013 train_op_g_ae: 1.0013
# step: 160, loss_g_ae: 0.9973 train_op_g_ae: 0.9973
# step: 165, loss_g_ae: 0.9853 train_op_g_ae: 0.9853
# step: 170, loss_g_ae: 0.9377 train_op_g_ae: 0.9377
# step: 175, loss_g_ae: 0.9427 train_op_g_ae: 0.9427
# step: 180, loss_g_ae: 0.9619 train_op_g_ae: 0.9619
# step: 185, loss_g_ae: 0.9712 train_op_g_ae: 0.9712
# step: 190, loss_g_ae: 0.9469 train_op_g_ae: 0.9469
# step: 195, loss_g_ae: 0.9717 train_op_g_ae: 0.9717
# step: 200, loss_g_ae: 0.9809 train_op_g_ae: 0.9809
# step: 205, loss_g_ae: 0.9939 train_op_g_ae: 0.9939
# step: 210, loss_g_ae: 0.9638 train_op_g_ae: 0.9638
# step: 215, loss_g_ae: 0.9164 train_op_g_ae: 0.9164
# step: 220, loss_g_ae: 0.9320 train_op_g_ae: 0.9320
# step: 225, loss_g_ae: 0.9238 train_op_g_ae: 0.9238
# step: 230, loss_g_ae: 0.9374 train_op_g_ae: 0.9374
# step: 235, loss_g_ae: 0.8887 train_op_g_ae: 0.8887
# step: 240, loss_g_ae: 0.8843 train_op_g_ae: 0.8843
# step: 245, loss_g_ae: 0.9317 train_op_g_ae: 0.9317
# step: 250, loss_g_ae: 0.9177 train_op_g_ae: 0.9177
# step: 255, loss_g_ae: 0.9230 train_op_g_ae: 0.9230
# step: 260, loss_g_ae: 0.9689 train_op_g_ae: 0.9689
# step: 265, loss_g_ae: 1.0212 train_op_g_ae: 1.0212
# step: 270, loss_g_ae: 0.9906 train_op_g_ae: 0.9906
# step: 275, loss_g_ae: 0.9394 train_op_g_ae: 0.9394
# step: 280, loss_g_ae: 0.9075 train_op_g_ae: 0.9075
# step: 285, loss_g_ae: 0.8723 train_op_g_ae: 0.8723
# step: 290, loss_g_ae: 0.9050 train_op_g_ae: 0.9050
# step: 295, loss_g_ae: 0.9240 train_op_g_ae: 0.9240
# step: 300, loss_g_ae: 0.8843 train_op_g_ae: 0.8843
# step: 305, loss_g_ae: 0.8055 train_op_g_ae: 0.8055
# step: 310, loss_g_ae: 0.8056 train_op_g_ae: 0.8056
# step: 315, loss_g_ae: 0.8448 train_op_g_ae: 0.8448
# step: 320, loss_g_ae: 0.8537 train_op_g_ae: 0.8537
# step: 325, loss_g_ae: 0.8686 train_op_g_ae: 0.8686
# step: 330, loss_g_ae: 0.8461 train_op_g_ae: 0.8461
# step: 335, loss_g_ae: 0.8430 train_op_g_ae: 0.8430
# step: 340, loss_g_ae: 0.8561 train_op_g_ae: 0.8561
# step: 345, loss_g_ae: 0.8085 train_op_g_ae: 0.8085
# step: 350, loss_g_ae: 0.8033 train_op_g_ae: 0.8033
# step: 355, loss_g_ae: 0.8123 train_op_g_ae: 0.8123
# step: 360, loss_g_ae: 0.8287 train_op_g_ae: 0.8287
# step: 365, loss_g_ae: 0.8601 train_op_g_ae: 0.8601
# step: 370, loss_g_ae: 0.8036 train_op_g_ae: 0.8036
# step: 375, loss_g_ae: 0.7607 train_op_g_ae: 0.7607
# step: 380, loss_g_ae: 0.7808 train_op_g_ae: 0.7808
# step: 385, loss_g_ae: 0.8001 train_op_g_ae: 0.8001
# step: 390, loss_g_ae: 0.7882 train_op_g_ae: 0.7882
# step: 395, loss_g_ae: 0.7664 train_op_g_ae: 0.7664
# step: 400, loss_g_ae: 0.7770 train_op_g_ae: 0.7770
# step: 405, loss_g_ae: 0.7872 train_op_g_ae: 0.7872
# step: 410, loss_g_ae: 0.7443 train_op_g_ae: 0.7443
# step: 415, loss_g_ae: 0.7206 train_op_g_ae: 0.7206
# step: 420, loss_g_ae: 0.7786 train_op_g_ae: 0.7786
# step: 425, loss_g_ae: 0.8076 train_op_g_ae: 0.8076
# step: 430, loss_g_ae: 0.8097 train_op_g_ae: 0.8097
# step: 435, loss_g_ae: 0.8101 train_op_g_ae: 0.8101
# step: 440, loss_g_ae: 0.7649 train_op_g_ae: 0.7649
# step: 445, loss_g_ae: 0.7570 train_op_g_ae: 0.7570
# step: 450, loss_g_ae: 0.7772 train_op_g_ae: 0.7772
# step: 455, loss_g_ae: 0.7770 train_op_g_ae: 0.7770
# step: 460, loss_g_ae: 0.8070 train_op_g_ae: 0.8070
# step: 465, loss_g_ae: 0.8107 train_op_g_ae: 0.8107
# step: 470, loss_g_ae: 0.7892 train_op_g_ae: 0.7892
# step: 475, loss_g_ae: 0.7848 train_op_g_ae: 0.7848
# step: 480, loss_g_ae: 0.7987 train_op_g_ae: 0.7987
# step: 485, loss_g_ae: 0.8132 train_op_g_ae: 0.8132
# step: 490, loss_g_ae: 0.7843 train_op_g_ae: 0.7843
# step: 495, loss_g_ae: 0.7901 train_op_g_ae: 0.7901
# step: 500, loss_g_ae: 0.8120 train_op_g_ae: 0.8120
# step: 505, loss_g_ae: 0.8224 train_op_g_ae: 0.8224
# step: 510, loss_g_ae: 0.8142 train_op_g_ae: 0.8142
# step: 515, loss_g_ae: 0.7886 train_op_g_ae: 0.7886
# step: 520, loss_g_ae: 0.7427 train_op_g_ae: 0.7427
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e0eb7bd06fb2> in <module>()
#       2     # Train
#       3     iterator.restart_dataset(sess, ['train_g'])
# ----> 4     _train_epoch(sess, epoch)
#
# <ipython-input-6-fba67d055e23> in _train_epoch(sess, epoch, verbose)
#       8
#       9                 feed_dict = {iterator.handle: iterator.get_handle(sess, 'train_g')}
# ---> 10                 vals_g = sess.run(model.train_g, feed_dict=feed_dict)
#      11                 avg_meters_g.add(vals_g)
#      12
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1276   def _do_call(self, fn, *args):
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#    1280       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1261       self._extend_graph()
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#    1265     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/pt4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1348     return tf_session.TF_SessionRun_wrapper(
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#    1352   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
saver.save(sess,'RLsave/texar_data_model2.ckpt')
# Out:
# INFO:tensorflow:RLsave/texar_data_model2.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# 'RLsave/texar_data_model2.ckpt'

# %%
feed_dict = {
    iterator.handle: iterator.get_handle(sess, 'val'),
    tx.context.global_mode(): tf.estimator.ModeKeys.EVAL
}

vals = sess.run(model.samples, feed_dict=feed_dict)

batch_size = vals.pop('batch_size')

# Computes BLEU
samples = tx.utils.dict_pop(vals, list(model.samples.keys()))
hyps = tx.utils.map_ids_to_strs(samples['transferred'], vocab)
print("samples: ",hyps)

refs = tx.utils.map_ids_to_strs(samples['original'], vocab)
refs = np.expand_dims(refs, axis=1)
print("reference: ",refs)
# Out:
# samples:  ['service was terrible .' 'service was good , but food was very slow .'
#  "it 's the outcome of it that makes me so supposed ."
#  '1st seating of ladies and chili oil .'
#  'i never thought anyone could make that one bad .'
#  'then they are too big for the other cookies .' 'great service .'
#  'the prices they charge are sealed for what you get .'
#  'this was a fun and delicious dinner to spend a birthday .'
#  "i visited t 's because i mean that they had a glaze menu ."
#  'this place is a serious amount with improved service .'
#  'when i went back with my wife , the cooking was completely car .'
#  'top _num_ .' 'every side of walnut is just amazing .'
#  'the food is delicious and served family style .'
#  'free bike train , etc .' 'our dogs mean everything to us .' 'wow !'
#  'it was a filthy friday .' 'the gyro fish with character was so good !'
#  'anyway , i have been twice for a dinner and it has been notice .'
#  'she credit back _num_ mins later and meatballs me his afternoon work looks great .'
#  'i have always wanted to find a dental bean girl and i found one !'
#  'the food is always good and the staff friendly .'
#  'and sometimes even appearance -- paste .'
#  'dr. chowder and his staff are absolutely wonderful !'
#  'seems like a lack of memorial in grease .' "she 's a spot-on !"
#  'i used to live near here and this is my favorite enemy .'
#  "i ca n't send the need to return here ."
#  'we had a pleasant experience that informed our expectations and recommend it !'
#  'dr. chowder is so kind and cookies .'
#  'i wish i could say the same for my burrito .'
#  'the food was delicious and the appearance cook exactly the way we hear .'
#  'huge service .'
#  'but its a good thing because exactly how appearance they are in our are .'
#  'great job .' 'their rib cheese same are also delicious !'
#  'best hot salsa in town .'
#  'great service from the staff and very generous and affordable trash .'
#  'they have la specials and plenty of foods food on their menu .'
#  'i was very pleased by everyone !'
#  'and this second go around is horrible !'
#  'fun place for a recommendations car dinner .'
#  'fun place , fun too , and amazing food !'
#  "we 've been going there turned information for over _num_ years ."
#  'i just love this place .' 'i will certainly return for the service .'
#  'i will not be shopping here downhill .' 'this place is awesome .'
#  'thank you hoover and inexpensive so much for everything you guys do .'
#  'absolutely airport !'
#  'great service and prices on new space for my truck .'
#  'great food and a nice selection of beer and wine .'
#  'i will definitely be returning soon !'
#  'overpriced and not even very good .'
#  'will try to make it back to have a full meal for sure .'
#  'my husband order a plate of shelf again .'
#  'i am glad i celebrate not get any appointment with this car .'
#  'fuck bread was served then visited .'
#  'i highly recommend the cheesy or hawaii .'
#  'the price for the quality is good .' 'just another money off joint .'
#  'great tasting and great food !']
# reference:  [['service was terrible .']
#  ['service was good , but food was very slow .']
#  ["it 's the principle of it that makes me so angry ."]
#  ['wide range of sesame and chili oil .']
#  ['i never thought anyone could make that one bad .']
#  ['then they are too big for the other fingers .']
#  ['great service .']
#  ['the prices they charge are outrageous for what you get .']
#  ['this was a fun and delicious dinner to celebrate a birthday .']
#  ["i visited macayo 's because i heard that they had a gluten-free menu ."]
#  ['this place is a shit hole with shit service .']
#  ['when i went back with my wife , the treatment was completely different .']
#  ['top _num_ .']
#  ['every side of theres is just amazing .']
#  ['the food is delicious and served family style .']
#  ['free bike rentals , etc .']
#  ['our dogs mean everything to us .']
#  ['wow !']
#  ['it was a glorious sunday .']
#  ['the crispy fish with mango was so good !']
#  ['anyway , i have been twice for a dinner and it has been sub-par .']
#  ['she calls back _num_ mins later and tells me his blood work looks great .']
#  ['i have always wanted to find a go-to makeup girl and i found one !']
#  ['the food is always good and the staff friendly .']
#  ['and sometimes even rotten -- i.e .']
#  ['dr. davis and his staff are absolutely wonderful !']
#  ['seems like a lack of truth in advertising .']
#  ["she 's a doll !"]
#  ['i used to live near here and this is my favorite safeway .']
#  ["i ca n't imagine the need to return here ."]
#  ['we had a pleasant experience that exceeded our expectations and recommend it !']
#  ['dr. hall is so kind and gentle .']
#  ['i wish i could say the same for my burrito .']
#  ['the food was delicious and the meet cook exactly the way we requested .']
#  ['exceptional service .']
#  ['but its a good thing because thats how popular they are in our are .']
#  ['great job .']
#  ['their philly cheese steaks are also delicious !']
#  ['best hot salsa in town .']
#  ['great service from the staff and very generous and affordable meals .']
#  ['they have daily specials and plenty of comfort food on their menu .']
#  ['i was very pleased by everyone !']
#  ['and this second go around is horrible !']
#  ['fun place for a lively group dinner .']
#  ['fun place , fun times , and amazing food !']
#  ["we 've been going there nearly monthly for over _num_ years ."]
#  ['i just love this place .']
#  ['i will certainly return for the service .']
#  ['i will not be shopping here anymore .']
#  ['this place is awesome .']
#  ['thank you barry and crew so much for everything you guys do .']
#  ['absolutely fabulous !']
#  ['great service and prices on new tires for my truck .']
#  ['great food and a nice selection of beer and wine .']
#  ['i will definitely be returning soon !']
#  ['overpriced and not even very good .']
#  ['will try to make it back to have a full meal for sure .']
#  ['my husband order a plate of albacore again .']
#  ['i am glad i di not get any appointment with this group .']
#  ['moldy bread was served then replaced .']
#  ['i highly recommend the calzone or stromboli .']
#  ['the price for the quality is good .']
#  ['just another rip off joint .']
#  ['great views and great food !']]

# %%
for epoch in range(1, 10):
    # Train
    iterator.restart_dataset(sess, ['train_g'])
    _train_epoch(sess, epoch)

    # Val
    iterator.restart_dataset(sess, 'val')
    _eval_epoch(sess, epoch, 'val')

    #saver.save(sess, os.path.join(config.checkpoint_path, 'ckpt'), epoch)
    saver.save(sess, os.path.join('screensave', 'model'), epoch)

    # Test
    iterator.restart_dataset(sess, 'test')
    _eval_epoch(sess, gamma_, lambda_g_, epoch, 'test')
